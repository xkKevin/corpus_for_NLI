# %%
import numpy as np
import tensorflow as tf
import sys
import time
from datetime import timedelta
import tensorflow.contrib.keras as kr
from sklearn import metrics
from sklearn.model_selection import KFold

import moxing as mox
mox.file.shift('os', 'mox')
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2

# %%
trainDataPath = "s3://corpus-text-classification1/data/train_5500.label.txt"
testDataPath = "s3://corpus-text-classification1/data/TREC_10.label.txt"
vocabPath = "s3://corpus-text-classification1/data/glove.6B.100d.txt"

# %%
def readfile(filePath):
    """读取文件内容，返回文本和标签列表"""
    train_data = []
    with open(filePath, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f.readlines():
            word = line.strip().split()
            label = word[0].split(":")[0]
            content = word[1:]
            train_data.append([content,label])
    
    np.random.shuffle(train_data)
    return np.asarray(train_data)


def loadGloVe(filename):
    vocab = []
    embd = []
    print('Loading GloVe!')
    # vocab.append('unk') #装载不认识的词
    # embd.append([0] * emb_size) #这个emb_size可能需要指定
    file = open(filename,'r',encoding='utf-8')
    for line in file.readlines():
        row = line.strip().split(' ')
        vocab.append(row[0])
        embd.append([float(ei) for ei in row[1:]])
    file.close()
    print('Completed!')
    return vocab,embd


def process_file(contents, labels, word_to_id, cat_to_id, num_classes, pad_max_length):
    """
    将文件转换为id表示,并且将每个单独的样本长度固定为pad_max_lengtn
    """
    # contents, labels = readfile(filePath)
    data_id, label_id = [], []
    # 将文本内容转换为对应的id形式
    for i in range(len(contents)):
        data_id.append([word_to_id[x] for x in contents[i] if x in word_to_id])
        label_id.append(cat_to_id[labels[i]])
    # 使用keras提供的pad_sequences来将文本pad为固定长度
    x_pad = kr.preprocessing.sequence.pad_sequences(data_id, pad_max_length)
    ''' https://blog.csdn.net/TH_NUM/article/details/80904900
    pad_sequences(sequences, maxlen=None, dtype=’int32’, padding=’pre’, truncating=’pre’, value=0.) 
        sequences：浮点数或整数构成的两层嵌套列表
        maxlen：None或整数，为序列的最大长度。大于此长度的序列将被截短，小于此长度的序列将在后部填0.
        dtype：返回的numpy array的数据类型
        padding：‘pre’或‘post’，确定当需要补0时，在序列的起始还是结尾补
        truncating：‘pre’或‘post’，确定当需要截断序列时，从起始还是结尾截断
        value：浮点数，此值将在填充时代替默认的填充值0
    '''
    y_pad = kr.utils.to_categorical(label_id, num_classes=num_classes)  # 将标签转换为one-hot表示
    ''' https://blog.csdn.net/nima1994/article/details/82468965
    to_categorical(y, num_classes=None, dtype='float32')
        将整型标签转为onehot。y为int数组，num_classes为标签类别总数，大于max(y)（标签从0开始的）。
        返回：如果num_classes=None，返回len(y) * [max(y)+1]（维度，m*n表示m行n列矩阵，下同），否则为len(y) * num_classes。
    '''
    return x_pad, y_pad

# %%
categories = ['ABBR', 'DESC', 'ENTY', 'HUM', 'LOC', 'NUM']
num_classes = len(categories)

cat_to_id = {'ABBR': 0, 'DESC': 1, 'ENTY': 2, 'HUM': 3, 'LOC': 4, 'NUM': 5}

vocab, embd = loadGloVe(vocabPath)
vocab_size = len(vocab)
embedding_dim = len(embd[0])
embedding = np.asarray(embd)
word_to_id = dict(zip(vocab, range(vocab_size)))

print(len(embedding),embedding_dim,vocab_size)

testData = readfile(testDataPath)
trainData = readfile(trainDataPath)

print(len(testData),len(trainData))
trainData = np.r_[trainData,testData]
np.random.shuffle(trainData)
len(trainData)

seq_length = 37
# Out:
# Loading GloVe!
# Completed!
# 400000 100 400000
# 500 5452

# %% [raw]
# def train_10_fold(train_data, categories):
#
#     tx, ty = process_file(train_data[:,0], train_data[:,1], word_to_id, cat_to_id, num_classes, seq_length)
#     print(len(tx),len(tx[0]),len(tx[1]))
#
#     fold_id = 0
#     test_acc = []
#
#     kf = KFold(n_splits=10)
#     for train_i, test_i in kf.split(tx):
#         fold_id += 1
#         print("Fold: ", fold_id)
#         test_acc.append(classifier.train(
#             X_train=tx[train_i],
#             y_train=ty[train_i],
#             X_eval=tx[test_i],
#             y_eval=ty[test_i],
#             categories=categories,
#             epochs=30
#         ))
#     print(test_acc)
#     print("%s, %s, %s, %s" % (np.mean(test_acc),np.std(test_acc),np.std(test_acc,ddof=1),np.var(test_acc)))
#     return test_acc

# %%
def train_split_data(model, train_data, categories):
    test_acc = []
    fold_id = 0

    tx, ty = process_file(train_data[:,0], train_data[:,1], word_to_id, cat_to_id, num_classes, seq_length)
    print(len(tx),len(tx[0]),len(tx[1]))

    kf = KFold(n_splits=10)
    for train_i, test_i in kf.split(tx):
        fold_id += 1
        print("Fold: ", fold_id)
        test_acc.append(model_train(model,tx[train_i], ty[train_i],tx[test_i], ty[test_i],categories))
        
    print(test_acc)
    print("%s, %s, %s, %s" % (np.mean(test_acc),np.std(test_acc),np.std(test_acc,ddof=1),np.var(test_acc)))
    return test_acc


def batch_iter(x_pad, y_pad, batch_size):
    """生成批次数据"""
    data_len = len(x_pad)
    num_batch = int((data_len - 1) / batch_size) + 1
    # np.arange()生成0到data_len的等差数列，默认等差为1；np.random.permutation()打乱生成的等差序列的顺序
    # 下面三句语句是为了将训练或测试文本的顺序打乱，因为原文本中每个分类的样本全部挨在一起，这样每个batch训练的都是同一个分类，不太好，打乱后每个batch可包含不同分类
    indices = np.random.permutation(np.arange(data_len))
    x_shuffle = x_pad[indices]
    y_shuffle = y_pad[indices]

    # 返回所有batch的数据
    for i in range(num_batch):
        start_id = i * batch_size
        end_id = min((i + 1) * batch_size, data_len)
        yield x_shuffle[start_id:end_id], y_shuffle[start_id:end_id]
        
        
def evaluate(sess, model, x_pad, y_pad, loss1, acc1, batch_size):
    """评估在某一数据上的准确率和损失"""
    data_len = len(x_pad)
    batch_eval = batch_iter(x_pad, y_pad, batch_size)  # 128
    total_loss = 0.0
    total_acc = 0.0
    for x_batch1, y_batch1 in batch_eval:
        batch_len = len(x_batch1)
        feed_dict1 = {model.inputX: x_batch1, model.inputY: y_batch1, model.dropoutKeepProb: 1.0}
        lossTmp, accTmp = sess.run([loss1, acc1], feed_dict=feed_dict1)
        total_loss += lossTmp * batch_len
        total_acc += accTmp * batch_len

    return total_loss / data_len, total_acc / data_len


def model_train(model, x_train, y_train, x_val, y_val, categories):
    
    # save_path = "%s/%s/%s/%s" % (savePath, split_type, fold_id, fold_id)
    # 创建session
    session = tf.Session()
    session.run(tf.global_variables_initializer())

    print('Training and evaluating...')
    
    total_batch = 0  # 总批次
    best_acc_train = 0.0  # 最佳验证集准确率
    last_improved = 0  # 记录上一次提升批次
    require_improvement = 500  # 如果超过1000轮未提升，提前结束训练
    flag = False

    for epoch in range(num_epochs):  # 20
        start_time = time.time()
        
        print('Epoch:', epoch + 1)
        batch_train = batch_iter(x_train, y_train, batch_size)
        for x_batch, y_batch in batch_train:
            feed_dict = {model.inputX: x_batch, model.inputY: y_batch, model.dropoutKeepProb: dropout_keep_prob}
            session.run(model.trainOp, feed_dict=feed_dict)  # 运行优化
            total_batch += 1

            if total_batch % print_per_batch == 0:
                # 每多少轮次输出在训练集和验证集上的性能
                feed_dict[model.dropoutKeepProb] = 1.0
                loss_train, acc_train = session.run([model.loss, model.acc], feed_dict=feed_dict)
                loss_val, acc_val = evaluate(session, model, x_val, y_val, model.loss, model.acc, 64)
                if acc_val > best_acc_train:
                    # 保存最好结果
                    best_acc_train = acc_val
                    last_improved = total_batch
                    # saver.save(sess=session, save_path=save_path)
                    improved_str = '*'
                else:
                    improved_str = ''
                
                duration = time.time() - start_time
                output = 'Iter: {:>1}, Train Loss: {:>6.4}, Train Acc: {:>6.2%}, Val Loss: {:>6.4}, Val Acc: {:>6.2%}, Time: {:.2f}s {}'
                print(output.format(total_batch, loss_train, acc_train, loss_val, acc_val, duration, improved_str))

            if total_batch - last_improved > require_improvement:
                # 验证集正确率长期不提升，提前结束训练
                print("No optimization for a long time, auto-stopping...")
                
                test_data_len = len(x_val)
                test_num_batch = int((test_data_len - 1) / batch_size) + 1

                y_test_cls = np.argmax(y_val, 1)  # 获得类别
                y_test_pred_cls = np.zeros(shape=len(x_val), dtype=np.int32)  # 保存预测结果  len(x_test) 表示有多少个文本

                for i in range(test_num_batch):  # 逐批次处理
                    start_id = i * batch_size
                    end_id = min((i + 1) * batch_size, test_data_len)
                    feed_dict = {
                        model.inputX: x_val[start_id:end_id],
                        model.dropoutKeepProb: 1.0
                    }
                    y_test_pred_cls[start_id:end_id] = session.run(model.y_pred_cls, feed_dict=feed_dict)

                accuracy_score = metrics.accuracy_score(y_test_cls, y_test_pred_cls)
                # 评估
                print("Precision, Recall and F1-Score...")
                print(metrics.classification_report(y_test_cls, y_test_pred_cls, target_names=categories))
                '''
                sklearn中的classification_report函数用于显示主要分类指标的文本报告．在报告中显示每个类的精确度，召回率，F1值等信息。
                    y_true：1维数组，或标签指示器数组/稀疏矩阵，目标值。 
                    y_pred：1维数组，或标签指示器数组/稀疏矩阵，分类器返回的估计值。 
                    labels：array，shape = [n_labels]，报表中包含的标签索引的可选列表。 
                    target_names：字符串列表，与标签匹配的可选显示名称（相同顺序）。 
                    原文链接：https://blog.csdn.net/akadiao/article/details/78788864
                '''

                # 混淆矩阵
                print("Confusion Matrix...")
                cm = metrics.confusion_matrix(y_test_cls, y_test_pred_cls)
                '''
                混淆矩阵是机器学习中总结分类模型预测结果的情形分析表，以矩阵形式将数据集中的记录按照真实的类别与分类模型作出的分类判断两个标准进行汇总。
                这个名字来源于它可以非常容易的表明多个类别是否有混淆（也就是一个class被预测成另一个class）
                https://blog.csdn.net/u011734144/article/details/80277225
                '''
                print(cm)
                
                flag = True
                break  # 跳出循环
        if flag:  # 同上
            break

    session.close()
    return accuracy_score

# %%
# 构建adversarailLSTM模型
class AdversarailLSTM(object):

    def __init__(self, wordEmbedding):
        # 定义输入
        self.inputX = tf.placeholder(tf.int32, [None, seq_length], name='inputX')
        self.inputY = tf.placeholder(tf.int32, [None, num_classes], name='inputY')

        self.dropoutKeepProb = tf.placeholder(tf.float64, name='keep_prob')

        # 词嵌入层
        with tf.name_scope("wordEmbedding"):
            wordEmbedding = tf.Variable(initial_value=wordEmbedding)
            self.embeddedWords = tf.nn.embedding_lookup(wordEmbedding, self.inputX)

        # 计算softmax交叉熵损失
        with tf.name_scope("loss"):
            with tf.variable_scope("Bi-LSTM", reuse=None):
                self.predictions = self._Bi_LSTMAttention(self.embeddedWords)
                # self.y_pred_cls = tf.cast(tf.greater_equal(self.predictions, 0.5), tf.float32, name="binaryPreds")
                self.y_pred_cls = tf.argmax(tf.nn.softmax(self.predictions),1)  # 预测类别 tf.argmax：返回每一行或每一列的最大值 1为里面（每一行），0为外面（每一列）
                # losses = tf.nn.sigmoid_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
                losses = tf.nn.softmax_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
                loss = tf.reduce_mean(losses)

        
        with tf.name_scope("perturloss"):
            with tf.variable_scope("Bi-LSTM", reuse=True):
                perturWordEmbedding = self._addPerturbation(self.embeddedWords, loss)
                print("perturbSize:{}".format(perturWordEmbedding))
                perturPredictions = self._Bi_LSTMAttention(perturWordEmbedding)
                # perturLosses = tf.nn.sigmoid_cross_entropy_with_logits(logits=perturPredictions, labels=self.inputY)
                perturLosses = tf.nn.softmax_cross_entropy_with_logits(logits=perturPredictions, labels=self.inputY)
                perturLoss = tf.reduce_mean(perturLosses)

        self.loss = loss + perturLoss
        
        globalStep = tf.Variable(0, name="globalStep", trainable=False)
        # 定义优化函数，传入学习速率参数
        optimizer = tf.train.AdamOptimizer(learning_rate)
        # 计算梯度,得到梯度和变量
        gradsAndVars = optimizer.compute_gradients(self.loss)
        # 将梯度应用到变量下，生成训练器
        self.trainOp = optimizer.apply_gradients(gradsAndVars, global_step=globalStep)

        # 准确率
        correct_pred = tf.equal(tf.argmax(self.inputY, 1), self.y_pred_cls)
        self.acc = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
        
        # self.loss = loss
        
        
    def _Bi_LSTMAttention(self, embeddedWords):
        # 定义两层双向LSTM的模型结构
        with tf.name_scope("Bi-LSTM"):
            fwHiddenLayers = []
            bwHiddenLayers = []
            for idx, hiddenSize in enumerate(hiddenSizes):
                with tf.name_scope("Bi-LSTM" + str(idx)):
                    # 定义前向网络结构
                    lstmFwCell = tf.nn.rnn_cell.DropoutWrapper(
                        tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                        output_keep_prob=self.dropoutKeepProb)

                    # 定义反向网络结构
                    lstmBwCell = tf.nn.rnn_cell.DropoutWrapper(
                        tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                        output_keep_prob=self.dropoutKeepProb)

                fwHiddenLayers.append(lstmFwCell)
                bwHiddenLayers.append(lstmBwCell)

            # 实现多层的LSTM结构， state_is_tuple=True，则状态会以元祖的形式组合(h, c)，否则列向拼接
            fwMultiLstm = tf.nn.rnn_cell.MultiRNNCell(cells=fwHiddenLayers, state_is_tuple=True)
            bwMultiLstm = tf.nn.rnn_cell.MultiRNNCell(cells=bwHiddenLayers, state_is_tuple=True)
            # 采用动态rnn，可以动态地输入序列的长度，若没有输入，则取序列的全长
            # outputs是一个元组(output_fw, output_bw), 其中两个元素的维度都是[batch_size, max_time, hidden_size], fw和bw的hiddensize一样
            # self.current_state是最终的状态，二元组(state_fw, state_bw), state_fw=[batch_size, s], s是一个元组(h, c)
            outputs, self.current_state = tf.nn.bidirectional_dynamic_rnn(fwMultiLstm, bwMultiLstm,
                                                                          self.embeddedWords, dtype=tf.float64,
                                                                          scope="bi-lstm" + str(idx))

        # 在bi-lstm+attention论文中，将前向和后向的输出相加
        with tf.name_scope("Attention"):
            H = outputs[0] + outputs[1]

            # 得到attention的输出
            output = self.attention(H)
            outputSize = hiddenSizes[-1]
            print("outputSize:{}".format(outputSize))

        # 全连接层的输出
        with tf.name_scope("output"):
            outputW = tf.get_variable(
                "outputW", dtype=tf.float64,
                shape=[outputSize, num_classes],
                initializer=tf.contrib.layers.xavier_initializer())

            outputB = tf.Variable(tf.constant(0.1, dtype=tf.float64, shape=[num_classes]), name="outputB")

            predictions = tf.nn.xw_plus_b(output, outputW, outputB, name="predictions")

            return predictions

    def attention(self, H):
        """
        利用Attention机制得到句子的向量表示
        """
        # 获得最后一层lstm神经元的数量
        hiddenSize = hiddenSizes[-1]

        # 初始化一个权重向量，是可训练的参数
        W = tf.Variable(tf.random_normal([hiddenSize], stddev=0.1, dtype=tf.float64))

        # 对bi-lstm的输出用激活函数做非线性转换
        M = tf.tanh(H)

        # 对W和M做矩阵运算，W=[batch_size, time_step, hidden_size], 计算前做维度转换成[batch_size * time_step, hidden_size]
        # newM = [batch_size, time_step, 1], 每一个时间步的输出由向量转换成一个数字
        newM = tf.matmul(tf.reshape(M, [-1, hiddenSize]), tf.reshape(W, [-1, 1]))

        # 对newM做维度转换成[batch_size, time_step]
        restoreM = tf.reshape(newM, [-1, seq_length])

        # 用softmax做归一化处理[batch_size, time_step]
        self.alpha = tf.nn.softmax(restoreM)

        # 利用求得的alpha的值对H进行加权求和，用矩阵运算直接操作
        r = tf.matmul(tf.transpose(H, [0, 2, 1]), tf.reshape(self.alpha, [-1, seq_length, 1]))

        # 将三维压缩成二维sequeezeR = [batch_size, hissen_size]
        sequeezeR = tf.squeeze(r)

        sentenceRepren = tf.tanh(sequeezeR)

        # 对attention的输出可以做dropout处理
        output = tf.nn.dropout(sentenceRepren, self.dropoutKeepProb)

        return output

    def _normalize(self, wordEmbedding, weights):
        """
        对word embedding 结合权重做标准化处理
        """
        mean = tf.matmul(weights, wordEmbedding)
        powWordEmbedding = tf.pow(wordEmbedding - mean, 2.)

        var = tf.matmul(weights, powWordEmbedding)
        stddev = tf.sqrt(1e-6 + var)

        return (wordEmbedding - mean) / stddev

    def _addPerturbation(self, embedded, loss):
        """
        添加波动到word embedding
        """
        grad, = tf.gradients(
            loss,
            embedded,
            aggregation_method=tf.AggregationMethod.EXPERIMENTAL_ACCUMULATE_N)
        grad = tf.stop_gradient(grad)
        perturb = self._scaleL2(grad, epsilon)
        # print("perturbSize:{}".format(embedded+perturb))
        return embedded + perturb

    def _scaleL2(self, x, norm_length):
        # shape(x) = [batch, num_step, d]
        # divide x by max(abs(x)) for a numerically stable L2 norm
        # 2norm(x) = a * 2norm(x/a)
        # scale over the full sequence, dim(1, 2)
        alpha = tf.reduce_max(tf.abs(x), (1, 2), keep_dims=True) + 1e-12
        l2_norm = alpha * tf.sqrt(tf.reduce_sum(tf.pow(x / alpha, 2), (1, 2), keep_dims=True) + 1e-6)
        x_unit = x / l2_norm
        return norm_length * x_unit

# %%
hiddenSizes = [128]  # 定义LSTM的隐藏层（一层，128个神经元）
epsilon = 5

num_filters = 256
kernel_size = 5
hidden_dim = 128
learning_rate = 1e-3
dropout_keep_prob = 0.5

num_epochs = 50
batch_size = 64
print_per_batch = 30  # 每多少轮输出一次结果

lstm = AdversarailLSTM(embedding)
# Out:
# outputSize:128
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:171: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:171: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:172: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:172: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# perturbSize:Tensor("perturloss/Bi-LSTM/add_2:0", shape=(?, 37, 100), dtype=float64)
# outputSize:128

# %%
train_split_data(lstm,trainData,categories)
# Out:
# 5952 37 37
# Fold:  1
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.234, Train Acc: 20.31%, Val Loss:  3.332, Val Acc: 20.30%, Time: 5.82s *
# Iter: 60, Train Loss:  3.086, Train Acc: 34.38%, Val Loss:  3.123, Val Acc: 32.89%, Time: 10.40s *
# Epoch: 2
# Iter: 90, Train Loss:  2.604, Train Acc: 54.69%, Val Loss:  2.735, Val Acc: 45.47%, Time: 1.44s *
# Iter: 120, Train Loss:  2.035, Train Acc: 67.19%, Val Loss:  2.448, Val Acc: 52.85%, Time: 6.02s *
# Iter: 150, Train Loss:  2.174, Train Acc: 64.06%, Val Loss:   2.13, Val Acc: 60.07%, Time: 10.58s *
# Epoch: 3
# Iter: 180, Train Loss:  1.469, Train Acc: 79.69%, Val Loss:  1.884, Val Acc: 65.10%, Time: 2.30s *
# Iter: 210, Train Loss:   1.34, Train Acc: 75.00%, Val Loss:  1.767, Val Acc: 66.28%, Time: 6.98s *
# Iter: 240, Train Loss:  1.147, Train Acc: 79.69%, Val Loss:  1.614, Val Acc: 70.64%, Time: 11.61s *
# Epoch: 4
# Iter: 270, Train Loss:  1.251, Train Acc: 79.69%, Val Loss:  1.537, Val Acc: 71.64%, Time: 3.01s *
# Iter: 300, Train Loss:  1.158, Train Acc: 75.00%, Val Loss:  1.488, Val Acc: 72.99%, Time: 7.62s *
# Iter: 330, Train Loss: 0.9644, Train Acc: 87.50%, Val Loss:  1.462, Val Acc: 74.50%, Time: 12.21s *
# Epoch: 5
# Iter: 360, Train Loss:   1.04, Train Acc: 78.12%, Val Loss:   1.38, Val Acc: 75.34%, Time: 3.83s *
# Iter: 390, Train Loss: 0.5909, Train Acc: 89.06%, Val Loss:  1.409, Val Acc: 75.50%, Time: 8.44s *
# Iter: 420, Train Loss: 0.7128, Train Acc: 88.64%, Val Loss:  1.385, Val Acc: 76.34%, Time: 13.10s *
# Epoch: 6
# Iter: 450, Train Loss: 0.7781, Train Acc: 81.25%, Val Loss:  1.323, Val Acc: 77.01%, Time: 4.62s *
# Iter: 480, Train Loss: 0.6926, Train Acc: 90.62%, Val Loss:  1.348, Val Acc: 77.01%, Time: 9.28s
# Epoch: 7
# Iter: 510, Train Loss: 0.3929, Train Acc: 95.31%, Val Loss:  1.291, Val Acc: 78.69%, Time: 1.42s *
# Iter: 540, Train Loss: 0.4899, Train Acc: 93.75%, Val Loss:  1.374, Val Acc: 76.85%, Time: 5.99s
# Iter: 570, Train Loss: 0.5121, Train Acc: 92.19%, Val Loss:  1.336, Val Acc: 77.68%, Time: 10.63s
# Epoch: 8
# Iter: 600, Train Loss: 0.2257, Train Acc: 96.88%, Val Loss:  1.338, Val Acc: 78.69%, Time: 2.20s
# Iter: 630, Train Loss: 0.6534, Train Acc: 85.94%, Val Loss:   1.35, Val Acc: 78.86%, Time: 6.79s *
# Iter: 660, Train Loss: 0.6574, Train Acc: 85.94%, Val Loss:  1.346, Val Acc: 78.52%, Time: 11.35s
# Epoch: 9
# Iter: 690, Train Loss: 0.2947, Train Acc: 95.31%, Val Loss:  1.381, Val Acc: 78.02%, Time: 3.00s
# Iter: 720, Train Loss: 0.4213, Train Acc: 92.19%, Val Loss:  1.333, Val Acc: 77.68%, Time: 7.59s
# Iter: 750, Train Loss: 0.5144, Train Acc: 93.75%, Val Loss:  1.438, Val Acc: 79.36%, Time: 12.20s *
# Epoch: 10
# Iter: 780, Train Loss: 0.2823, Train Acc: 95.31%, Val Loss:  1.449, Val Acc: 79.70%, Time: 3.76s *
# Iter: 810, Train Loss:  0.109, Train Acc: 96.88%, Val Loss:  1.588, Val Acc: 77.18%, Time: 8.29s
# Iter: 840, Train Loss: 0.2537, Train Acc: 95.45%, Val Loss:  1.433, Val Acc: 79.03%, Time: 12.88s
# Epoch: 11
# Iter: 870, Train Loss: 0.4946, Train Acc: 90.62%, Val Loss:  1.398, Val Acc: 78.86%, Time: 4.61s
# Iter: 900, Train Loss: 0.2094, Train Acc: 95.31%, Val Loss:  1.526, Val Acc: 80.20%, Time: 9.18s *
# Epoch: 12
# Iter: 930, Train Loss: 0.1822, Train Acc: 96.88%, Val Loss:   1.56, Val Acc: 78.69%, Time: 1.41s
# Iter: 960, Train Loss: 0.1184, Train Acc: 98.44%, Val Loss:  1.537, Val Acc: 78.86%, Time: 5.99s
# Iter: 990, Train Loss: 0.2288, Train Acc: 95.31%, Val Loss:   1.53, Val Acc: 79.70%, Time: 10.64s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2048, Train Acc: 95.31%, Val Loss:  1.626, Val Acc: 78.19%, Time: 2.18s
# Iter: 1050, Train Loss: 0.2185, Train Acc: 96.88%, Val Loss:  1.514, Val Acc: 81.54%, Time: 6.74s *
# Iter: 1080, Train Loss: 0.2849, Train Acc: 93.75%, Val Loss:  1.527, Val Acc: 79.87%, Time: 11.31s
# Epoch: 14
# Iter: 1110, Train Loss: 0.2982, Train Acc: 93.75%, Val Loss:  1.615, Val Acc: 78.86%, Time: 3.01s
# Iter: 1140, Train Loss: 0.1537, Train Acc: 96.88%, Val Loss:  1.672, Val Acc: 78.86%, Time: 7.59s
# Iter: 1170, Train Loss: 0.3019, Train Acc: 93.75%, Val Loss:  1.832, Val Acc: 77.01%, Time: 12.16s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1643, Train Acc: 98.44%, Val Loss:  1.604, Val Acc: 79.03%, Time: 3.79s
# Iter: 1230, Train Loss: 0.1592, Train Acc: 98.44%, Val Loss:  1.821, Val Acc: 79.70%, Time: 8.33s
# Iter: 1260, Train Loss: 0.07714, Train Acc: 100.00%, Val Loss:  1.662, Val Acc: 79.03%, Time: 12.90s
# Epoch: 16
# Iter: 1290, Train Loss: 0.2512, Train Acc: 93.75%, Val Loss:   1.72, Val Acc: 78.02%, Time: 4.59s
# Iter: 1320, Train Loss: 0.06769, Train Acc: 98.44%, Val Loss:  1.954, Val Acc: 77.01%, Time: 9.16s
# Epoch: 17
# Iter: 1350, Train Loss: 0.2195, Train Acc: 95.31%, Val Loss:  1.819, Val Acc: 79.03%, Time: 1.43s
# Iter: 1380, Train Loss: 0.05302, Train Acc: 100.00%, Val Loss:  1.897, Val Acc: 77.85%, Time: 6.05s
# Iter: 1410, Train Loss: 0.2267, Train Acc: 96.88%, Val Loss:  1.806, Val Acc: 79.53%, Time: 10.62s
# Epoch: 18
# Iter: 1440, Train Loss: 0.1597, Train Acc: 96.88%, Val Loss:  1.823, Val Acc: 79.53%, Time: 2.19s
# Iter: 1470, Train Loss: 0.2667, Train Acc: 95.31%, Val Loss:  1.758, Val Acc: 81.04%, Time: 6.70s
# Iter: 1500, Train Loss:  0.282, Train Acc: 93.75%, Val Loss:   1.75, Val Acc: 79.19%, Time: 11.26s
# Epoch: 19
# Iter: 1530, Train Loss: 0.1921, Train Acc: 96.88%, Val Loss:  1.917, Val Acc: 78.69%, Time: 3.01s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.89      0.73      0.80        11
#         DESC       0.74      0.67      0.70       124
#         ENTY       0.70      0.75      0.73       130
#          HUM       0.77      0.81      0.79       121
#          LOC       0.85      0.84      0.84        86
#          NUM       0.93      0.91      0.92       124
#
#    micro avg       0.79      0.79      0.79       596
#    macro avg       0.81      0.78      0.80       596
# weighted avg       0.79      0.79      0.79       596
#
# Confusion Matrix...
# [[  8   1   1   1   0   0]
#  [  0  83  20  12   4   5]
#  [  1  14  98  12   3   2]
#  [  0   6  11  98   4   2]
#  [  0   5   5   4  72   0]
#  [  0   3   5   1   2 113]]
# Fold:  2
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.354, Train Acc: 25.00%, Val Loss:  3.297, Val Acc: 27.18%, Time: 5.70s *
# Iter: 60, Train Loss:  2.986, Train Acc: 40.62%, Val Loss:  3.148, Val Acc: 35.74%, Time: 10.35s *
# Epoch: 2
# Iter: 90, Train Loss:   2.72, Train Acc: 45.31%, Val Loss:  2.731, Val Acc: 48.49%, Time: 1.44s *
# Iter: 120, Train Loss:  2.071, Train Acc: 64.06%, Val Loss:  2.319, Val Acc: 59.56%, Time: 6.11s *
# Iter: 150, Train Loss:  2.053, Train Acc: 59.38%, Val Loss:  1.991, Val Acc: 65.10%, Time: 10.73s *
# Epoch: 3
# Iter: 180, Train Loss:   1.95, Train Acc: 67.19%, Val Loss:  1.831, Val Acc: 67.62%, Time: 2.23s *
# Iter: 210, Train Loss:  1.931, Train Acc: 60.94%, Val Loss:   1.68, Val Acc: 69.97%, Time: 6.88s *
# Iter: 240, Train Loss:  1.376, Train Acc: 76.56%, Val Loss:  1.465, Val Acc: 72.15%, Time: 11.47s *
# Epoch: 4
# Iter: 270, Train Loss: 0.9258, Train Acc: 87.50%, Val Loss:  1.425, Val Acc: 72.32%, Time: 3.00s *
# Iter: 300, Train Loss: 0.9115, Train Acc: 82.81%, Val Loss:   1.35, Val Acc: 76.17%, Time: 7.56s *
# Iter: 330, Train Loss:  1.011, Train Acc: 82.81%, Val Loss:  1.254, Val Acc: 76.34%, Time: 12.13s *
# Epoch: 5
# Iter: 360, Train Loss: 0.7748, Train Acc: 89.06%, Val Loss:  1.237, Val Acc: 77.85%, Time: 3.80s *
# Iter: 390, Train Loss:  0.909, Train Acc: 82.81%, Val Loss:  1.228, Val Acc: 77.35%, Time: 8.40s
# Iter: 420, Train Loss: 0.8951, Train Acc: 81.82%, Val Loss:  1.193, Val Acc: 78.19%, Time: 13.01s *
# Epoch: 6
# Iter: 450, Train Loss: 0.9086, Train Acc: 82.81%, Val Loss:  1.266, Val Acc: 76.34%, Time: 4.57s
# Iter: 480, Train Loss:  0.452, Train Acc: 93.75%, Val Loss:  1.202, Val Acc: 79.70%, Time: 9.22s *
# Epoch: 7
# Iter: 510, Train Loss: 0.2435, Train Acc: 96.88%, Val Loss:  1.186, Val Acc: 78.52%, Time: 1.43s
# Iter: 540, Train Loss: 0.4524, Train Acc: 89.06%, Val Loss:  1.201, Val Acc: 79.03%, Time: 6.00s
# Iter: 570, Train Loss: 0.5401, Train Acc: 85.94%, Val Loss:  1.201, Val Acc: 79.03%, Time: 10.59s
# Epoch: 8
# Iter: 600, Train Loss: 0.1521, Train Acc: 98.44%, Val Loss:  1.267, Val Acc: 78.86%, Time: 2.21s
# Iter: 630, Train Loss: 0.6329, Train Acc: 90.62%, Val Loss:  1.407, Val Acc: 77.52%, Time: 6.80s
# Iter: 660, Train Loss: 0.6049, Train Acc: 89.06%, Val Loss:   1.32, Val Acc: 77.52%, Time: 11.41s
# Epoch: 9
# Iter: 690, Train Loss: 0.1701, Train Acc: 98.44%, Val Loss:  1.201, Val Acc: 80.03%, Time: 2.98s *
# Iter: 720, Train Loss: 0.2251, Train Acc: 96.88%, Val Loss:   1.33, Val Acc: 78.69%, Time: 7.51s
# Iter: 750, Train Loss: 0.3727, Train Acc: 92.19%, Val Loss:  1.264, Val Acc: 78.36%, Time: 12.09s
# Epoch: 10
# Iter: 780, Train Loss: 0.3903, Train Acc: 93.75%, Val Loss:  1.278, Val Acc: 78.69%, Time: 3.84s
# Iter: 810, Train Loss: 0.2308, Train Acc: 93.75%, Val Loss:   1.31, Val Acc: 79.53%, Time: 8.40s
# Iter: 840, Train Loss: 0.1313, Train Acc: 100.00%, Val Loss:  1.398, Val Acc: 80.70%, Time: 12.98s *
# Epoch: 11
# Iter: 870, Train Loss: 0.2412, Train Acc: 95.31%, Val Loss:   1.35, Val Acc: 81.21%, Time: 4.58s *
# Iter: 900, Train Loss: 0.3535, Train Acc: 90.62%, Val Loss:  1.465, Val Acc: 77.85%, Time: 9.14s
# Epoch: 12
# Iter: 930, Train Loss: 0.3543, Train Acc: 95.31%, Val Loss:  1.285, Val Acc: 78.69%, Time: 1.42s
# Iter: 960, Train Loss: 0.2297, Train Acc: 96.88%, Val Loss:   1.45, Val Acc: 80.70%, Time: 5.99s
# Iter: 990, Train Loss: 0.4255, Train Acc: 92.19%, Val Loss:  1.697, Val Acc: 77.85%, Time: 10.62s
# Epoch: 13
# Iter: 1020, Train Loss: 0.1882, Train Acc: 96.88%, Val Loss:  1.321, Val Acc: 79.36%, Time: 2.23s
# Iter: 1050, Train Loss: 0.2676, Train Acc: 96.88%, Val Loss:  1.375, Val Acc: 79.70%, Time: 6.83s
# Iter: 1080, Train Loss: 0.1882, Train Acc: 96.88%, Val Loss:  1.401, Val Acc: 80.37%, Time: 11.42s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1315, Train Acc: 98.44%, Val Loss:  1.498, Val Acc: 80.70%, Time: 3.00s
# Iter: 1140, Train Loss: 0.1667, Train Acc: 96.88%, Val Loss:  1.399, Val Acc: 79.36%, Time: 7.61s
# Iter: 1170, Train Loss: 0.2565, Train Acc: 95.31%, Val Loss:  1.403, Val Acc: 80.54%, Time: 12.18s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1357, Train Acc: 98.44%, Val Loss:  1.672, Val Acc: 79.03%, Time: 3.88s
# Iter: 1230, Train Loss: 0.2149, Train Acc: 96.88%, Val Loss:  1.367, Val Acc: 78.69%, Time: 8.42s
# Iter: 1260, Train Loss: 0.2224, Train Acc: 95.45%, Val Loss:  1.527, Val Acc: 78.69%, Time: 12.99s
# Epoch: 16
# Iter: 1290, Train Loss: 0.3708, Train Acc: 95.31%, Val Loss:  1.632, Val Acc: 80.03%, Time: 4.61s
# Iter: 1320, Train Loss: 0.1078, Train Acc: 98.44%, Val Loss:  1.667, Val Acc: 79.87%, Time: 9.25s
# Epoch: 17
# Iter: 1350, Train Loss: 0.4543, Train Acc: 93.75%, Val Loss:  1.584, Val Acc: 79.53%, Time: 1.42s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.73      0.85        15
#         DESC       0.75      0.80      0.77       152
#         ENTY       0.73      0.80      0.77       138
#          HUM       0.87      0.80      0.83       120
#          LOC       0.86      0.69      0.76        86
#          NUM       0.81      0.88      0.84        85
#
#    micro avg       0.79      0.79      0.79       596
#    macro avg       0.84      0.78      0.80       596
# weighted avg       0.80      0.79      0.79       596
#
# Confusion Matrix...
# [[ 11   3   1   0   0   0]
#  [  0 121  17   3   6   5]
#  [  0  13 111   5   2   7]
#  [  0   6  15  96   0   3]
#  [  0  15   4   5  59   3]
#  [  0   3   4   1   2  75]]
# Fold:  3
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.218, Train Acc: 25.00%, Val Loss:  3.263, Val Acc: 27.90%, Time: 5.61s *
# Iter: 60, Train Loss:  3.059, Train Acc: 45.31%, Val Loss:  3.066, Val Acc: 47.06%, Time: 10.18s *
# Epoch: 2
# Iter: 90, Train Loss:  2.526, Train Acc: 51.56%, Val Loss:  2.671, Val Acc: 51.60%, Time: 1.42s *
# Iter: 120, Train Loss:  2.407, Train Acc: 62.50%, Val Loss:  2.412, Val Acc: 57.48%, Time: 5.99s *
# Iter: 150, Train Loss:  2.056, Train Acc: 64.06%, Val Loss:  2.066, Val Acc: 64.37%, Time: 10.61s *
# Epoch: 3
# Iter: 180, Train Loss:  1.668, Train Acc: 68.75%, Val Loss:  1.855, Val Acc: 68.57%, Time: 2.18s *
# Iter: 210, Train Loss:  1.699, Train Acc: 70.31%, Val Loss:  1.821, Val Acc: 67.90%, Time: 6.74s
# Iter: 240, Train Loss:  1.353, Train Acc: 73.44%, Val Loss:  1.609, Val Acc: 72.94%, Time: 11.31s *
# Epoch: 4
# Iter: 270, Train Loss:  1.214, Train Acc: 84.38%, Val Loss:    1.5, Val Acc: 74.12%, Time: 3.00s *
# Iter: 300, Train Loss:  1.207, Train Acc: 78.12%, Val Loss:  1.419, Val Acc: 75.97%, Time: 7.60s *
# Iter: 330, Train Loss:  1.333, Train Acc: 81.25%, Val Loss:   1.39, Val Acc: 75.97%, Time: 12.28s
# Epoch: 5
# Iter: 360, Train Loss: 0.9719, Train Acc: 78.12%, Val Loss:  1.325, Val Acc: 78.15%, Time: 3.84s *
# Iter: 390, Train Loss: 0.7989, Train Acc: 85.94%, Val Loss:  1.442, Val Acc: 76.30%, Time: 8.42s
# Iter: 420, Train Loss: 0.6528, Train Acc: 91.11%, Val Loss:  1.275, Val Acc: 77.98%, Time: 13.04s
# Epoch: 6
# Iter: 450, Train Loss: 0.6501, Train Acc: 89.06%, Val Loss:  1.344, Val Acc: 77.31%, Time: 4.62s
# Iter: 480, Train Loss: 0.9044, Train Acc: 82.81%, Val Loss:  1.284, Val Acc: 78.15%, Time: 9.20s *
# Epoch: 7
# Iter: 510, Train Loss: 0.6148, Train Acc: 87.50%, Val Loss:  1.264, Val Acc: 80.00%, Time: 1.43s *
# Iter: 540, Train Loss: 0.4573, Train Acc: 90.62%, Val Loss:  1.335, Val Acc: 78.82%, Time: 6.11s
# Iter: 570, Train Loss: 0.3502, Train Acc: 92.19%, Val Loss:   1.31, Val Acc: 78.99%, Time: 10.75s
# Epoch: 8
# Iter: 600, Train Loss:  0.309, Train Acc: 96.88%, Val Loss:  1.265, Val Acc: 80.17%, Time: 2.23s *
# Iter: 630, Train Loss: 0.5552, Train Acc: 90.62%, Val Loss:  1.375, Val Acc: 79.33%, Time: 6.84s
# Iter: 660, Train Loss: 0.3793, Train Acc: 90.62%, Val Loss:  1.307, Val Acc: 80.84%, Time: 11.42s *
# Epoch: 9
# Iter: 690, Train Loss: 0.3279, Train Acc: 95.31%, Val Loss:  1.353, Val Acc: 79.66%, Time: 3.02s
# Iter: 720, Train Loss: 0.1296, Train Acc: 100.00%, Val Loss:  1.374, Val Acc: 80.00%, Time: 7.69s
# Iter: 750, Train Loss: 0.3897, Train Acc: 95.31%, Val Loss:   1.48, Val Acc: 80.34%, Time: 12.30s
# Epoch: 10
# Iter: 780, Train Loss: 0.3352, Train Acc: 95.31%, Val Loss:  1.567, Val Acc: 79.66%, Time: 3.81s
# Iter: 810, Train Loss:  0.507, Train Acc: 89.06%, Val Loss:  1.529, Val Acc: 79.50%, Time: 8.40s
# Iter: 840, Train Loss: 0.3239, Train Acc: 95.56%, Val Loss:  1.586, Val Acc: 80.00%, Time: 13.01s
# Epoch: 11
# Iter: 870, Train Loss: 0.1876, Train Acc: 96.88%, Val Loss:  1.507, Val Acc: 80.17%, Time: 4.58s
# Iter: 900, Train Loss: 0.3013, Train Acc: 93.75%, Val Loss:  1.607, Val Acc: 80.17%, Time: 9.12s
# Epoch: 12
# Iter: 930, Train Loss: 0.1771, Train Acc: 95.31%, Val Loss:  1.709, Val Acc: 78.32%, Time: 1.43s
# Iter: 960, Train Loss: 0.1913, Train Acc: 96.88%, Val Loss:  1.665, Val Acc: 79.50%, Time: 5.97s
# Iter: 990, Train Loss: 0.1659, Train Acc: 98.44%, Val Loss:  1.635, Val Acc: 78.99%, Time: 10.55s
# Epoch: 13
# Iter: 1020, Train Loss: 0.04105, Train Acc: 100.00%, Val Loss:   1.71, Val Acc: 79.16%, Time: 2.25s
# Iter: 1050, Train Loss: 0.1917, Train Acc: 96.88%, Val Loss:  1.688, Val Acc: 78.99%, Time: 6.79s
# Iter: 1080, Train Loss: 0.3291, Train Acc: 93.75%, Val Loss:  1.986, Val Acc: 78.32%, Time: 11.39s
# Epoch: 14
# Iter: 1110, Train Loss: 0.3178, Train Acc: 96.88%, Val Loss:  1.806, Val Acc: 75.13%, Time: 3.08s
# Iter: 1140, Train Loss: 0.4715, Train Acc: 92.19%, Val Loss:  1.516, Val Acc: 78.99%, Time: 7.79s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.78      0.88         9
#         DESC       0.75      0.78      0.77       130
#         ENTY       0.76      0.79      0.78       140
#          HUM       0.80      0.79      0.80       131
#          LOC       0.75      0.71      0.73        85
#          NUM       0.86      0.84      0.85       100
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.82      0.78      0.80       595
# weighted avg       0.79      0.78      0.79       595
#
# Confusion Matrix...
# [[  7   2   0   0   0   0]
#  [  0 102  15   5   5   3]
#  [  0  11 111   8   5   5]
#  [  0   6  12 103   7   3]
#  [  0  12   4   6  60   3]
#  [  0   3   4   6   3  84]]
# Fold:  4
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.288, Train Acc: 21.88%, Val Loss:  3.282, Val Acc: 21.68%, Time: 5.57s *
# Iter: 60, Train Loss:  3.213, Train Acc: 29.69%, Val Loss:  2.989, Val Acc: 40.17%, Time: 10.13s *
# Epoch: 2
# Iter: 90, Train Loss:  2.721, Train Acc: 51.56%, Val Loss:  2.659, Val Acc: 51.93%, Time: 1.39s *
# Iter: 120, Train Loss:  2.511, Train Acc: 59.38%, Val Loss:  2.291, Val Acc: 59.33%, Time: 5.98s *
# Iter: 150, Train Loss:  1.866, Train Acc: 64.06%, Val Loss:  2.099, Val Acc: 62.69%, Time: 10.56s *
# Epoch: 3
# Iter: 180, Train Loss:  1.147, Train Acc: 82.81%, Val Loss:  1.857, Val Acc: 66.39%, Time: 2.20s *
# Iter: 210, Train Loss:  1.499, Train Acc: 76.56%, Val Loss:  1.704, Val Acc: 70.08%, Time: 6.75s *
# Iter: 240, Train Loss: 0.8999, Train Acc: 87.50%, Val Loss:  1.538, Val Acc: 71.93%, Time: 11.28s *
# Epoch: 4
# Iter: 270, Train Loss:  0.899, Train Acc: 78.12%, Val Loss:  1.476, Val Acc: 72.77%, Time: 2.97s *
# Iter: 300, Train Loss:  1.072, Train Acc: 78.12%, Val Loss:   1.41, Val Acc: 75.80%, Time: 7.46s *
# Iter: 330, Train Loss: 0.8441, Train Acc: 81.25%, Val Loss:  1.378, Val Acc: 76.64%, Time: 12.05s *
# Epoch: 5
# Iter: 360, Train Loss:  0.616, Train Acc: 90.62%, Val Loss:    1.4, Val Acc: 76.81%, Time: 3.77s *
# Iter: 390, Train Loss: 0.5685, Train Acc: 90.62%, Val Loss:  1.384, Val Acc: 75.29%, Time: 8.35s
# Iter: 420, Train Loss: 0.8543, Train Acc: 88.89%, Val Loss:  1.337, Val Acc: 77.48%, Time: 12.88s *
# Epoch: 6
# Iter: 450, Train Loss: 0.7782, Train Acc: 85.94%, Val Loss:  1.349, Val Acc: 78.49%, Time: 4.50s *
# Iter: 480, Train Loss: 0.3047, Train Acc: 96.88%, Val Loss:  1.298, Val Acc: 79.83%, Time: 9.03s *
# Epoch: 7
# Iter: 510, Train Loss:  0.563, Train Acc: 90.62%, Val Loss:  1.365, Val Acc: 78.82%, Time: 1.41s
# Iter: 540, Train Loss: 0.5765, Train Acc: 89.06%, Val Loss:  1.526, Val Acc: 78.49%, Time: 5.96s
# Iter: 570, Train Loss: 0.4639, Train Acc: 90.62%, Val Loss:  1.364, Val Acc: 80.34%, Time: 10.49s *
# Epoch: 8
# Iter: 600, Train Loss: 0.4853, Train Acc: 92.19%, Val Loss:  1.529, Val Acc: 78.99%, Time: 2.19s
# Iter: 630, Train Loss: 0.3279, Train Acc: 96.88%, Val Loss:   1.38, Val Acc: 78.99%, Time: 6.75s
# Iter: 660, Train Loss: 0.4086, Train Acc: 93.75%, Val Loss:  1.453, Val Acc: 80.00%, Time: 11.32s
# Epoch: 9
# Iter: 690, Train Loss: 0.3784, Train Acc: 92.19%, Val Loss:   1.56, Val Acc: 78.99%, Time: 3.02s
# Iter: 720, Train Loss: 0.4577, Train Acc: 90.62%, Val Loss:  1.685, Val Acc: 78.82%, Time: 7.59s
# Iter: 750, Train Loss:   0.13, Train Acc: 100.00%, Val Loss:  1.417, Val Acc: 80.00%, Time: 12.19s
# Epoch: 10
# Iter: 780, Train Loss: 0.2202, Train Acc: 96.88%, Val Loss:   1.53, Val Acc: 78.99%, Time: 3.80s
# Iter: 810, Train Loss:  0.578, Train Acc: 87.50%, Val Loss:  1.561, Val Acc: 80.50%, Time: 8.38s *
# Iter: 840, Train Loss: 0.3364, Train Acc: 95.56%, Val Loss:  1.749, Val Acc: 75.97%, Time: 12.97s
# Epoch: 11
# Iter: 870, Train Loss: 0.4616, Train Acc: 92.19%, Val Loss:  1.463, Val Acc: 79.33%, Time: 4.57s
# Iter: 900, Train Loss: 0.2938, Train Acc: 93.75%, Val Loss:  1.578, Val Acc: 79.66%, Time: 9.18s
# Epoch: 12
# Iter: 930, Train Loss: 0.1675, Train Acc: 96.88%, Val Loss:  1.526, Val Acc: 80.00%, Time: 1.40s
# Iter: 960, Train Loss: 0.2184, Train Acc: 95.31%, Val Loss:  1.584, Val Acc: 80.00%, Time: 6.00s
# Iter: 990, Train Loss: 0.3835, Train Acc: 90.62%, Val Loss:    1.6, Val Acc: 80.84%, Time: 10.51s *
# Epoch: 13
# Iter: 1020, Train Loss: 0.1624, Train Acc: 96.88%, Val Loss:  1.655, Val Acc: 79.66%, Time: 2.17s
# Iter: 1050, Train Loss: 0.2977, Train Acc: 93.75%, Val Loss:  1.656, Val Acc: 79.50%, Time: 6.77s
# Iter: 1080, Train Loss: 0.2143, Train Acc: 95.31%, Val Loss:  1.718, Val Acc: 78.99%, Time: 11.37s
# Epoch: 14
# Iter: 1110, Train Loss: 0.3952, Train Acc: 93.75%, Val Loss:  1.704, Val Acc: 79.33%, Time: 2.97s
# Iter: 1140, Train Loss: 0.1491, Train Acc: 98.44%, Val Loss:  1.769, Val Acc: 78.49%, Time: 7.59s
# Iter: 1170, Train Loss: 0.3383, Train Acc: 92.19%, Val Loss:   1.61, Val Acc: 80.00%, Time: 12.18s
# Epoch: 15
# Iter: 1200, Train Loss: 0.5324, Train Acc: 87.50%, Val Loss:  1.792, Val Acc: 77.65%, Time: 3.83s
# Iter: 1230, Train Loss: 0.1703, Train Acc: 96.88%, Val Loss:  1.855, Val Acc: 79.33%, Time: 8.36s
# Iter: 1260, Train Loss: 0.1961, Train Acc: 95.56%, Val Loss:  1.863, Val Acc: 78.66%, Time: 12.94s
# Epoch: 16
# Iter: 1290, Train Loss: 0.2058, Train Acc: 96.88%, Val Loss:  1.788, Val Acc: 79.83%, Time: 4.55s
# Iter: 1320, Train Loss: 0.1853, Train Acc: 98.44%, Val Loss:  1.952, Val Acc: 76.97%, Time: 9.15s
# Epoch: 17
# Iter: 1350, Train Loss: 0.1728, Train Acc: 96.88%, Val Loss:  1.751, Val Acc: 79.16%, Time: 1.42s
# Iter: 1380, Train Loss: 0.3864, Train Acc: 92.19%, Val Loss:  1.814, Val Acc: 80.50%, Time: 5.92s
# Iter: 1410, Train Loss: 0.3172, Train Acc: 92.19%, Val Loss:  1.978, Val Acc: 79.66%, Time: 10.53s
# Epoch: 18
# Iter: 1440, Train Loss: 0.1292, Train Acc: 96.88%, Val Loss:  1.951, Val Acc: 79.33%, Time: 2.18s
# Iter: 1470, Train Loss: 0.1739, Train Acc: 95.31%, Val Loss:  1.798, Val Acc: 79.50%, Time: 6.71s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.88      0.70      0.78        10
#         DESC       0.84      0.71      0.77       131
#         ENTY       0.71      0.78      0.74       135
#          HUM       0.77      0.79      0.78       129
#          LOC       0.86      0.83      0.84        95
#          NUM       0.86      0.95      0.90        95
#
#    micro avg       0.80      0.80      0.80       595
#    macro avg       0.82      0.79      0.80       595
# weighted avg       0.80      0.80      0.80       595
#
# Confusion Matrix...
# [[  7   1   0   0   2   0]
#  [  1  93  21   7   2   7]
#  [  0   4 105  17   4   5]
#  [  0   6  17 102   3   1]
#  [  0   6   4   4  79   2]
#  [  0   1   0   2   2  90]]
# Fold:  5
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.331, Train Acc: 25.00%, Val Loss:  3.318, Val Acc: 24.20%, Time: 5.63s *
# Iter: 60, Train Loss:  2.731, Train Acc: 48.44%, Val Loss:  2.979, Val Acc: 38.99%, Time: 10.22s *
# Epoch: 2
# Iter: 90, Train Loss:  2.867, Train Acc: 46.88%, Val Loss:  2.668, Val Acc: 46.72%, Time: 1.39s *
# Iter: 120, Train Loss:  2.544, Train Acc: 54.69%, Val Loss:  2.421, Val Acc: 54.96%, Time: 5.89s *
# Iter: 150, Train Loss:  1.976, Train Acc: 60.94%, Val Loss:  2.303, Val Acc: 54.62%, Time: 10.43s
# Epoch: 3
# Iter: 180, Train Loss:   1.74, Train Acc: 65.62%, Val Loss:  1.837, Val Acc: 65.71%, Time: 2.21s *
# Iter: 210, Train Loss:  1.671, Train Acc: 65.62%, Val Loss:  1.713, Val Acc: 68.91%, Time: 6.76s *
# Iter: 240, Train Loss:   1.38, Train Acc: 78.12%, Val Loss:  1.564, Val Acc: 71.60%, Time: 11.37s *
# Epoch: 4
# Iter: 270, Train Loss:  1.149, Train Acc: 82.81%, Val Loss:  1.476, Val Acc: 73.11%, Time: 2.97s *
# Iter: 300, Train Loss: 0.8927, Train Acc: 87.50%, Val Loss:  1.363, Val Acc: 75.29%, Time: 7.60s *
# Iter: 330, Train Loss:  1.221, Train Acc: 73.44%, Val Loss:  1.311, Val Acc: 76.81%, Time: 12.17s *
# Epoch: 5
# Iter: 360, Train Loss: 0.5939, Train Acc: 89.06%, Val Loss:  1.314, Val Acc: 76.97%, Time: 3.78s *
# Iter: 390, Train Loss: 0.8131, Train Acc: 82.81%, Val Loss:  1.281, Val Acc: 77.48%, Time: 8.30s *
# Iter: 420, Train Loss: 0.7353, Train Acc: 84.44%, Val Loss:  1.289, Val Acc: 77.48%, Time: 12.89s *
# Epoch: 6
# Iter: 450, Train Loss:  0.707, Train Acc: 89.06%, Val Loss:  1.276, Val Acc: 78.66%, Time: 4.62s *
# Iter: 480, Train Loss: 0.6657, Train Acc: 87.50%, Val Loss:  1.295, Val Acc: 77.31%, Time: 9.19s
# Epoch: 7
# Iter: 510, Train Loss: 0.5098, Train Acc: 92.19%, Val Loss:  1.272, Val Acc: 76.81%, Time: 1.41s
# Iter: 540, Train Loss: 0.2551, Train Acc: 96.88%, Val Loss:  1.485, Val Acc: 75.97%, Time: 5.99s
# Iter: 570, Train Loss: 0.4696, Train Acc: 89.06%, Val Loss:  1.222, Val Acc: 79.16%, Time: 10.55s *
# Epoch: 8
# Iter: 600, Train Loss: 0.7024, Train Acc: 89.06%, Val Loss:  1.314, Val Acc: 78.15%, Time: 2.21s
# Iter: 630, Train Loss: 0.3085, Train Acc: 96.88%, Val Loss:  1.317, Val Acc: 78.82%, Time: 6.79s
# Iter: 660, Train Loss: 0.3706, Train Acc: 95.31%, Val Loss:  1.345, Val Acc: 77.31%, Time: 11.38s
# Epoch: 9
# Iter: 690, Train Loss: 0.6152, Train Acc: 90.62%, Val Loss:  1.325, Val Acc: 78.49%, Time: 3.00s
# Iter: 720, Train Loss: 0.2464, Train Acc: 95.31%, Val Loss:  1.484, Val Acc: 77.48%, Time: 7.65s
# Iter: 750, Train Loss: 0.7347, Train Acc: 85.94%, Val Loss:  1.385, Val Acc: 77.48%, Time: 12.23s
# Epoch: 10
# Iter: 780, Train Loss: 0.2834, Train Acc: 96.88%, Val Loss:  1.399, Val Acc: 78.99%, Time: 3.82s
# Iter: 810, Train Loss: 0.2495, Train Acc: 96.88%, Val Loss:  1.468, Val Acc: 77.98%, Time: 8.40s
# Iter: 840, Train Loss: 0.4243, Train Acc: 91.11%, Val Loss:  1.431, Val Acc: 77.82%, Time: 13.08s
# Epoch: 11
# Iter: 870, Train Loss: 0.2473, Train Acc: 95.31%, Val Loss:   1.59, Val Acc: 76.97%, Time: 4.57s
# Iter: 900, Train Loss: 0.3592, Train Acc: 92.19%, Val Loss:  1.429, Val Acc: 78.49%, Time: 9.17s
# Epoch: 12
# Iter: 930, Train Loss: 0.09568, Train Acc: 100.00%, Val Loss:  1.582, Val Acc: 79.16%, Time: 1.43s
# Iter: 960, Train Loss: 0.5416, Train Acc: 89.06%, Val Loss:  1.363, Val Acc: 80.00%, Time: 5.96s *
# Iter: 990, Train Loss: 0.1619, Train Acc: 96.88%, Val Loss:  1.548, Val Acc: 77.98%, Time: 10.49s
# Epoch: 13
# Iter: 1020, Train Loss: 0.1764, Train Acc: 96.88%, Val Loss:  1.621, Val Acc: 76.97%, Time: 2.17s
# Iter: 1050, Train Loss: 0.1598, Train Acc: 98.44%, Val Loss:  1.535, Val Acc: 78.32%, Time: 6.72s
# Iter: 1080, Train Loss: 0.1912, Train Acc: 96.88%, Val Loss:  1.684, Val Acc: 78.82%, Time: 11.27s
# Epoch: 14
# Iter: 1110, Train Loss: 0.2921, Train Acc: 93.75%, Val Loss:  1.657, Val Acc: 78.66%, Time: 3.01s
# Iter: 1140, Train Loss: 0.3056, Train Acc: 93.75%, Val Loss:  1.574, Val Acc: 78.99%, Time: 7.61s
# Iter: 1170, Train Loss: 0.2562, Train Acc: 95.31%, Val Loss:  1.679, Val Acc: 78.82%, Time: 12.16s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1144, Train Acc: 98.44%, Val Loss:  1.732, Val Acc: 79.16%, Time: 3.74s
# Iter: 1230, Train Loss: 0.4255, Train Acc: 90.62%, Val Loss:  1.728, Val Acc: 78.15%, Time: 8.44s
# Iter: 1260, Train Loss: 0.2011, Train Acc: 95.56%, Val Loss:  1.574, Val Acc: 79.33%, Time: 13.03s
# Epoch: 16
# Iter: 1290, Train Loss: 0.1119, Train Acc: 98.44%, Val Loss:   1.62, Val Acc: 78.66%, Time: 4.63s
# Iter: 1320, Train Loss: 0.2194, Train Acc: 95.31%, Val Loss:  1.586, Val Acc: 78.99%, Time: 9.20s
# Epoch: 17
# Iter: 1350, Train Loss: 0.1402, Train Acc: 96.88%, Val Loss:  1.757, Val Acc: 79.16%, Time: 1.41s
# Iter: 1380, Train Loss: 0.08387, Train Acc: 98.44%, Val Loss:  1.617, Val Acc: 79.66%, Time: 5.97s
# Iter: 1410, Train Loss: 0.3149, Train Acc: 90.62%, Val Loss:  1.804, Val Acc: 77.65%, Time: 10.54s
# Epoch: 18
# Iter: 1440, Train Loss:  0.173, Train Acc: 95.31%, Val Loss:  1.565, Val Acc: 79.66%, Time: 2.21s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.22      0.36         9
#         DESC       0.74      0.64      0.69       115
#         ENTY       0.74      0.81      0.77       128
#          HUM       0.78      0.91      0.84       129
#          LOC       0.81      0.66      0.73        87
#          NUM       0.83      0.87      0.85       127
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.82      0.68      0.71       595
# weighted avg       0.78      0.78      0.77       595
#
# Confusion Matrix...
# [[  2   3   1   3   0   0]
#  [  0  74  16  12   7   6]
#  [  0   7 104   9   1   7]
#  [  0   0   8 117   1   3]
#  [  0  13   5   6  57   6]
#  [  0   3   7   3   4 110]]
# Fold:  6
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.171, Train Acc: 31.25%, Val Loss:  3.268, Val Acc: 22.02%, Time: 5.58s *
# Iter: 60, Train Loss:  3.085, Train Acc: 35.94%, Val Loss:  3.042, Val Acc: 41.34%, Time: 10.12s *
# Epoch: 2
# Iter: 90, Train Loss:  2.507, Train Acc: 62.50%, Val Loss:  2.623, Val Acc: 55.29%, Time: 1.43s *
# Iter: 120, Train Loss:   2.08, Train Acc: 65.62%, Val Loss:  2.346, Val Acc: 56.81%, Time: 5.99s *
# Iter: 150, Train Loss:  2.069, Train Acc: 64.06%, Val Loss:   2.09, Val Acc: 61.01%, Time: 10.69s *
# Epoch: 3
# Iter: 180, Train Loss:  1.746, Train Acc: 70.31%, Val Loss:  1.808, Val Acc: 66.72%, Time: 2.21s *
# Iter: 210, Train Loss:  1.829, Train Acc: 67.19%, Val Loss:   1.71, Val Acc: 67.90%, Time: 6.76s *
# Iter: 240, Train Loss:  1.208, Train Acc: 76.56%, Val Loss:  1.498, Val Acc: 72.94%, Time: 11.36s *
# Epoch: 4
# Iter: 270, Train Loss:  1.031, Train Acc: 81.25%, Val Loss:  1.414, Val Acc: 74.62%, Time: 2.96s *
# Iter: 300, Train Loss: 0.9337, Train Acc: 84.38%, Val Loss:  1.418, Val Acc: 75.46%, Time: 7.44s *
# Iter: 330, Train Loss:  1.053, Train Acc: 79.69%, Val Loss:  1.414, Val Acc: 75.29%, Time: 11.98s
# Epoch: 5
# Iter: 360, Train Loss: 0.9807, Train Acc: 85.94%, Val Loss:  1.451, Val Acc: 75.29%, Time: 3.81s
# Iter: 390, Train Loss: 0.6862, Train Acc: 89.06%, Val Loss:   1.29, Val Acc: 78.15%, Time: 8.32s *
# Iter: 420, Train Loss: 0.8386, Train Acc: 86.67%, Val Loss:  1.337, Val Acc: 76.97%, Time: 12.86s
# Epoch: 6
# Iter: 450, Train Loss:  0.995, Train Acc: 84.38%, Val Loss:  1.341, Val Acc: 77.82%, Time: 4.58s
# Iter: 480, Train Loss: 0.5688, Train Acc: 90.62%, Val Loss:  1.297, Val Acc: 78.15%, Time: 9.13s
# Epoch: 7
# Iter: 510, Train Loss: 0.7024, Train Acc: 87.50%, Val Loss:  1.326, Val Acc: 77.48%, Time: 1.39s
# Iter: 540, Train Loss: 0.7611, Train Acc: 87.50%, Val Loss:  1.469, Val Acc: 78.15%, Time: 6.26s
# Iter: 570, Train Loss: 0.6488, Train Acc: 90.62%, Val Loss:  1.374, Val Acc: 78.32%, Time: 11.06s *
# Epoch: 8
# Iter: 600, Train Loss: 0.5394, Train Acc: 90.62%, Val Loss:   1.42, Val Acc: 78.49%, Time: 2.31s *
# Iter: 630, Train Loss: 0.1579, Train Acc: 98.44%, Val Loss:  1.617, Val Acc: 76.47%, Time: 7.06s
# Iter: 660, Train Loss: 0.4666, Train Acc: 92.19%, Val Loss:  1.471, Val Acc: 78.66%, Time: 11.79s *
# Epoch: 9
# Iter: 690, Train Loss: 0.2243, Train Acc: 96.88%, Val Loss:  1.504, Val Acc: 78.82%, Time: 3.11s *
# Iter: 720, Train Loss: 0.3743, Train Acc: 92.19%, Val Loss:  1.627, Val Acc: 78.32%, Time: 7.94s
# Iter: 750, Train Loss: 0.2165, Train Acc: 96.88%, Val Loss:  1.573, Val Acc: 78.66%, Time: 12.54s
# Epoch: 10
# Iter: 780, Train Loss: 0.4572, Train Acc: 92.19%, Val Loss:  1.493, Val Acc: 78.82%, Time: 3.76s *
# Iter: 810, Train Loss: 0.2813, Train Acc: 98.44%, Val Loss:  1.759, Val Acc: 77.82%, Time: 8.33s
# Iter: 840, Train Loss:  0.382, Train Acc: 93.33%, Val Loss:  1.699, Val Acc: 77.82%, Time: 12.89s
# Epoch: 11
# Iter: 870, Train Loss: 0.2176, Train Acc: 95.31%, Val Loss:  1.683, Val Acc: 78.32%, Time: 4.51s
# Iter: 900, Train Loss: 0.3039, Train Acc: 95.31%, Val Loss:  1.659, Val Acc: 78.99%, Time: 9.05s *
# Epoch: 12
# Iter: 930, Train Loss: 0.4969, Train Acc: 90.62%, Val Loss:  1.836, Val Acc: 76.97%, Time: 1.42s
# Iter: 960, Train Loss: 0.1681, Train Acc: 96.88%, Val Loss:  1.731, Val Acc: 79.33%, Time: 5.96s *
# Iter: 990, Train Loss: 0.3237, Train Acc: 95.31%, Val Loss:  1.813, Val Acc: 77.65%, Time: 10.53s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2436, Train Acc: 96.88%, Val Loss:  1.836, Val Acc: 78.99%, Time: 2.20s
# Iter: 1050, Train Loss: 0.02129, Train Acc: 100.00%, Val Loss:  1.816, Val Acc: 78.49%, Time: 6.74s
# Iter: 1080, Train Loss: 0.1847, Train Acc: 95.31%, Val Loss:  1.723, Val Acc: 78.49%, Time: 11.30s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1729, Train Acc: 95.31%, Val Loss:  1.838, Val Acc: 78.32%, Time: 2.98s
# Iter: 1140, Train Loss: 0.2007, Train Acc: 93.75%, Val Loss:   1.84, Val Acc: 78.15%, Time: 7.49s
# Iter: 1170, Train Loss: 0.3028, Train Acc: 93.75%, Val Loss:  1.927, Val Acc: 77.82%, Time: 12.00s
# Epoch: 15
# Iter: 1200, Train Loss:  0.134, Train Acc: 98.44%, Val Loss:  1.916, Val Acc: 78.66%, Time: 3.74s
# Iter: 1230, Train Loss: 0.1084, Train Acc: 98.44%, Val Loss:   1.93, Val Acc: 78.82%, Time: 8.30s
# Iter: 1260, Train Loss: 0.02897, Train Acc: 100.00%, Val Loss:  1.982, Val Acc: 79.33%, Time: 12.83s *
# Epoch: 16
# Iter: 1290, Train Loss: 0.08721, Train Acc: 98.44%, Val Loss:  2.001, Val Acc: 79.50%, Time: 4.55s *
# Iter: 1320, Train Loss: 0.1583, Train Acc: 96.88%, Val Loss:  1.997, Val Acc: 78.66%, Time: 9.20s
# Epoch: 17
# Iter: 1350, Train Loss: 0.09885, Train Acc: 96.88%, Val Loss:  2.087, Val Acc: 78.66%, Time: 1.41s
# Iter: 1380, Train Loss:  0.374, Train Acc: 90.62%, Val Loss:  2.013, Val Acc: 79.33%, Time: 5.97s
# Iter: 1410, Train Loss: 0.05967, Train Acc: 98.44%, Val Loss:   2.14, Val Acc: 77.82%, Time: 10.49s
# Epoch: 18
# Iter: 1440, Train Loss: 0.02416, Train Acc: 100.00%, Val Loss:  2.144, Val Acc: 78.15%, Time: 2.22s
# Iter: 1470, Train Loss: 0.1136, Train Acc: 96.88%, Val Loss:  2.137, Val Acc: 79.16%, Time: 6.73s
# Iter: 1500, Train Loss: 0.1046, Train Acc: 98.44%, Val Loss:   2.26, Val Acc: 77.14%, Time: 11.25s
# Epoch: 19
# Iter: 1530, Train Loss: 0.05034, Train Acc: 98.44%, Val Loss:  2.278, Val Acc: 76.64%, Time: 3.01s
# Iter: 1560, Train Loss: 0.3021, Train Acc: 95.31%, Val Loss:   2.16, Val Acc: 78.66%, Time: 7.57s
# Iter: 1590, Train Loss: 0.1786, Train Acc: 96.88%, Val Loss:  2.093, Val Acc: 78.99%, Time: 12.24s
# Epoch: 20
# Iter: 1620, Train Loss: 0.1077, Train Acc: 98.44%, Val Loss:  2.243, Val Acc: 78.99%, Time: 3.88s
# Iter: 1650, Train Loss: 0.09951, Train Acc: 98.44%, Val Loss:  2.125, Val Acc: 78.66%, Time: 8.63s
# Iter: 1680, Train Loss: 0.1478, Train Acc: 100.00%, Val Loss:  2.176, Val Acc: 77.48%, Time: 13.20s
# Epoch: 21
# Iter: 1710, Train Loss: 0.05825, Train Acc: 100.00%, Val Loss:  2.274, Val Acc: 78.32%, Time: 4.72s
# Iter: 1740, Train Loss: 0.07099, Train Acc: 98.44%, Val Loss:  2.059, Val Acc: 78.66%, Time: 9.29s
# Epoch: 22
# Iter: 1770, Train Loss: 0.06792, Train Acc: 98.44%, Val Loss:  2.061, Val Acc: 79.16%, Time: 1.41s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.75      0.86         8
#         DESC       0.80      0.73      0.76       113
#         ENTY       0.66      0.76      0.71       130
#          HUM       0.87      0.77      0.82       153
#          LOC       0.77      0.79      0.78        98
#          NUM       0.84      0.92      0.88        93
#
#    micro avg       0.79      0.79      0.79       595
#    macro avg       0.82      0.79      0.80       595
# weighted avg       0.79      0.79      0.79       595
#
# Confusion Matrix...
# [[  6   1   0   1   0   0]
#  [  0  82  17   6   4   4]
#  [  0   9  99   5  13   4]
#  [  0   4  22 118   5   4]
#  [  0   6   6   5  77   4]
#  [  0   0   5   1   1  86]]
# Fold:  7
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.298, Train Acc: 31.25%, Val Loss:  3.216, Val Acc: 31.43%, Time: 5.55s *
# Iter: 60, Train Loss:  2.963, Train Acc: 31.25%, Val Loss:  3.009, Val Acc: 32.94%, Time: 10.10s *
# Epoch: 2
# Iter: 90, Train Loss:  2.703, Train Acc: 42.19%, Val Loss:  2.606, Val Acc: 53.28%, Time: 1.41s *
# Iter: 120, Train Loss:  2.393, Train Acc: 56.25%, Val Loss:  2.327, Val Acc: 56.97%, Time: 6.03s *
# Iter: 150, Train Loss:  2.174, Train Acc: 65.62%, Val Loss:  2.088, Val Acc: 64.20%, Time: 10.58s *
# Epoch: 3
# Iter: 180, Train Loss:  1.613, Train Acc: 70.31%, Val Loss:  1.931, Val Acc: 63.19%, Time: 2.19s
# Iter: 210, Train Loss:  1.646, Train Acc: 73.44%, Val Loss:  1.683, Val Acc: 68.40%, Time: 6.74s *
# Iter: 240, Train Loss:  1.118, Train Acc: 81.25%, Val Loss:  1.445, Val Acc: 74.12%, Time: 11.28s *
# Epoch: 4
# Iter: 270, Train Loss:  1.134, Train Acc: 76.56%, Val Loss:   1.41, Val Acc: 74.45%, Time: 2.99s *
# Iter: 300, Train Loss:   1.29, Train Acc: 81.25%, Val Loss:  1.316, Val Acc: 75.97%, Time: 7.68s *
# Iter: 330, Train Loss:   1.09, Train Acc: 76.56%, Val Loss:    1.3, Val Acc: 74.96%, Time: 12.21s
# Epoch: 5
# Iter: 360, Train Loss:  1.023, Train Acc: 84.38%, Val Loss:  1.246, Val Acc: 76.81%, Time: 3.78s *
# Iter: 390, Train Loss: 0.6934, Train Acc: 89.06%, Val Loss:  1.265, Val Acc: 77.14%, Time: 8.36s *
# Iter: 420, Train Loss: 0.7987, Train Acc: 84.44%, Val Loss:  1.223, Val Acc: 77.65%, Time: 12.92s *
# Epoch: 6
# Iter: 450, Train Loss: 0.7249, Train Acc: 84.38%, Val Loss:  1.287, Val Acc: 76.47%, Time: 4.62s
# Iter: 480, Train Loss: 0.7895, Train Acc: 90.62%, Val Loss:  1.334, Val Acc: 76.30%, Time: 9.22s
# Epoch: 7
# Iter: 510, Train Loss: 0.5205, Train Acc: 90.62%, Val Loss:  1.226, Val Acc: 78.66%, Time: 1.40s *
# Iter: 540, Train Loss: 0.7193, Train Acc: 87.50%, Val Loss:  1.399, Val Acc: 76.97%, Time: 5.93s
# Iter: 570, Train Loss: 0.4927, Train Acc: 93.75%, Val Loss:  1.254, Val Acc: 78.66%, Time: 10.50s
# Epoch: 8
# Iter: 600, Train Loss: 0.6314, Train Acc: 89.06%, Val Loss:  1.258, Val Acc: 79.33%, Time: 2.20s *
# Iter: 630, Train Loss: 0.5483, Train Acc: 87.50%, Val Loss:  1.258, Val Acc: 78.49%, Time: 6.79s
# Iter: 660, Train Loss: 0.2615, Train Acc: 95.31%, Val Loss:  1.242, Val Acc: 79.66%, Time: 11.35s *
# Epoch: 9
# Iter: 690, Train Loss: 0.2588, Train Acc: 95.31%, Val Loss:  1.226, Val Acc: 79.33%, Time: 3.02s
# Iter: 720, Train Loss: 0.4144, Train Acc: 93.75%, Val Loss:  1.346, Val Acc: 79.16%, Time: 7.58s
# Iter: 750, Train Loss: 0.4119, Train Acc: 92.19%, Val Loss:  1.315, Val Acc: 80.67%, Time: 12.16s *
# Epoch: 10
# Iter: 780, Train Loss: 0.5298, Train Acc: 90.62%, Val Loss:  1.376, Val Acc: 78.32%, Time: 3.77s
# Iter: 810, Train Loss: 0.1638, Train Acc: 96.88%, Val Loss:  1.476, Val Acc: 78.32%, Time: 8.32s
# Iter: 840, Train Loss: 0.5301, Train Acc: 93.33%, Val Loss:  1.336, Val Acc: 78.49%, Time: 12.88s
# Epoch: 11
# Iter: 870, Train Loss: 0.3313, Train Acc: 95.31%, Val Loss:  1.396, Val Acc: 79.33%, Time: 4.62s
# Iter: 900, Train Loss: 0.1945, Train Acc: 95.31%, Val Loss:  1.479, Val Acc: 78.82%, Time: 9.14s
# Epoch: 12
# Iter: 930, Train Loss: 0.2235, Train Acc: 95.31%, Val Loss:  1.414, Val Acc: 79.33%, Time: 1.41s
# Iter: 960, Train Loss: 0.1138, Train Acc: 98.44%, Val Loss:  1.393, Val Acc: 79.33%, Time: 6.04s
# Iter: 990, Train Loss: 0.2858, Train Acc: 95.31%, Val Loss:  1.448, Val Acc: 79.33%, Time: 10.59s
# Epoch: 13
# Iter: 1020, Train Loss: 0.1818, Train Acc: 96.88%, Val Loss:  1.466, Val Acc: 78.99%, Time: 2.23s
# Iter: 1050, Train Loss: 0.4308, Train Acc: 90.62%, Val Loss:  1.543, Val Acc: 79.50%, Time: 6.81s
# Iter: 1080, Train Loss: 0.2741, Train Acc: 95.31%, Val Loss:  1.561, Val Acc: 78.82%, Time: 11.41s
# Epoch: 14
# Iter: 1110, Train Loss: 0.3365, Train Acc: 93.75%, Val Loss:  1.516, Val Acc: 79.33%, Time: 3.02s
# Iter: 1140, Train Loss: 0.2904, Train Acc: 93.75%, Val Loss:  1.564, Val Acc: 78.49%, Time: 7.57s
# Iter: 1170, Train Loss: 0.1824, Train Acc: 96.88%, Val Loss:  1.665, Val Acc: 78.49%, Time: 12.13s
# Epoch: 15
# Iter: 1200, Train Loss: 0.04772, Train Acc: 100.00%, Val Loss:  1.709, Val Acc: 78.66%, Time: 3.79s
# Iter: 1230, Train Loss: 0.1533, Train Acc: 98.44%, Val Loss:  1.651, Val Acc: 78.32%, Time: 8.31s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.62      0.77         8
#         DESC       0.79      0.77      0.78       163
#         ENTY       0.66      0.81      0.73       124
#          HUM       0.83      0.72      0.77       119
#          LOC       0.83      0.72      0.77        88
#          NUM       0.82      0.88      0.85        93
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.82      0.76      0.78       595
# weighted avg       0.79      0.78      0.78       595
#
# Confusion Matrix...
# [[  5   2   1   0   0   0]
#  [  0 126  23   4   6   4]
#  [  0   3 101   9   3   8]
#  [  0   7  22  86   2   2]
#  [  0  17   1   3  63   4]
#  [  0   4   4   1   2  82]]
# Fold:  8
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.266, Train Acc: 43.75%, Val Loss:  3.278, Val Acc: 36.97%, Time: 5.61s *
# Iter: 60, Train Loss:   3.13, Train Acc: 35.94%, Val Loss:  2.997, Val Acc: 47.56%, Time: 10.19s *
# Epoch: 2
# Iter: 90, Train Loss:   2.53, Train Acc: 43.75%, Val Loss:  2.787, Val Acc: 44.20%, Time: 1.40s
# Iter: 120, Train Loss:  2.176, Train Acc: 54.69%, Val Loss:  2.408, Val Acc: 56.30%, Time: 5.97s *
# Iter: 150, Train Loss:   2.46, Train Acc: 48.44%, Val Loss:  2.238, Val Acc: 58.15%, Time: 10.56s *
# Epoch: 3
# Iter: 180, Train Loss:  1.452, Train Acc: 78.12%, Val Loss:  2.025, Val Acc: 65.38%, Time: 2.21s *
# Iter: 210, Train Loss:  1.594, Train Acc: 71.88%, Val Loss:  1.939, Val Acc: 65.21%, Time: 6.84s
# Iter: 240, Train Loss:  1.769, Train Acc: 62.50%, Val Loss:  1.647, Val Acc: 69.92%, Time: 11.43s *
# Epoch: 4
# Iter: 270, Train Loss:  1.251, Train Acc: 78.12%, Val Loss:  1.543, Val Acc: 72.77%, Time: 2.99s *
# Iter: 300, Train Loss:  1.125, Train Acc: 82.81%, Val Loss:  1.606, Val Acc: 70.76%, Time: 7.52s
# Iter: 330, Train Loss:  1.345, Train Acc: 75.00%, Val Loss:  1.488, Val Acc: 74.29%, Time: 12.08s *
# Epoch: 5
# Iter: 360, Train Loss:  1.362, Train Acc: 76.56%, Val Loss:  1.557, Val Acc: 71.93%, Time: 3.79s
# Iter: 390, Train Loss: 0.5986, Train Acc: 93.75%, Val Loss:  1.435, Val Acc: 76.13%, Time: 8.36s *
# Iter: 420, Train Loss: 0.6216, Train Acc: 93.33%, Val Loss:  1.363, Val Acc: 75.63%, Time: 12.93s
# Epoch: 6
# Iter: 450, Train Loss: 0.7476, Train Acc: 87.50%, Val Loss:  1.465, Val Acc: 76.13%, Time: 4.57s
# Iter: 480, Train Loss: 0.8502, Train Acc: 85.94%, Val Loss:  1.492, Val Acc: 72.61%, Time: 9.15s
# Epoch: 7
# Iter: 510, Train Loss:   0.62, Train Acc: 90.62%, Val Loss:  1.398, Val Acc: 75.46%, Time: 1.41s
# Iter: 540, Train Loss: 0.6129, Train Acc: 90.62%, Val Loss:  1.476, Val Acc: 73.61%, Time: 6.02s
# Iter: 570, Train Loss: 0.7601, Train Acc: 89.06%, Val Loss:    1.4, Val Acc: 76.30%, Time: 10.69s *
# Epoch: 8
# Iter: 600, Train Loss: 0.3646, Train Acc: 95.31%, Val Loss:  1.453, Val Acc: 74.29%, Time: 2.20s
# Iter: 630, Train Loss:  0.324, Train Acc: 95.31%, Val Loss:  1.355, Val Acc: 76.47%, Time: 6.76s *
# Iter: 660, Train Loss: 0.3114, Train Acc: 93.75%, Val Loss:  1.456, Val Acc: 76.47%, Time: 11.31s
# Epoch: 9
# Iter: 690, Train Loss: 0.4317, Train Acc: 92.19%, Val Loss:  1.469, Val Acc: 75.29%, Time: 3.01s
# Iter: 720, Train Loss: 0.3592, Train Acc: 92.19%, Val Loss:  1.565, Val Acc: 75.13%, Time: 7.60s
# Iter: 750, Train Loss: 0.2231, Train Acc: 96.88%, Val Loss:  1.425, Val Acc: 77.31%, Time: 12.17s *
# Epoch: 10
# Iter: 780, Train Loss: 0.2275, Train Acc: 96.88%, Val Loss:  1.496, Val Acc: 75.46%, Time: 3.78s
# Iter: 810, Train Loss: 0.4005, Train Acc: 89.06%, Val Loss:  1.439, Val Acc: 78.99%, Time: 8.41s *
# Iter: 840, Train Loss: 0.2141, Train Acc: 95.56%, Val Loss:   1.44, Val Acc: 76.64%, Time: 12.94s
# Epoch: 11
# Iter: 870, Train Loss: 0.4085, Train Acc: 93.75%, Val Loss:  1.619, Val Acc: 76.47%, Time: 4.56s
# Iter: 900, Train Loss: 0.3687, Train Acc: 92.19%, Val Loss:  1.586, Val Acc: 77.14%, Time: 9.13s
# Epoch: 12
# Iter: 930, Train Loss:  0.307, Train Acc: 96.88%, Val Loss:   1.55, Val Acc: 77.48%, Time: 1.42s
# Iter: 960, Train Loss: 0.1074, Train Acc: 100.00%, Val Loss:  1.564, Val Acc: 76.13%, Time: 6.01s
# Iter: 990, Train Loss: 0.3108, Train Acc: 93.75%, Val Loss:  1.647, Val Acc: 77.31%, Time: 10.68s
# Epoch: 13
# Iter: 1020, Train Loss: 0.3424, Train Acc: 93.75%, Val Loss:  1.809, Val Acc: 74.62%, Time: 2.20s
# Iter: 1050, Train Loss: 0.3218, Train Acc: 95.31%, Val Loss:  1.675, Val Acc: 75.13%, Time: 6.83s
# Iter: 1080, Train Loss:  0.158, Train Acc: 96.88%, Val Loss:  1.547, Val Acc: 78.66%, Time: 11.39s
# Epoch: 14
# Iter: 1110, Train Loss: 0.06334, Train Acc: 100.00%, Val Loss:  1.757, Val Acc: 75.97%, Time: 3.02s
# Iter: 1140, Train Loss: 0.09099, Train Acc: 98.44%, Val Loss:  1.695, Val Acc: 76.64%, Time: 7.60s
# Iter: 1170, Train Loss: 0.1382, Train Acc: 98.44%, Val Loss:  1.687, Val Acc: 76.47%, Time: 12.21s
# Epoch: 15
# Iter: 1200, Train Loss: 0.2168, Train Acc: 96.88%, Val Loss:  1.709, Val Acc: 75.29%, Time: 3.82s
# Iter: 1230, Train Loss:   0.15, Train Acc: 96.88%, Val Loss:   1.69, Val Acc: 77.48%, Time: 8.35s
# Iter: 1260, Train Loss: 0.02531, Train Acc: 100.00%, Val Loss:  1.737, Val Acc: 74.79%, Time: 12.98s
# Epoch: 16
# Iter: 1290, Train Loss: 0.1163, Train Acc: 98.44%, Val Loss:  1.801, Val Acc: 77.65%, Time: 4.58s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.78      0.78      0.78         9
#         DESC       0.76      0.72      0.74       138
#         ENTY       0.60      0.88      0.71       126
#          HUM       0.88      0.68      0.77       123
#          LOC       0.84      0.70      0.76        94
#          NUM       0.90      0.82      0.86       105
#
#    micro avg       0.76      0.76      0.76       595
#    macro avg       0.79      0.76      0.77       595
# weighted avg       0.79      0.76      0.76       595
#
# Confusion Matrix...
# [[  7   1   1   0   0   0]
#  [  2  99  28   2   5   2]
#  [  0   6 111   6   1   2]
#  [  0   9  26  84   4   0]
#  [  0  10  12   0  66   6]
#  [  0   6   7   3   3  86]]
# Fold:  9
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.187, Train Acc: 39.06%, Val Loss:  3.262, Val Acc: 27.23%, Time: 5.62s *
# Iter: 60, Train Loss:  2.827, Train Acc: 50.00%, Val Loss:  2.899, Val Acc: 43.36%, Time: 10.22s *
# Epoch: 2
# Iter: 90, Train Loss:  2.511, Train Acc: 53.12%, Val Loss:  2.604, Val Acc: 49.75%, Time: 1.41s *
# Iter: 120, Train Loss:   2.37, Train Acc: 60.94%, Val Loss:  2.357, Val Acc: 53.61%, Time: 5.99s *
# Iter: 150, Train Loss:  2.496, Train Acc: 54.69%, Val Loss:  2.227, Val Acc: 57.65%, Time: 10.56s *
# Epoch: 3
# Iter: 180, Train Loss:  1.581, Train Acc: 70.31%, Val Loss:  1.908, Val Acc: 63.36%, Time: 2.22s *
# Iter: 210, Train Loss:  1.591, Train Acc: 78.12%, Val Loss:  1.736, Val Acc: 68.24%, Time: 6.73s *
# Iter: 240, Train Loss:   1.69, Train Acc: 71.88%, Val Loss:  1.617, Val Acc: 71.09%, Time: 11.31s *
# Epoch: 4
# Iter: 270, Train Loss:  1.029, Train Acc: 84.38%, Val Loss:  1.511, Val Acc: 72.61%, Time: 2.97s *
# Iter: 300, Train Loss:  1.182, Train Acc: 82.81%, Val Loss:  1.497, Val Acc: 73.78%, Time: 7.60s *
# Iter: 330, Train Loss:  1.226, Train Acc: 82.81%, Val Loss:  1.476, Val Acc: 71.60%, Time: 12.19s
# Epoch: 5
# Iter: 360, Train Loss: 0.9362, Train Acc: 85.94%, Val Loss:   1.43, Val Acc: 74.12%, Time: 3.80s *
# Iter: 390, Train Loss:  0.787, Train Acc: 84.38%, Val Loss:  1.459, Val Acc: 73.61%, Time: 8.33s
# Iter: 420, Train Loss:  1.073, Train Acc: 84.44%, Val Loss:  1.363, Val Acc: 75.46%, Time: 12.89s *
# Epoch: 6
# Iter: 450, Train Loss: 0.5321, Train Acc: 92.19%, Val Loss:  1.537, Val Acc: 73.61%, Time: 4.62s
# Iter: 480, Train Loss: 0.7612, Train Acc: 89.06%, Val Loss:   1.43, Val Acc: 76.30%, Time: 9.18s *
# Epoch: 7
# Iter: 510, Train Loss: 0.3569, Train Acc: 93.75%, Val Loss:  1.447, Val Acc: 74.79%, Time: 1.41s
# Iter: 540, Train Loss: 0.9384, Train Acc: 81.25%, Val Loss:  1.484, Val Acc: 76.30%, Time: 5.96s
# Iter: 570, Train Loss: 0.5191, Train Acc: 92.19%, Val Loss:  1.567, Val Acc: 74.29%, Time: 10.52s
# Epoch: 8
# Iter: 600, Train Loss: 0.5749, Train Acc: 89.06%, Val Loss:  1.551, Val Acc: 75.46%, Time: 2.19s
# Iter: 630, Train Loss: 0.4809, Train Acc: 93.75%, Val Loss:  1.634, Val Acc: 76.81%, Time: 6.80s *
# Iter: 660, Train Loss: 0.5398, Train Acc: 92.19%, Val Loss:   1.48, Val Acc: 75.46%, Time: 11.38s
# Epoch: 9
# Iter: 690, Train Loss: 0.2953, Train Acc: 93.75%, Val Loss:  1.589, Val Acc: 76.97%, Time: 3.02s *
# Iter: 720, Train Loss: 0.1678, Train Acc: 98.44%, Val Loss:  1.528, Val Acc: 77.31%, Time: 7.57s *
# Iter: 750, Train Loss: 0.5202, Train Acc: 92.19%, Val Loss:  1.719, Val Acc: 76.47%, Time: 12.16s
# Epoch: 10
# Iter: 780, Train Loss: 0.4807, Train Acc: 93.75%, Val Loss:  1.716, Val Acc: 76.47%, Time: 3.78s
# Iter: 810, Train Loss: 0.3483, Train Acc: 93.75%, Val Loss:   1.78, Val Acc: 76.47%, Time: 8.36s
# Iter: 840, Train Loss:  0.362, Train Acc: 95.56%, Val Loss:  1.686, Val Acc: 75.97%, Time: 12.93s
# Epoch: 11
# Iter: 870, Train Loss: 0.4095, Train Acc: 93.75%, Val Loss:  1.878, Val Acc: 75.46%, Time: 4.54s
# Iter: 900, Train Loss: 0.09349, Train Acc: 98.44%, Val Loss:  1.764, Val Acc: 77.31%, Time: 9.16s
# Epoch: 12
# Iter: 930, Train Loss: 0.4074, Train Acc: 92.19%, Val Loss:  1.798, Val Acc: 75.97%, Time: 1.41s
# Iter: 960, Train Loss: 0.06275, Train Acc: 100.00%, Val Loss:  1.762, Val Acc: 76.13%, Time: 5.97s
# Iter: 990, Train Loss: 0.3655, Train Acc: 95.31%, Val Loss:  2.084, Val Acc: 76.30%, Time: 10.56s
# Epoch: 13
# Iter: 1020, Train Loss: 0.1411, Train Acc: 96.88%, Val Loss:  2.046, Val Acc: 75.13%, Time: 2.22s
# Iter: 1050, Train Loss:  0.192, Train Acc: 96.88%, Val Loss:   2.02, Val Acc: 75.13%, Time: 6.75s
# Iter: 1080, Train Loss: 0.03894, Train Acc: 100.00%, Val Loss:  2.001, Val Acc: 75.97%, Time: 11.33s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1626, Train Acc: 98.44%, Val Loss:  1.886, Val Acc: 76.13%, Time: 2.97s
# Iter: 1140, Train Loss: 0.2771, Train Acc: 95.31%, Val Loss:  2.176, Val Acc: 74.96%, Time: 7.50s
# Iter: 1170, Train Loss:  0.326, Train Acc: 96.88%, Val Loss:   1.98, Val Acc: 75.46%, Time: 12.11s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1311, Train Acc: 98.44%, Val Loss:  2.079, Val Acc: 74.96%, Time: 3.77s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.50      0.60      0.55         5
#         DESC       0.68      0.66      0.67       111
#         ENTY       0.78      0.70      0.74       148
#          HUM       0.74      0.89      0.81       134
#          LOC       0.90      0.76      0.82       103
#          NUM       0.77      0.83      0.80        94
#
#    micro avg       0.76      0.76      0.76       595
#    macro avg       0.73      0.74      0.73       595
# weighted avg       0.77      0.76      0.76       595
#
# Confusion Matrix...
# [[  3   1   0   1   0   0]
#  [  2  73  19   9   2   6]
#  [  1  12 103  20   1  11]
#  [  0   9   2 119   3   1]
#  [  0  10   1   9  78   5]
#  [  0   3   7   3   3  78]]
# Fold:  10
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.281, Train Acc: 32.81%, Val Loss:  3.343, Val Acc: 30.92%, Time: 5.62s *
# Iter: 60, Train Loss:  3.149, Train Acc: 39.06%, Val Loss:  3.082, Val Acc: 41.51%, Time: 10.25s *
# Epoch: 2
# Iter: 90, Train Loss:  2.353, Train Acc: 54.69%, Val Loss:  2.699, Val Acc: 47.39%, Time: 1.41s *
# Iter: 120, Train Loss:  2.057, Train Acc: 64.06%, Val Loss:  2.538, Val Acc: 52.94%, Time: 6.00s *
# Iter: 150, Train Loss:   1.91, Train Acc: 62.50%, Val Loss:  2.278, Val Acc: 56.97%, Time: 10.54s *
# Epoch: 3
# Iter: 180, Train Loss:  1.954, Train Acc: 62.50%, Val Loss:  2.023, Val Acc: 60.67%, Time: 2.19s *
# Iter: 210, Train Loss:  1.947, Train Acc: 59.38%, Val Loss:  2.061, Val Acc: 60.84%, Time: 6.76s *
# Iter: 240, Train Loss:  1.537, Train Acc: 73.44%, Val Loss:  1.803, Val Acc: 65.21%, Time: 11.35s *
# Epoch: 4
# Iter: 270, Train Loss:  1.438, Train Acc: 73.44%, Val Loss:  1.812, Val Acc: 69.24%, Time: 2.99s *
# Iter: 300, Train Loss:  1.134, Train Acc: 79.69%, Val Loss:  1.702, Val Acc: 67.23%, Time: 7.53s
# Iter: 330, Train Loss: 0.8737, Train Acc: 82.81%, Val Loss:  1.592, Val Acc: 70.59%, Time: 12.08s *
# Epoch: 5
# Iter: 360, Train Loss:  0.988, Train Acc: 81.25%, Val Loss:  1.667, Val Acc: 71.93%, Time: 3.76s *
# Iter: 390, Train Loss: 0.9034, Train Acc: 85.94%, Val Loss:  1.553, Val Acc: 72.44%, Time: 8.35s *
# Iter: 420, Train Loss: 0.9522, Train Acc: 82.22%, Val Loss:  1.717, Val Acc: 71.43%, Time: 12.91s
# Epoch: 6
# Iter: 450, Train Loss: 0.5868, Train Acc: 92.19%, Val Loss:  1.585, Val Acc: 74.79%, Time: 4.58s *
# Iter: 480, Train Loss: 0.7953, Train Acc: 84.38%, Val Loss:  1.619, Val Acc: 73.61%, Time: 9.16s
# Epoch: 7
# Iter: 510, Train Loss:  1.014, Train Acc: 87.50%, Val Loss:  1.567, Val Acc: 74.45%, Time: 1.41s
# Iter: 540, Train Loss: 0.3832, Train Acc: 93.75%, Val Loss:  1.736, Val Acc: 72.94%, Time: 5.89s
# Iter: 570, Train Loss: 0.8402, Train Acc: 87.50%, Val Loss:  1.604, Val Acc: 75.29%, Time: 10.47s *
# Epoch: 8
# Iter: 600, Train Loss: 0.5781, Train Acc: 90.62%, Val Loss:  1.868, Val Acc: 75.13%, Time: 2.20s
# Iter: 630, Train Loss: 0.3007, Train Acc: 93.75%, Val Loss:  1.763, Val Acc: 75.46%, Time: 6.75s *
# Iter: 660, Train Loss: 0.3493, Train Acc: 95.31%, Val Loss:  1.609, Val Acc: 76.64%, Time: 11.29s *
# Epoch: 9
# Iter: 690, Train Loss: 0.3926, Train Acc: 93.75%, Val Loss:  1.697, Val Acc: 76.81%, Time: 2.93s *
# Iter: 720, Train Loss: 0.1836, Train Acc: 96.88%, Val Loss:  1.894, Val Acc: 75.29%, Time: 7.51s
# Iter: 750, Train Loss: 0.2092, Train Acc: 95.31%, Val Loss:  1.798, Val Acc: 78.15%, Time: 12.12s *
# Epoch: 10
# Iter: 780, Train Loss: 0.1401, Train Acc: 100.00%, Val Loss:  1.818, Val Acc: 74.45%, Time: 3.85s
# Iter: 810, Train Loss: 0.2669, Train Acc: 95.31%, Val Loss:  1.828, Val Acc: 76.13%, Time: 8.39s
# Iter: 840, Train Loss: 0.3402, Train Acc: 93.33%, Val Loss:  1.693, Val Acc: 76.81%, Time: 12.95s
# Epoch: 11
# Iter: 870, Train Loss: 0.3097, Train Acc: 93.75%, Val Loss:  1.873, Val Acc: 75.97%, Time: 4.61s
# Iter: 900, Train Loss: 0.2435, Train Acc: 95.31%, Val Loss:  1.938, Val Acc: 76.97%, Time: 9.17s
# Epoch: 12
# Iter: 930, Train Loss: 0.07727, Train Acc: 98.44%, Val Loss:   2.17, Val Acc: 75.80%, Time: 1.39s
# Iter: 960, Train Loss:  0.144, Train Acc: 98.44%, Val Loss:  2.022, Val Acc: 77.98%, Time: 5.92s
# Iter: 990, Train Loss: 0.2563, Train Acc: 95.31%, Val Loss:   1.96, Val Acc: 78.49%, Time: 10.49s *
# Epoch: 13
# Iter: 1020, Train Loss: 0.07231, Train Acc: 100.00%, Val Loss:  2.215, Val Acc: 75.63%, Time: 2.19s
# Iter: 1050, Train Loss: 0.1927, Train Acc: 96.88%, Val Loss:  2.032, Val Acc: 75.29%, Time: 6.77s
# Iter: 1080, Train Loss: 0.2833, Train Acc: 96.88%, Val Loss:  1.884, Val Acc: 76.30%, Time: 11.31s
# Epoch: 14
# Iter: 1110, Train Loss: 0.2835, Train Acc: 93.75%, Val Loss:  2.213, Val Acc: 74.29%, Time: 3.07s
# Iter: 1140, Train Loss: 0.04703, Train Acc: 98.44%, Val Loss:  2.153, Val Acc: 75.97%, Time: 7.62s
# Iter: 1170, Train Loss: 0.1439, Train Acc: 98.44%, Val Loss:  2.102, Val Acc: 76.13%, Time: 12.27s
# Epoch: 15
# Iter: 1200, Train Loss: 0.2019, Train Acc: 98.44%, Val Loss:  1.991, Val Acc: 75.46%, Time: 3.79s
# Iter: 1230, Train Loss: 0.3201, Train Acc: 93.75%, Val Loss:  2.217, Val Acc: 75.63%, Time: 8.29s
# Iter: 1260, Train Loss: 0.0749, Train Acc: 97.78%, Val Loss:  2.231, Val Acc: 75.46%, Time: 12.91s
# Epoch: 16
# Iter: 1290, Train Loss: 0.1769, Train Acc: 96.88%, Val Loss:  2.265, Val Acc: 75.63%, Time: 4.58s
# Iter: 1320, Train Loss: 0.07298, Train Acc: 98.44%, Val Loss:  1.991, Val Acc: 76.13%, Time: 9.12s
# Epoch: 17
# Iter: 1350, Train Loss: 0.1026, Train Acc: 98.44%, Val Loss:  2.128, Val Acc: 74.96%, Time: 1.42s
# Iter: 1380, Train Loss: 0.2354, Train Acc: 95.31%, Val Loss:   2.31, Val Acc: 76.47%, Time: 5.95s
# Iter: 1410, Train Loss: 0.09578, Train Acc: 98.44%, Val Loss:  2.372, Val Acc: 76.13%, Time: 10.47s
# Epoch: 18
# Iter: 1440, Train Loss: 0.2568, Train Acc: 95.31%, Val Loss:  2.511, Val Acc: 75.46%, Time: 2.16s
# Iter: 1470, Train Loss: 0.1505, Train Acc: 96.88%, Val Loss:  2.415, Val Acc: 75.80%, Time: 6.67s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.70      0.64      0.67        11
#         DESC       0.64      0.70      0.67       123
#         ENTY       0.71      0.73      0.72       145
#          HUM       0.87      0.81      0.84       129
#          LOC       0.82      0.78      0.80        94
#          NUM       0.85      0.85      0.85        93
#
#    micro avg       0.76      0.76      0.76       595
#    macro avg       0.76      0.75      0.76       595
# weighted avg       0.77      0.76      0.77       595
#
# Confusion Matrix...
# [[  7   3   1   0   0   0]
#  [  1  86  18   6   6   6]
#  [  0  21 106   7   5   6]
#  [  1   3  17 104   4   0]
#  [  0  14   5   0  73   2]
#  [  1   7   2   3   1  79]]
# [0.7919463087248322, 0.7936241610738255, 0.7848739495798319, 0.8, 0.7798319327731092, 0.7865546218487395, 0.7781512605042017, 0.761344537815126, 0.7630252100840336, 0.7647058823529411]
# 0.780405786475664, 0.012910963416815802, 0.013609350394749272, 0.00016669297635035595
# [0.7919463087248322,
#  0.7936241610738255,
#  0.7848739495798319,
#  0.8,
#  0.7798319327731092,
#  0.7865546218487395,
#  0.7781512605042017,
#  0.761344537815126,
#  0.7630252100840336,
#  0.7647058823529411]
