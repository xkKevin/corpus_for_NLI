# %%
import numpy as np
import tensorflow as tf
import sys
import time
from datetime import timedelta
import tensorflow.contrib.keras as kr
from sklearn import metrics
from sklearn.model_selection import KFold

import moxing as mox
mox.file.shift('os', 'mox')
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2

# %%
trainDataPath = "s3://corpus-text-classification1/data/train_5500.label.txt"
testDataPath = "s3://corpus-text-classification1/data/TREC_10.label.txt"
vocabPath = "s3://corpus-text-classification1/data/glove.6B.100d.txt"

# %%
def readfile(filePath):
    """读取文件内容，返回文本和标签列表"""
    train_data = []
    with open(filePath, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f.readlines():
            word = line.strip().split()
            label = word[0].split(":")[0]
            content = word[1:]
            train_data.append([content,label])
    
    np.random.shuffle(train_data)
    return np.asarray(train_data)


def loadGloVe(filename):
    vocab = []
    embd = []
    print('Loading GloVe!')
    # vocab.append('unk') #装载不认识的词
    # embd.append([0] * emb_size) #这个emb_size可能需要指定
    file = open(filename,'r',encoding='utf-8')
    for line in file.readlines():
        row = line.strip().split(' ')
        vocab.append(row[0])
        embd.append([float(ei) for ei in row[1:]])
    file.close()
    print('Completed!')
    return vocab,embd


def process_file(contents, labels, word_to_id, cat_to_id, num_classes, pad_max_length):
    """
    将文件转换为id表示,并且将每个单独的样本长度固定为pad_max_lengtn
    """
    # contents, labels = readfile(filePath)
    data_id, label_id = [], []
    # 将文本内容转换为对应的id形式
    for i in range(len(contents)):
        data_id.append([word_to_id[x] for x in contents[i] if x in word_to_id])
        label_id.append(cat_to_id[labels[i]])
    # 使用keras提供的pad_sequences来将文本pad为固定长度
    x_pad = kr.preprocessing.sequence.pad_sequences(data_id, pad_max_length)
    ''' https://blog.csdn.net/TH_NUM/article/details/80904900
    pad_sequences(sequences, maxlen=None, dtype=’int32’, padding=’pre’, truncating=’pre’, value=0.) 
        sequences：浮点数或整数构成的两层嵌套列表
        maxlen：None或整数，为序列的最大长度。大于此长度的序列将被截短，小于此长度的序列将在后部填0.
        dtype：返回的numpy array的数据类型
        padding：‘pre’或‘post’，确定当需要补0时，在序列的起始还是结尾补
        truncating：‘pre’或‘post’，确定当需要截断序列时，从起始还是结尾截断
        value：浮点数，此值将在填充时代替默认的填充值0
    '''
    y_pad = kr.utils.to_categorical(label_id, num_classes=num_classes)  # 将标签转换为one-hot表示
    ''' https://blog.csdn.net/nima1994/article/details/82468965
    to_categorical(y, num_classes=None, dtype='float32')
        将整型标签转为onehot。y为int数组，num_classes为标签类别总数，大于max(y)（标签从0开始的）。
        返回：如果num_classes=None，返回len(y) * [max(y)+1]（维度，m*n表示m行n列矩阵，下同），否则为len(y) * num_classes。
    '''
    return x_pad, y_pad

# %%
categories = ['ABBR', 'DESC', 'ENTY', 'HUM', 'LOC', 'NUM']
num_classes = len(categories)

cat_to_id = {'ABBR': 0, 'DESC': 1, 'ENTY': 2, 'HUM': 3, 'LOC': 4, 'NUM': 5}

vocab, embd = loadGloVe(vocabPath)
vocab_size = len(vocab)
embedding_dim = len(embd[0])
embedding = np.asarray(embd)
word_to_id = dict(zip(vocab, range(vocab_size)))

print(len(embedding),embedding_dim,vocab_size)

testData = readfile(testDataPath)
trainData = readfile(trainDataPath)

print(len(testData),len(trainData))
trainData = np.r_[trainData,testData]
np.random.shuffle(trainData)
len(trainData)

seq_length = 37
# Out:
# Loading GloVe!
# Completed!
# 400000 100 400000
# 500 5452

# %% [raw]
# def train_10_fold(train_data, categories):
#
#     tx, ty = process_file(train_data[:,0], train_data[:,1], word_to_id, cat_to_id, num_classes, seq_length)
#     print(len(tx),len(tx[0]),len(tx[1]))
#
#     fold_id = 0
#     test_acc = []
#
#     kf = KFold(n_splits=10)
#     for train_i, test_i in kf.split(tx):
#         fold_id += 1
#         print("Fold: ", fold_id)
#         test_acc.append(classifier.train(
#             X_train=tx[train_i],
#             y_train=ty[train_i],
#             X_eval=tx[test_i],
#             y_eval=ty[test_i],
#             categories=categories,
#             epochs=30
#         ))
#     print(test_acc)
#     print("%s, %s, %s, %s" % (np.mean(test_acc),np.std(test_acc),np.std(test_acc,ddof=1),np.var(test_acc)))
#     return test_acc

# %%
def train_split_data(model, train_data, categories):
    test_acc = []
    fold_id = 0

    tx, ty = process_file(train_data[:,0], train_data[:,1], word_to_id, cat_to_id, num_classes, seq_length)
    print(len(tx),len(tx[0]),len(tx[1]))

    kf = KFold(n_splits=10)
    for train_i, test_i in kf.split(tx):
        fold_id += 1
        print("Fold: ", fold_id)
        test_acc.append(model_train(model,tx[train_i], ty[train_i],tx[test_i], ty[test_i],categories))
        
    print(test_acc)
    print("%s, %s, %s, %s" % (np.mean(test_acc),np.std(test_acc),np.std(test_acc,ddof=1),np.var(test_acc)))
    return test_acc


def batch_iter(x_pad, y_pad, batch_size):
    """生成批次数据"""
    data_len = len(x_pad)
    num_batch = int((data_len - 1) / batch_size) + 1
    # np.arange()生成0到data_len的等差数列，默认等差为1；np.random.permutation()打乱生成的等差序列的顺序
    # 下面三句语句是为了将训练或测试文本的顺序打乱，因为原文本中每个分类的样本全部挨在一起，这样每个batch训练的都是同一个分类，不太好，打乱后每个batch可包含不同分类
    indices = np.random.permutation(np.arange(data_len))
    x_shuffle = x_pad[indices]
    y_shuffle = y_pad[indices]

    # 返回所有batch的数据
    for i in range(num_batch):
        start_id = i * batch_size
        end_id = min((i + 1) * batch_size, data_len)
        yield x_shuffle[start_id:end_id], y_shuffle[start_id:end_id]
        
        
def evaluate(sess, model, x_pad, y_pad, loss1, acc1, batch_size):
    """评估在某一数据上的准确率和损失"""
    data_len = len(x_pad)
    batch_eval = batch_iter(x_pad, y_pad, batch_size)  # 128
    total_loss = 0.0
    total_acc = 0.0
    for x_batch1, y_batch1 in batch_eval:
        batch_len = len(x_batch1)
        feed_dict1 = {model.inputX: x_batch1, model.inputY: y_batch1, model.dropoutKeepProb: 1.0}
        lossTmp, accTmp = sess.run([loss1, acc1], feed_dict=feed_dict1)
        total_loss += lossTmp * batch_len
        total_acc += accTmp * batch_len

    return total_loss / data_len, total_acc / data_len


def model_train(model, x_train, y_train, x_val, y_val, categories):
    
    # save_path = "%s/%s/%s/%s" % (savePath, split_type, fold_id, fold_id)
    # 创建session
    session = tf.Session()
    session.run(tf.global_variables_initializer())

    print('Training and evaluating...')
    
    total_batch = 0  # 总批次
    best_acc_train = 0.0  # 最佳验证集准确率
    last_improved = 0  # 记录上一次提升批次
    require_improvement = 500  # 如果超过1000轮未提升，提前结束训练
    flag = False

    for epoch in range(num_epochs):  # 20
        start_time = time.time()
        
        print('Epoch:', epoch + 1)
        batch_train = batch_iter(x_train, y_train, batch_size)
        for x_batch, y_batch in batch_train:
            feed_dict = {model.inputX: x_batch, model.inputY: y_batch, model.dropoutKeepProb: dropout_keep_prob}
            session.run(model.trainOp, feed_dict=feed_dict)  # 运行优化
            total_batch += 1

            if total_batch % print_per_batch == 0:
                # 每多少轮次输出在训练集和验证集上的性能
                feed_dict[model.dropoutKeepProb] = 1.0
                loss_train, acc_train = session.run([model.loss, model.acc], feed_dict=feed_dict)
                loss_val, acc_val = evaluate(session, model, x_val, y_val, model.loss, model.acc, 64)
                if acc_val > best_acc_train:
                    # 保存最好结果
                    best_acc_train = acc_val
                    last_improved = total_batch
                    # saver.save(sess=session, save_path=save_path)
                    improved_str = '*'
                else:
                    improved_str = ''
                
                duration = time.time() - start_time
                output = 'Iter: {:>1}, Train Loss: {:>6.4}, Train Acc: {:>6.2%}, Val Loss: {:>6.4}, Val Acc: {:>6.2%}, Time: {:.2f}s {}'
                print(output.format(total_batch, loss_train, acc_train, loss_val, acc_val, duration, improved_str))

            if total_batch - last_improved > require_improvement:
                # 验证集正确率长期不提升，提前结束训练
                print("No optimization for a long time, auto-stopping...")
                
                test_data_len = len(x_val)
                test_num_batch = int((test_data_len - 1) / batch_size) + 1

                y_test_cls = np.argmax(y_val, 1)  # 获得类别
                y_test_pred_cls = np.zeros(shape=len(x_val), dtype=np.int32)  # 保存预测结果  len(x_test) 表示有多少个文本

                for i in range(test_num_batch):  # 逐批次处理
                    start_id = i * batch_size
                    end_id = min((i + 1) * batch_size, test_data_len)
                    feed_dict = {
                        model.inputX: x_val[start_id:end_id],
                        model.dropoutKeepProb: 1.0
                    }
                    y_test_pred_cls[start_id:end_id] = session.run(model.y_pred_cls, feed_dict=feed_dict)

                accuracy_score = metrics.accuracy_score(y_test_cls, y_test_pred_cls)
                # 评估
                print("Precision, Recall and F1-Score...")
                print(metrics.classification_report(y_test_cls, y_test_pred_cls, target_names=categories))
                '''
                sklearn中的classification_report函数用于显示主要分类指标的文本报告．在报告中显示每个类的精确度，召回率，F1值等信息。
                    y_true：1维数组，或标签指示器数组/稀疏矩阵，目标值。 
                    y_pred：1维数组，或标签指示器数组/稀疏矩阵，分类器返回的估计值。 
                    labels：array，shape = [n_labels]，报表中包含的标签索引的可选列表。 
                    target_names：字符串列表，与标签匹配的可选显示名称（相同顺序）。 
                    原文链接：https://blog.csdn.net/akadiao/article/details/78788864
                '''

                # 混淆矩阵
                print("Confusion Matrix...")
                cm = metrics.confusion_matrix(y_test_cls, y_test_pred_cls)
                '''
                混淆矩阵是机器学习中总结分类模型预测结果的情形分析表，以矩阵形式将数据集中的记录按照真实的类别与分类模型作出的分类判断两个标准进行汇总。
                这个名字来源于它可以非常容易的表明多个类别是否有混淆（也就是一个class被预测成另一个class）
                https://blog.csdn.net/u011734144/article/details/80277225
                '''
                print(cm)
                
                flag = True
                break  # 跳出循环
        if flag:  # 同上
            break

    session.close()
    return accuracy_score

# %%
# 构建adversarailLSTM模型
class AdversarailLSTM(object):

    def __init__(self, wordEmbedding):
        # 定义输入
        self.inputX = tf.placeholder(tf.int32, [None, seq_length], name='inputX')
        self.inputY = tf.placeholder(tf.int32, [None, num_classes], name='inputY')

        self.dropoutKeepProb = tf.placeholder(tf.float64, name='keep_prob')

        # 词嵌入层
        with tf.name_scope("wordEmbedding"):
            wordEmbedding = tf.Variable(initial_value=wordEmbedding)
            self.embeddedWords = tf.nn.embedding_lookup(wordEmbedding, self.inputX)

        # 计算softmax交叉熵损失
        with tf.name_scope("loss"):
            with tf.variable_scope("Bi-LSTM", reuse=None):
                self.predictions = self._Bi_LSTMAttention(self.embeddedWords)
                # self.y_pred_cls = tf.cast(tf.greater_equal(self.predictions, 0.5), tf.float32, name="binaryPreds")
                self.y_pred_cls = tf.argmax(tf.nn.softmax(self.predictions),1)  # 预测类别 tf.argmax：返回每一行或每一列的最大值 1为里面（每一行），0为外面（每一列）
                # losses = tf.nn.sigmoid_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
                losses = tf.nn.softmax_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
                loss = tf.reduce_mean(losses)

        
        with tf.name_scope("perturloss"):
            with tf.variable_scope("Bi-LSTM", reuse=True):
                perturWordEmbedding = self._addPerturbation(self.embeddedWords, loss)
                print("perturbSize:{}".format(perturWordEmbedding))
                perturPredictions = self._Bi_LSTMAttention(perturWordEmbedding)
                # perturLosses = tf.nn.sigmoid_cross_entropy_with_logits(logits=perturPredictions, labels=self.inputY)
                perturLosses = tf.nn.softmax_cross_entropy_with_logits(logits=perturPredictions, labels=self.inputY)
                perturLoss = tf.reduce_mean(perturLosses)

        self.loss = loss + perturLoss
        
        globalStep = tf.Variable(0, name="globalStep", trainable=False)
        # 定义优化函数，传入学习速率参数
        optimizer = tf.train.AdamOptimizer(learning_rate)
        # 计算梯度,得到梯度和变量
        gradsAndVars = optimizer.compute_gradients(self.loss)
        # 将梯度应用到变量下，生成训练器
        self.trainOp = optimizer.apply_gradients(gradsAndVars, global_step=globalStep)

        # 准确率
        correct_pred = tf.equal(tf.argmax(self.inputY, 1), self.y_pred_cls)
        self.acc = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
        
        # self.loss = loss
        
        
    def _Bi_LSTMAttention(self, embeddedWords):
        # 定义两层双向LSTM的模型结构
        with tf.name_scope("Bi-LSTM"):
            fwHiddenLayers = []
            bwHiddenLayers = []
            for idx, hiddenSize in enumerate(hiddenSizes):
                with tf.name_scope("Bi-LSTM" + str(idx)):
                    # 定义前向网络结构
                    lstmFwCell = tf.nn.rnn_cell.DropoutWrapper(
                        tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                        output_keep_prob=self.dropoutKeepProb)

                    # 定义反向网络结构
                    lstmBwCell = tf.nn.rnn_cell.DropoutWrapper(
                        tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                        output_keep_prob=self.dropoutKeepProb)

                fwHiddenLayers.append(lstmFwCell)
                bwHiddenLayers.append(lstmBwCell)

            # 实现多层的LSTM结构， state_is_tuple=True，则状态会以元祖的形式组合(h, c)，否则列向拼接
            fwMultiLstm = tf.nn.rnn_cell.MultiRNNCell(cells=fwHiddenLayers, state_is_tuple=True)
            bwMultiLstm = tf.nn.rnn_cell.MultiRNNCell(cells=bwHiddenLayers, state_is_tuple=True)
            # 采用动态rnn，可以动态地输入序列的长度，若没有输入，则取序列的全长
            # outputs是一个元组(output_fw, output_bw), 其中两个元素的维度都是[batch_size, max_time, hidden_size], fw和bw的hiddensize一样
            # self.current_state是最终的状态，二元组(state_fw, state_bw), state_fw=[batch_size, s], s是一个元组(h, c)
            outputs, self.current_state = tf.nn.bidirectional_dynamic_rnn(fwMultiLstm, bwMultiLstm,
                                                                          self.embeddedWords, dtype=tf.float64,
                                                                          scope="bi-lstm" + str(idx))

        # 在bi-lstm+attention论文中，将前向和后向的输出相加
        with tf.name_scope("Attention"):
            H = outputs[0] + outputs[1]

            # 得到attention的输出
            output = self.attention(H)
            outputSize = hiddenSizes[-1]
            print("outputSize:{}".format(outputSize))

        # 全连接层的输出
        with tf.name_scope("output"):
            outputW = tf.get_variable(
                "outputW", dtype=tf.float64,
                shape=[outputSize, num_classes],
                initializer=tf.contrib.layers.xavier_initializer())

            outputB = tf.Variable(tf.constant(0.1, dtype=tf.float64, shape=[num_classes]), name="outputB")

            predictions = tf.nn.xw_plus_b(output, outputW, outputB, name="predictions")

            return predictions

    def attention(self, H):
        """
        利用Attention机制得到句子的向量表示
        """
        # 获得最后一层lstm神经元的数量
        hiddenSize = hiddenSizes[-1]

        # 初始化一个权重向量，是可训练的参数
        W = tf.Variable(tf.random_normal([hiddenSize], stddev=0.1, dtype=tf.float64))

        # 对bi-lstm的输出用激活函数做非线性转换
        M = tf.tanh(H)

        # 对W和M做矩阵运算，W=[batch_size, time_step, hidden_size], 计算前做维度转换成[batch_size * time_step, hidden_size]
        # newM = [batch_size, time_step, 1], 每一个时间步的输出由向量转换成一个数字
        newM = tf.matmul(tf.reshape(M, [-1, hiddenSize]), tf.reshape(W, [-1, 1]))

        # 对newM做维度转换成[batch_size, time_step]
        restoreM = tf.reshape(newM, [-1, seq_length])

        # 用softmax做归一化处理[batch_size, time_step]
        self.alpha = tf.nn.softmax(restoreM)

        # 利用求得的alpha的值对H进行加权求和，用矩阵运算直接操作
        r = tf.matmul(tf.transpose(H, [0, 2, 1]), tf.reshape(self.alpha, [-1, seq_length, 1]))

        # 将三维压缩成二维sequeezeR = [batch_size, hissen_size]
        sequeezeR = tf.squeeze(r)

        sentenceRepren = tf.tanh(sequeezeR)

        # 对attention的输出可以做dropout处理
        output = tf.nn.dropout(sentenceRepren, self.dropoutKeepProb)

        return output

    def _normalize(self, wordEmbedding, weights):
        """
        对word embedding 结合权重做标准化处理
        """
        mean = tf.matmul(weights, wordEmbedding)
        powWordEmbedding = tf.pow(wordEmbedding - mean, 2.)

        var = tf.matmul(weights, powWordEmbedding)
        stddev = tf.sqrt(1e-6 + var)

        return (wordEmbedding - mean) / stddev

    def _addPerturbation(self, embedded, loss):
        """
        添加波动到word embedding
        """
        grad, = tf.gradients(
            loss,
            embedded,
            aggregation_method=tf.AggregationMethod.EXPERIMENTAL_ACCUMULATE_N)
        grad = tf.stop_gradient(grad)
        perturb = self._scaleL2(grad, epsilon)
        # print("perturbSize:{}".format(embedded+perturb))
        return embedded + perturb

    def _scaleL2(self, x, norm_length):
        # shape(x) = [batch, num_step, d]
        # divide x by max(abs(x)) for a numerically stable L2 norm
        # 2norm(x) = a * 2norm(x/a)
        # scale over the full sequence, dim(1, 2)
        alpha = tf.reduce_max(tf.abs(x), (1, 2), keep_dims=True) + 1e-12
        l2_norm = alpha * tf.sqrt(tf.reduce_sum(tf.pow(x / alpha, 2), (1, 2), keep_dims=True) + 1e-6)
        x_unit = x / l2_norm
        return norm_length * x_unit

# %%
hiddenSizes = [128]  # 定义LSTM的隐藏层（一层，128个神经元）
epsilon = 5

num_filters = 256
kernel_size = 5
hidden_dim = 128
learning_rate = 1e-3
dropout_keep_prob = 0.5

num_epochs = 50
batch_size = 64
print_per_batch = 30  # 每多少轮输出一次结果

lstm = AdversarailLSTM(embedding)
# Out:
# outputSize:128
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:171: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:171: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:172: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:172: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# perturbSize:Tensor("perturloss/Bi-LSTM/add_2:0", shape=(?, 37, 100), dtype=float64)
# outputSize:128

# %%
train_split_data(lstm,trainData,categories)
# Out:
# 5952 37 37
# Fold:  1
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.316, Train Acc: 25.00%, Val Loss:  3.267, Val Acc: 22.82%, Time: 7.88s *
# Iter: 60, Train Loss:  3.102, Train Acc: 35.94%, Val Loss:  3.034, Val Acc: 33.39%, Time: 12.70s *
# Epoch: 2
# Iter: 90, Train Loss:  2.452, Train Acc: 54.69%, Val Loss:  2.587, Val Acc: 52.52%, Time: 1.53s *
# Iter: 120, Train Loss:  2.107, Train Acc: 60.94%, Val Loss:  2.351, Val Acc: 54.53%, Time: 6.32s *
# Iter: 150, Train Loss:  2.107, Train Acc: 64.06%, Val Loss:  2.028, Val Acc: 60.91%, Time: 11.14s *
# Epoch: 3
# Iter: 180, Train Loss:  1.632, Train Acc: 75.00%, Val Loss:  1.851, Val Acc: 64.26%, Time: 2.34s *
# Iter: 210, Train Loss:  1.347, Train Acc: 78.12%, Val Loss:  1.602, Val Acc: 70.13%, Time: 7.19s *
# Iter: 240, Train Loss:  1.387, Train Acc: 75.00%, Val Loss:  1.458, Val Acc: 74.83%, Time: 12.04s *
# Epoch: 4
# Iter: 270, Train Loss:  1.132, Train Acc: 76.56%, Val Loss:  1.347, Val Acc: 75.17%, Time: 3.14s *
# Iter: 300, Train Loss: 0.9648, Train Acc: 81.25%, Val Loss:  1.321, Val Acc: 76.51%, Time: 7.97s *
# Iter: 330, Train Loss:  1.251, Train Acc: 81.25%, Val Loss:  1.278, Val Acc: 77.35%, Time: 12.78s *
# Epoch: 5
# Iter: 360, Train Loss: 0.6563, Train Acc: 90.62%, Val Loss:  1.245, Val Acc: 76.34%, Time: 3.97s
# Iter: 390, Train Loss: 0.6818, Train Acc: 92.19%, Val Loss:  1.344, Val Acc: 76.85%, Time: 8.76s
# Iter: 420, Train Loss: 0.6261, Train Acc: 88.64%, Val Loss:  1.225, Val Acc: 78.52%, Time: 13.60s *
# Epoch: 6
# Iter: 450, Train Loss: 0.7992, Train Acc: 89.06%, Val Loss:  1.385, Val Acc: 76.51%, Time: 4.82s
# Iter: 480, Train Loss:  0.424, Train Acc: 93.75%, Val Loss:  1.331, Val Acc: 77.35%, Time: 9.70s
# Epoch: 7
# Iter: 510, Train Loss: 0.4723, Train Acc: 93.75%, Val Loss:   1.25, Val Acc: 78.69%, Time: 1.47s *
# Iter: 540, Train Loss: 0.3773, Train Acc: 96.88%, Val Loss:  1.227, Val Acc: 77.85%, Time: 6.24s
# Iter: 570, Train Loss: 0.8058, Train Acc: 87.50%, Val Loss:  1.367, Val Acc: 78.02%, Time: 11.21s
# Epoch: 8
# Iter: 600, Train Loss: 0.4028, Train Acc: 95.31%, Val Loss:  1.439, Val Acc: 77.35%, Time: 2.37s
# Iter: 630, Train Loss: 0.4558, Train Acc: 90.62%, Val Loss:  1.324, Val Acc: 79.70%, Time: 7.21s *
# Iter: 660, Train Loss: 0.4137, Train Acc: 93.75%, Val Loss:  1.303, Val Acc: 79.36%, Time: 12.07s
# Epoch: 9
# Iter: 690, Train Loss: 0.5096, Train Acc: 90.62%, Val Loss:  1.342, Val Acc: 78.69%, Time: 3.17s
# Iter: 720, Train Loss: 0.2417, Train Acc: 96.88%, Val Loss:  1.325, Val Acc: 79.03%, Time: 8.05s
# Iter: 750, Train Loss: 0.2943, Train Acc: 95.31%, Val Loss:  1.377, Val Acc: 79.19%, Time: 12.90s
# Epoch: 10
# Iter: 780, Train Loss: 0.1827, Train Acc: 96.88%, Val Loss:  1.482, Val Acc: 77.68%, Time: 3.99s
# Iter: 810, Train Loss: 0.2332, Train Acc: 96.88%, Val Loss:  1.466, Val Acc: 79.36%, Time: 8.79s
# Iter: 840, Train Loss: 0.1515, Train Acc: 95.45%, Val Loss:  1.497, Val Acc: 80.20%, Time: 13.61s *
# Epoch: 11
# Iter: 870, Train Loss: 0.1258, Train Acc: 98.44%, Val Loss:  1.588, Val Acc: 78.36%, Time: 4.76s
# Iter: 900, Train Loss: 0.2226, Train Acc: 95.31%, Val Loss:  1.636, Val Acc: 78.19%, Time: 9.52s
# Epoch: 12
# Iter: 930, Train Loss:  0.201, Train Acc: 98.44%, Val Loss:  1.532, Val Acc: 79.03%, Time: 1.48s
# Iter: 960, Train Loss: 0.1905, Train Acc: 95.31%, Val Loss:  1.681, Val Acc: 78.69%, Time: 6.39s
# Iter: 990, Train Loss: 0.3385, Train Acc: 95.31%, Val Loss:  1.644, Val Acc: 78.19%, Time: 11.22s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2928, Train Acc: 93.75%, Val Loss:  1.688, Val Acc: 78.19%, Time: 2.33s
# Iter: 1050, Train Loss: 0.1121, Train Acc: 98.44%, Val Loss:  1.649, Val Acc: 79.70%, Time: 7.22s
# Iter: 1080, Train Loss: 0.2323, Train Acc: 95.31%, Val Loss:  1.687, Val Acc: 79.19%, Time: 12.02s
# Epoch: 14
# Iter: 1110, Train Loss: 0.2166, Train Acc: 95.31%, Val Loss:  1.576, Val Acc: 78.69%, Time: 3.15s
# Iter: 1140, Train Loss: 0.2632, Train Acc: 93.75%, Val Loss:  1.702, Val Acc: 79.36%, Time: 8.01s
# Iter: 1170, Train Loss: 0.3278, Train Acc: 95.31%, Val Loss:  2.058, Val Acc: 77.01%, Time: 12.79s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1597, Train Acc: 98.44%, Val Loss:  1.812, Val Acc: 78.36%, Time: 4.00s
# Iter: 1230, Train Loss: 0.2244, Train Acc: 93.75%, Val Loss:  1.922, Val Acc: 78.19%, Time: 8.79s
# Iter: 1260, Train Loss: 0.02385, Train Acc: 100.00%, Val Loss:  1.918, Val Acc: 77.68%, Time: 13.62s
# Epoch: 16
# Iter: 1290, Train Loss: 0.06657, Train Acc: 98.44%, Val Loss:  1.929, Val Acc: 79.19%, Time: 4.85s
# Iter: 1320, Train Loss: 0.2789, Train Acc: 95.31%, Val Loss:   2.01, Val Acc: 78.69%, Time: 9.70s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.67      0.80         6
#         DESC       0.73      0.78      0.75       122
#         ENTY       0.73      0.74      0.74       136
#          HUM       0.83      0.81      0.82       128
#          LOC       0.84      0.74      0.79        95
#          NUM       0.85      0.90      0.88       109
#
#    micro avg       0.79      0.79      0.79       596
#    macro avg       0.83      0.77      0.80       596
# weighted avg       0.79      0.79      0.79       596
#
# Confusion Matrix...
# [[  4   2   0   0   0   0]
#  [  0  95  15   3   6   3]
#  [  0  14 101  11   2   8]
#  [  0   4  15 104   4   1]
#  [  0  13   3   4  70   5]
#  [  0   3   4   3   1  98]]
# Fold:  2
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.116, Train Acc: 32.81%, Val Loss:   3.24, Val Acc: 31.04%, Time: 5.96s *
# Iter: 60, Train Loss:  2.975, Train Acc: 39.06%, Val Loss:  3.006, Val Acc: 39.60%, Time: 10.80s *
# Epoch: 2
# Iter: 90, Train Loss:  2.662, Train Acc: 53.12%, Val Loss:  2.667, Val Acc: 50.34%, Time: 1.50s *
# Iter: 120, Train Loss:  2.022, Train Acc: 65.62%, Val Loss:  2.381, Val Acc: 54.03%, Time: 6.39s *
# Iter: 150, Train Loss:  1.616, Train Acc: 78.12%, Val Loss:   2.09, Val Acc: 62.75%, Time: 11.18s *
# Epoch: 3
# Iter: 180, Train Loss:  1.242, Train Acc: 82.81%, Val Loss:  1.842, Val Acc: 66.28%, Time: 2.34s *
# Iter: 210, Train Loss:  1.552, Train Acc: 67.19%, Val Loss:  1.769, Val Acc: 66.95%, Time: 7.16s *
# Iter: 240, Train Loss:  1.693, Train Acc: 71.88%, Val Loss:    1.6, Val Acc: 71.81%, Time: 11.98s *
# Epoch: 4
# Iter: 270, Train Loss:  1.184, Train Acc: 79.69%, Val Loss:  1.553, Val Acc: 72.15%, Time: 3.19s *
# Iter: 300, Train Loss:  0.838, Train Acc: 85.94%, Val Loss:  1.476, Val Acc: 74.33%, Time: 8.06s *
# Iter: 330, Train Loss: 0.9501, Train Acc: 82.81%, Val Loss:    1.4, Val Acc: 75.17%, Time: 12.94s *
# Epoch: 5
# Iter: 360, Train Loss: 0.7037, Train Acc: 89.06%, Val Loss:  1.451, Val Acc: 73.99%, Time: 4.07s
# Iter: 390, Train Loss:   1.14, Train Acc: 82.81%, Val Loss:  1.387, Val Acc: 75.50%, Time: 8.98s *
# Iter: 420, Train Loss: 0.9455, Train Acc: 84.09%, Val Loss:  1.316, Val Acc: 76.34%, Time: 13.81s *
# Epoch: 6
# Iter: 450, Train Loss: 0.4235, Train Acc: 92.19%, Val Loss:  1.472, Val Acc: 75.50%, Time: 4.77s
# Iter: 480, Train Loss: 0.5655, Train Acc: 93.75%, Val Loss:  1.378, Val Acc: 76.85%, Time: 9.62s *
# Epoch: 7
# Iter: 510, Train Loss: 0.5256, Train Acc: 92.19%, Val Loss:  1.433, Val Acc: 76.85%, Time: 1.49s
# Iter: 540, Train Loss: 0.8857, Train Acc: 84.38%, Val Loss:  1.388, Val Acc: 77.01%, Time: 6.29s *
# Iter: 570, Train Loss: 0.7271, Train Acc: 89.06%, Val Loss:  1.428, Val Acc: 76.68%, Time: 11.07s
# Epoch: 8
# Iter: 600, Train Loss: 0.6342, Train Acc: 87.50%, Val Loss:  1.371, Val Acc: 77.68%, Time: 2.29s *
# Iter: 630, Train Loss: 0.3548, Train Acc: 93.75%, Val Loss:  1.479, Val Acc: 76.34%, Time: 7.05s
# Iter: 660, Train Loss: 0.4141, Train Acc: 93.75%, Val Loss:  1.367, Val Acc: 78.36%, Time: 11.86s *
# Epoch: 9
# Iter: 690, Train Loss: 0.5719, Train Acc: 92.19%, Val Loss:  1.532, Val Acc: 77.35%, Time: 3.15s
# Iter: 720, Train Loss: 0.3038, Train Acc: 95.31%, Val Loss:  1.452, Val Acc: 78.19%, Time: 8.02s
# Iter: 750, Train Loss: 0.5869, Train Acc: 89.06%, Val Loss:   1.41, Val Acc: 79.03%, Time: 12.75s *
# Epoch: 10
# Iter: 780, Train Loss: 0.3614, Train Acc: 93.75%, Val Loss:  1.581, Val Acc: 77.35%, Time: 3.94s
# Iter: 810, Train Loss: 0.1696, Train Acc: 98.44%, Val Loss:    1.6, Val Acc: 77.85%, Time: 8.70s
# Iter: 840, Train Loss: 0.1775, Train Acc: 97.73%, Val Loss:   1.52, Val Acc: 78.02%, Time: 13.45s
# Epoch: 11
# Iter: 870, Train Loss: 0.3565, Train Acc: 95.31%, Val Loss:  1.463, Val Acc: 79.03%, Time: 4.73s *
# Iter: 900, Train Loss: 0.6694, Train Acc: 89.06%, Val Loss:  1.753, Val Acc: 74.33%, Time: 9.49s
# Epoch: 12
# Iter: 930, Train Loss: 0.2597, Train Acc: 95.31%, Val Loss:  1.545, Val Acc: 78.52%, Time: 1.47s
# Iter: 960, Train Loss: 0.2971, Train Acc: 96.88%, Val Loss:  1.677, Val Acc: 76.34%, Time: 6.20s
# Iter: 990, Train Loss: 0.3202, Train Acc: 95.31%, Val Loss:  1.836, Val Acc: 76.34%, Time: 11.00s
# Epoch: 13
# Iter: 1020, Train Loss:  0.311, Train Acc: 90.62%, Val Loss:   1.61, Val Acc: 77.85%, Time: 2.32s
# Iter: 1050, Train Loss: 0.2074, Train Acc: 98.44%, Val Loss:  1.872, Val Acc: 75.67%, Time: 7.07s
# Iter: 1080, Train Loss: 0.2509, Train Acc: 95.31%, Val Loss:  1.736, Val Acc: 77.68%, Time: 11.90s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1323, Train Acc: 98.44%, Val Loss:  1.798, Val Acc: 77.18%, Time: 3.12s
# Iter: 1140, Train Loss: 0.2527, Train Acc: 95.31%, Val Loss:  1.873, Val Acc: 77.52%, Time: 7.91s
# Iter: 1170, Train Loss: 0.2662, Train Acc: 95.31%, Val Loss:  1.854, Val Acc: 75.50%, Time: 12.71s
# Epoch: 15
# Iter: 1200, Train Loss: 0.03286, Train Acc: 98.44%, Val Loss:  1.963, Val Acc: 77.01%, Time: 3.98s
# Iter: 1230, Train Loss: 0.1262, Train Acc: 96.88%, Val Loss:  1.837, Val Acc: 77.68%, Time: 8.75s
# Iter: 1260, Train Loss: 0.1827, Train Acc: 97.73%, Val Loss:  1.994, Val Acc: 75.17%, Time: 13.57s
# Epoch: 16
# Iter: 1290, Train Loss: 0.1676, Train Acc: 95.31%, Val Loss:  1.718, Val Acc: 79.03%, Time: 4.79s
# Iter: 1320, Train Loss: 0.1719, Train Acc: 95.31%, Val Loss:  1.786, Val Acc: 79.70%, Time: 9.53s *
# Epoch: 17
# Iter: 1350, Train Loss: 0.3813, Train Acc: 93.75%, Val Loss:  1.922, Val Acc: 76.68%, Time: 1.48s
# Iter: 1380, Train Loss: 0.09677, Train Acc: 98.44%, Val Loss:    1.8, Val Acc: 77.18%, Time: 6.27s
# Iter: 1410, Train Loss: 0.1423, Train Acc: 96.88%, Val Loss:  1.928, Val Acc: 76.68%, Time: 11.00s
# Epoch: 18
# Iter: 1440, Train Loss: 0.2057, Train Acc: 96.88%, Val Loss:  2.195, Val Acc: 75.84%, Time: 2.30s
# Iter: 1470, Train Loss: 0.3169, Train Acc: 93.75%, Val Loss:  1.872, Val Acc: 76.51%, Time: 7.15s
# Iter: 1500, Train Loss: 0.2071, Train Acc: 96.88%, Val Loss:  2.075, Val Acc: 76.34%, Time: 11.92s
# Epoch: 19
# Iter: 1530, Train Loss: 0.09814, Train Acc: 98.44%, Val Loss:  1.964, Val Acc: 78.36%, Time: 3.13s
# Iter: 1560, Train Loss: 0.3316, Train Acc: 92.19%, Val Loss:  1.942, Val Acc: 77.35%, Time: 7.90s
# Iter: 1590, Train Loss: 0.2619, Train Acc: 96.88%, Val Loss:  2.228, Val Acc: 75.00%, Time: 12.65s
# Epoch: 20
# Iter: 1620, Train Loss: 0.07718, Train Acc: 98.44%, Val Loss:  2.171, Val Acc: 75.00%, Time: 3.95s
# Iter: 1650, Train Loss: 0.1089, Train Acc: 98.44%, Val Loss:  2.055, Val Acc: 78.02%, Time: 8.73s
# Iter: 1680, Train Loss: 0.09245, Train Acc: 97.73%, Val Loss:   2.25, Val Acc: 75.34%, Time: 13.59s
# Epoch: 21
# Iter: 1710, Train Loss: 0.2079, Train Acc: 96.88%, Val Loss:  2.148, Val Acc: 76.51%, Time: 4.82s
# Iter: 1740, Train Loss: 0.1911, Train Acc: 95.31%, Val Loss:  1.982, Val Acc: 78.86%, Time: 9.63s
# Epoch: 22
# Iter: 1770, Train Loss: 0.04178, Train Acc: 100.00%, Val Loss:  2.075, Val Acc: 76.51%, Time: 1.51s
# Iter: 1800, Train Loss: 0.1623, Train Acc: 98.44%, Val Loss:  2.343, Val Acc: 75.34%, Time: 6.32s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.62      0.83      0.71         6
#         DESC       0.91      0.64      0.75       138
#         ENTY       0.69      0.78      0.73       136
#          HUM       0.77      0.84      0.81       126
#          LOC       0.66      0.73      0.70        86
#          NUM       0.86      0.87      0.86       104
#
#    micro avg       0.77      0.77      0.77       596
#    macro avg       0.75      0.78      0.76       596
# weighted avg       0.78      0.77      0.77       596
#
# Confusion Matrix...
# [[  5   0   0   0   1   0]
#  [  2  88  22  12  12   2]
#  [  1   2 106  11   8   8]
#  [  0   2  11 106   6   1]
#  [  0   5   8   6  63   4]
#  [  0   0   7   2   5  90]]
# Fold:  3
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.228, Train Acc: 28.12%, Val Loss:  3.294, Val Acc: 24.20%, Time: 5.94s *
# Iter: 60, Train Loss:  2.896, Train Acc: 40.62%, Val Loss:  2.931, Val Acc: 42.86%, Time: 10.72s *
# Epoch: 2
# Iter: 90, Train Loss:  2.661, Train Acc: 46.88%, Val Loss:  2.627, Val Acc: 55.97%, Time: 1.49s *
# Iter: 120, Train Loss:  2.262, Train Acc: 57.81%, Val Loss:  2.365, Val Acc: 55.97%, Time: 6.34s
# Iter: 150, Train Loss:  1.795, Train Acc: 67.19%, Val Loss:  2.113, Val Acc: 62.52%, Time: 11.19s *
# Epoch: 3
# Iter: 180, Train Loss:  1.691, Train Acc: 70.31%, Val Loss:  1.827, Val Acc: 66.72%, Time: 2.33s *
# Iter: 210, Train Loss:  1.792, Train Acc: 68.75%, Val Loss:  1.714, Val Acc: 69.75%, Time: 7.14s *
# Iter: 240, Train Loss: 0.9166, Train Acc: 82.81%, Val Loss:   1.47, Val Acc: 74.62%, Time: 11.95s *
# Epoch: 4
# Iter: 270, Train Loss:  1.176, Train Acc: 76.56%, Val Loss:  1.378, Val Acc: 76.64%, Time: 3.13s *
# Iter: 300, Train Loss: 0.8793, Train Acc: 87.50%, Val Loss:  1.305, Val Acc: 77.65%, Time: 7.98s *
# Iter: 330, Train Loss:  1.142, Train Acc: 84.38%, Val Loss:  1.279, Val Acc: 77.65%, Time: 12.77s *
# Epoch: 5
# Iter: 360, Train Loss: 0.7828, Train Acc: 87.50%, Val Loss:  1.285, Val Acc: 78.99%, Time: 4.01s *
# Iter: 390, Train Loss: 0.7111, Train Acc: 90.62%, Val Loss:  1.207, Val Acc: 78.82%, Time: 8.95s
# Iter: 420, Train Loss: 0.7742, Train Acc: 84.44%, Val Loss:  1.217, Val Acc: 78.99%, Time: 13.67s
# Epoch: 6
# Iter: 450, Train Loss: 0.5572, Train Acc: 92.19%, Val Loss:  1.238, Val Acc: 80.00%, Time: 4.82s *
# Iter: 480, Train Loss:  1.142, Train Acc: 81.25%, Val Loss:  1.247, Val Acc: 79.50%, Time: 9.62s
# Epoch: 7
# Iter: 510, Train Loss:   0.46, Train Acc: 95.31%, Val Loss:  1.154, Val Acc: 81.68%, Time: 1.47s *
# Iter: 540, Train Loss: 0.4535, Train Acc: 95.31%, Val Loss:  1.197, Val Acc: 81.51%, Time: 6.30s
# Iter: 570, Train Loss: 0.6464, Train Acc: 90.62%, Val Loss:  1.331, Val Acc: 81.68%, Time: 11.18s
# Epoch: 8
# Iter: 600, Train Loss: 0.2797, Train Acc: 96.88%, Val Loss:  1.236, Val Acc: 81.85%, Time: 2.32s *
# Iter: 630, Train Loss:  0.676, Train Acc: 87.50%, Val Loss:  1.285, Val Acc: 81.51%, Time: 7.14s
# Iter: 660, Train Loss: 0.6031, Train Acc: 92.19%, Val Loss:  1.238, Val Acc: 82.02%, Time: 11.98s *
# Epoch: 9
# Iter: 690, Train Loss: 0.3102, Train Acc: 95.31%, Val Loss:  1.257, Val Acc: 81.18%, Time: 3.17s
# Iter: 720, Train Loss: 0.2495, Train Acc: 98.44%, Val Loss:  1.344, Val Acc: 81.01%, Time: 8.00s
# Iter: 750, Train Loss: 0.3963, Train Acc: 95.31%, Val Loss:  1.383, Val Acc: 79.66%, Time: 12.90s
# Epoch: 10
# Iter: 780, Train Loss: 0.5122, Train Acc: 92.19%, Val Loss:  1.286, Val Acc: 82.86%, Time: 3.99s *
# Iter: 810, Train Loss: 0.4954, Train Acc: 92.19%, Val Loss:  1.461, Val Acc: 81.01%, Time: 8.79s
# Iter: 840, Train Loss: 0.3319, Train Acc: 91.11%, Val Loss:  1.355, Val Acc: 81.85%, Time: 13.61s
# Epoch: 11
# Iter: 870, Train Loss: 0.1493, Train Acc: 96.88%, Val Loss:  1.468, Val Acc: 81.51%, Time: 4.84s
# Iter: 900, Train Loss: 0.2379, Train Acc: 96.88%, Val Loss:  1.347, Val Acc: 82.52%, Time: 9.65s
# Epoch: 12
# Iter: 930, Train Loss: 0.3978, Train Acc: 92.19%, Val Loss:  1.409, Val Acc: 82.02%, Time: 1.46s
# Iter: 960, Train Loss: 0.4104, Train Acc: 93.75%, Val Loss:  1.391, Val Acc: 81.51%, Time: 6.29s
# Iter: 990, Train Loss: 0.2554, Train Acc: 95.31%, Val Loss:  1.513, Val Acc: 81.51%, Time: 11.14s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2582, Train Acc: 93.75%, Val Loss:  1.461, Val Acc: 82.02%, Time: 2.32s
# Iter: 1050, Train Loss: 0.3146, Train Acc: 93.75%, Val Loss:  1.686, Val Acc: 77.82%, Time: 7.18s
# Iter: 1080, Train Loss: 0.0929, Train Acc: 98.44%, Val Loss:  1.464, Val Acc: 80.50%, Time: 12.00s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1263, Train Acc: 100.00%, Val Loss:  1.546, Val Acc: 80.17%, Time: 3.21s
# Iter: 1140, Train Loss: 0.3003, Train Acc: 93.75%, Val Loss:  1.562, Val Acc: 81.34%, Time: 8.04s
# Iter: 1170, Train Loss: 0.3159, Train Acc: 93.75%, Val Loss:  1.589, Val Acc: 81.85%, Time: 12.93s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1569, Train Acc: 96.88%, Val Loss:  1.653, Val Acc: 81.34%, Time: 4.06s
# Iter: 1230, Train Loss: 0.05206, Train Acc: 98.44%, Val Loss:  1.524, Val Acc: 81.68%, Time: 8.89s
# Iter: 1260, Train Loss: 0.1491, Train Acc: 97.78%, Val Loss:   1.66, Val Acc: 81.85%, Time: 13.72s
# Epoch: 16
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.67      0.80         9
#         DESC       0.78      0.70      0.74       132
#         ENTY       0.75      0.82      0.78       131
#          HUM       0.81      0.84      0.82       129
#          LOC       0.87      0.76      0.81        78
#          NUM       0.86      0.92      0.89       116
#
#    micro avg       0.81      0.81      0.81       595
#    macro avg       0.84      0.78      0.81       595
# weighted avg       0.81      0.81      0.81       595
#
# Confusion Matrix...
# [[  6   2   1   0   0   0]
#  [  0  93  21   8   2   8]
#  [  0   8 107   8   3   5]
#  [  0   8   8 108   2   3]
#  [  0   7   5   5  59   2]
#  [  0   2   1   4   2 107]]
# Fold:  4
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.291, Train Acc: 26.56%, Val Loss:  3.309, Val Acc: 24.54%, Time: 5.86s *
# Iter: 60, Train Loss:  2.963, Train Acc: 48.44%, Val Loss:  3.047, Val Acc: 44.71%, Time: 10.70s *
# Epoch: 2
# Iter: 90, Train Loss:  2.396, Train Acc: 59.38%, Val Loss:  2.737, Val Acc: 47.73%, Time: 1.51s *
# Iter: 120, Train Loss:  2.368, Train Acc: 53.12%, Val Loss:  2.543, Val Acc: 50.08%, Time: 6.34s *
# Iter: 150, Train Loss:  2.139, Train Acc: 60.94%, Val Loss:  2.254, Val Acc: 59.16%, Time: 11.23s *
# Epoch: 3
# Iter: 180, Train Loss:  1.888, Train Acc: 59.38%, Val Loss:  1.993, Val Acc: 62.86%, Time: 2.38s *
# Iter: 210, Train Loss:  1.657, Train Acc: 70.31%, Val Loss:  1.915, Val Acc: 63.03%, Time: 7.34s *
# Iter: 240, Train Loss: 0.9426, Train Acc: 85.94%, Val Loss:  1.681, Val Acc: 68.74%, Time: 12.28s *
# Epoch: 4
# Iter: 270, Train Loss:  1.337, Train Acc: 79.69%, Val Loss:  1.618, Val Acc: 69.92%, Time: 3.15s *
# Iter: 300, Train Loss:  1.263, Train Acc: 76.56%, Val Loss:  1.525, Val Acc: 72.10%, Time: 8.02s *
# Iter: 330, Train Loss:  1.577, Train Acc: 76.56%, Val Loss:  1.539, Val Acc: 71.93%, Time: 12.87s
# Epoch: 5
# Iter: 360, Train Loss: 0.7499, Train Acc: 87.50%, Val Loss:  1.487, Val Acc: 73.95%, Time: 4.03s *
# Iter: 390, Train Loss: 0.7039, Train Acc: 92.19%, Val Loss:  1.459, Val Acc: 72.44%, Time: 8.85s
# Iter: 420, Train Loss:  1.082, Train Acc: 80.00%, Val Loss:  1.397, Val Acc: 74.29%, Time: 13.68s *
# Epoch: 6
# Iter: 450, Train Loss: 0.7192, Train Acc: 89.06%, Val Loss:  1.481, Val Acc: 73.11%, Time: 4.88s
# Iter: 480, Train Loss:  0.683, Train Acc: 89.06%, Val Loss:  1.426, Val Acc: 74.12%, Time: 9.70s
# Epoch: 7
# Iter: 510, Train Loss: 0.6611, Train Acc: 90.62%, Val Loss:  1.411, Val Acc: 74.62%, Time: 1.49s *
# Iter: 540, Train Loss: 0.4912, Train Acc: 92.19%, Val Loss:  1.479, Val Acc: 74.29%, Time: 6.36s
# Iter: 570, Train Loss:  0.362, Train Acc: 93.75%, Val Loss:   1.35, Val Acc: 75.46%, Time: 11.21s *
# Epoch: 8
# Iter: 600, Train Loss: 0.5014, Train Acc: 87.50%, Val Loss:  1.586, Val Acc: 74.96%, Time: 2.34s
# Iter: 630, Train Loss: 0.4901, Train Acc: 93.75%, Val Loss:  1.507, Val Acc: 74.12%, Time: 7.16s
# Iter: 660, Train Loss: 0.6372, Train Acc: 89.06%, Val Loss:  1.476, Val Acc: 75.29%, Time: 11.95s
# Epoch: 9
# Iter: 690, Train Loss: 0.3378, Train Acc: 90.62%, Val Loss:  1.467, Val Acc: 76.30%, Time: 3.22s *
# Iter: 720, Train Loss: 0.2297, Train Acc: 96.88%, Val Loss:  1.557, Val Acc: 75.80%, Time: 8.05s
# Iter: 750, Train Loss: 0.3237, Train Acc: 92.19%, Val Loss:  1.519, Val Acc: 75.29%, Time: 12.88s
# Epoch: 10
# Iter: 780, Train Loss:  0.446, Train Acc: 92.19%, Val Loss:  1.636, Val Acc: 76.30%, Time: 3.95s
# Iter: 810, Train Loss: 0.3852, Train Acc: 95.31%, Val Loss:   1.76, Val Acc: 75.46%, Time: 8.71s
# Iter: 840, Train Loss: 0.1288, Train Acc: 97.78%, Val Loss:  1.603, Val Acc: 75.13%, Time: 13.49s
# Epoch: 11
# Iter: 870, Train Loss: 0.1272, Train Acc: 98.44%, Val Loss:  2.097, Val Acc: 72.77%, Time: 4.79s
# Iter: 900, Train Loss: 0.1506, Train Acc: 96.88%, Val Loss:  1.681, Val Acc: 74.45%, Time: 9.60s
# Epoch: 12
# Iter: 930, Train Loss: 0.2002, Train Acc: 98.44%, Val Loss:  1.727, Val Acc: 74.12%, Time: 1.56s
# Iter: 960, Train Loss: 0.3801, Train Acc: 93.75%, Val Loss:  2.126, Val Acc: 71.76%, Time: 6.41s
# Iter: 990, Train Loss: 0.1183, Train Acc: 100.00%, Val Loss:  1.745, Val Acc: 74.45%, Time: 11.26s
# Epoch: 13
# Iter: 1020, Train Loss: 0.4955, Train Acc: 93.75%, Val Loss:  2.005, Val Acc: 73.61%, Time: 2.31s
# Iter: 1050, Train Loss: 0.1794, Train Acc: 98.44%, Val Loss:  1.901, Val Acc: 74.62%, Time: 7.11s
# Iter: 1080, Train Loss: 0.1304, Train Acc: 98.44%, Val Loss:  1.918, Val Acc: 75.29%, Time: 11.91s
# Epoch: 14
# Iter: 1110, Train Loss: 0.2515, Train Acc: 95.31%, Val Loss:  1.931, Val Acc: 74.62%, Time: 3.15s
# Iter: 1140, Train Loss: 0.6561, Train Acc: 89.06%, Val Loss:   2.09, Val Acc: 73.78%, Time: 7.99s
# Iter: 1170, Train Loss: 0.04591, Train Acc: 100.00%, Val Loss:  1.799, Val Acc: 75.13%, Time: 12.82s
# Epoch: 15
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.83      0.67      0.74        15
#         DESC       0.73      0.75      0.74       138
#         ENTY       0.70      0.75      0.72       144
#          HUM       0.88      0.68      0.77       114
#          LOC       0.82      0.72      0.77        96
#          NUM       0.71      0.92      0.80        88
#
#    micro avg       0.75      0.75      0.75       595
#    macro avg       0.78      0.75      0.76       595
# weighted avg       0.76      0.75      0.75       595
#
# Confusion Matrix...
# [[ 10   5   0   0   0   0]
#  [  2 103  19   3   3   8]
#  [  0  14 108   7   7   8]
#  [  0   7  21  78   2   6]
#  [  0  10   5   1  69  11]
#  [  0   3   1   0   3  81]]
# Fold:  5
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.179, Train Acc: 34.38%, Val Loss:  3.218, Val Acc: 28.24%, Time: 5.96s *
# Iter: 60, Train Loss:  2.891, Train Acc: 46.88%, Val Loss:  3.022, Val Acc: 39.83%, Time: 10.79s *
# Epoch: 2
# Iter: 90, Train Loss:  2.542, Train Acc: 50.00%, Val Loss:  2.656, Val Acc: 51.93%, Time: 1.54s *
# Iter: 120, Train Loss:  2.048, Train Acc: 67.19%, Val Loss:  2.343, Val Acc: 57.31%, Time: 6.37s *
# Iter: 150, Train Loss:  1.612, Train Acc: 71.88%, Val Loss:  2.144, Val Acc: 60.34%, Time: 11.26s *
# Epoch: 3
# Iter: 180, Train Loss:  1.307, Train Acc: 76.56%, Val Loss:  1.826, Val Acc: 67.90%, Time: 2.33s *
# Iter: 210, Train Loss:  1.882, Train Acc: 64.06%, Val Loss:  1.721, Val Acc: 69.24%, Time: 7.19s *
# Iter: 240, Train Loss:  1.229, Train Acc: 87.50%, Val Loss:   1.62, Val Acc: 69.41%, Time: 12.02s *
# Epoch: 4
# Iter: 270, Train Loss:  1.638, Train Acc: 73.44%, Val Loss:  1.558, Val Acc: 72.10%, Time: 3.14s *
# Iter: 300, Train Loss:  1.405, Train Acc: 78.12%, Val Loss:  1.513, Val Acc: 72.61%, Time: 7.96s *
# Iter: 330, Train Loss:  1.094, Train Acc: 79.69%, Val Loss:  1.449, Val Acc: 73.61%, Time: 12.81s *
# Epoch: 5
# Iter: 360, Train Loss: 0.4996, Train Acc: 93.75%, Val Loss:  1.511, Val Acc: 73.95%, Time: 3.99s *
# Iter: 390, Train Loss: 0.9267, Train Acc: 84.38%, Val Loss:  1.456, Val Acc: 75.63%, Time: 8.82s *
# Iter: 420, Train Loss:  1.014, Train Acc: 82.22%, Val Loss:  1.327, Val Acc: 75.46%, Time: 13.67s
# Epoch: 6
# Iter: 450, Train Loss: 0.5488, Train Acc: 92.19%, Val Loss:  1.376, Val Acc: 75.46%, Time: 4.84s
# Iter: 480, Train Loss:  0.839, Train Acc: 87.50%, Val Loss:  1.524, Val Acc: 76.13%, Time: 9.68s *
# Epoch: 7
# Iter: 510, Train Loss: 0.3692, Train Acc: 92.19%, Val Loss:  1.531, Val Acc: 77.14%, Time: 1.49s *
# Iter: 540, Train Loss: 0.4084, Train Acc: 92.19%, Val Loss:  1.429, Val Acc: 76.81%, Time: 6.32s
# Iter: 570, Train Loss: 0.3341, Train Acc: 93.75%, Val Loss:  1.424, Val Acc: 77.31%, Time: 11.17s *
# Epoch: 8
# Iter: 600, Train Loss: 0.4636, Train Acc: 93.75%, Val Loss:  1.421, Val Acc: 78.66%, Time: 2.34s *
# Iter: 630, Train Loss: 0.4731, Train Acc: 93.75%, Val Loss:   1.42, Val Acc: 78.99%, Time: 7.20s *
# Iter: 660, Train Loss: 0.4434, Train Acc: 90.62%, Val Loss:   1.46, Val Acc: 78.49%, Time: 12.07s
# Epoch: 9
# Iter: 690, Train Loss: 0.3665, Train Acc: 90.62%, Val Loss:  1.493, Val Acc: 78.49%, Time: 3.20s
# Iter: 720, Train Loss: 0.4637, Train Acc: 90.62%, Val Loss:   1.78, Val Acc: 76.13%, Time: 8.02s
# Iter: 750, Train Loss:  0.438, Train Acc: 92.19%, Val Loss:  1.469, Val Acc: 78.15%, Time: 12.83s
# Epoch: 10
# Iter: 780, Train Loss: 0.2168, Train Acc: 95.31%, Val Loss:  1.552, Val Acc: 77.48%, Time: 4.00s
# Iter: 810, Train Loss: 0.2822, Train Acc: 93.75%, Val Loss:  1.599, Val Acc: 77.31%, Time: 8.76s
# Iter: 840, Train Loss: 0.4741, Train Acc: 93.33%, Val Loss:  1.515, Val Acc: 79.16%, Time: 13.63s *
# Epoch: 11
# Iter: 870, Train Loss: 0.2621, Train Acc: 96.88%, Val Loss:  1.534, Val Acc: 78.32%, Time: 4.84s
# Iter: 900, Train Loss:  0.311, Train Acc: 93.75%, Val Loss:  1.756, Val Acc: 77.14%, Time: 9.69s
# Epoch: 12
# Iter: 930, Train Loss: 0.07568, Train Acc: 100.00%, Val Loss:   1.58, Val Acc: 78.82%, Time: 1.51s
# Iter: 960, Train Loss: 0.2613, Train Acc: 95.31%, Val Loss:  1.827, Val Acc: 78.15%, Time: 6.31s
# Iter: 990, Train Loss: 0.2007, Train Acc: 98.44%, Val Loss:  1.495, Val Acc: 79.83%, Time: 11.10s *
# Epoch: 13
# Iter: 1020, Train Loss:  0.155, Train Acc: 98.44%, Val Loss:  1.718, Val Acc: 78.32%, Time: 2.32s
# Iter: 1050, Train Loss: 0.1421, Train Acc: 98.44%, Val Loss:  1.742, Val Acc: 78.32%, Time: 7.10s
# Iter: 1080, Train Loss: 0.1092, Train Acc: 96.88%, Val Loss:  1.681, Val Acc: 79.50%, Time: 11.93s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1055, Train Acc: 100.00%, Val Loss:  1.839, Val Acc: 78.32%, Time: 3.15s
# Iter: 1140, Train Loss: 0.1468, Train Acc: 96.88%, Val Loss:  1.917, Val Acc: 78.32%, Time: 7.98s
# Iter: 1170, Train Loss: 0.1679, Train Acc: 95.31%, Val Loss:  1.768, Val Acc: 79.33%, Time: 12.73s
# Epoch: 15
# Iter: 1200, Train Loss: 0.3117, Train Acc: 92.19%, Val Loss:  1.745, Val Acc: 78.32%, Time: 4.00s
# Iter: 1230, Train Loss:  0.252, Train Acc: 95.31%, Val Loss:  1.841, Val Acc: 80.17%, Time: 8.86s *
# Iter: 1260, Train Loss:   0.16, Train Acc: 95.56%, Val Loss:  1.944, Val Acc: 77.48%, Time: 13.63s
# Epoch: 16
# Iter: 1290, Train Loss: 0.07804, Train Acc: 98.44%, Val Loss:  1.833, Val Acc: 78.66%, Time: 4.78s
# Iter: 1320, Train Loss: 0.2087, Train Acc: 93.75%, Val Loss:  1.847, Val Acc: 78.49%, Time: 9.55s
# Epoch: 17
# Iter: 1350, Train Loss: 0.1342, Train Acc: 96.88%, Val Loss:  1.782, Val Acc: 78.15%, Time: 1.51s
# Iter: 1380, Train Loss: 0.0621, Train Acc: 98.44%, Val Loss:    1.7, Val Acc: 79.83%, Time: 6.26s
# Iter: 1410, Train Loss: 0.1109, Train Acc: 96.88%, Val Loss:  1.797, Val Acc: 79.50%, Time: 11.07s
# Epoch: 18
# Iter: 1440, Train Loss: 0.1665, Train Acc: 96.88%, Val Loss:  2.033, Val Acc: 78.32%, Time: 2.31s
# Iter: 1470, Train Loss: 0.03054, Train Acc: 100.00%, Val Loss:  1.826, Val Acc: 80.50%, Time: 7.13s *
# Iter: 1500, Train Loss: 0.1076, Train Acc: 98.44%, Val Loss:  1.887, Val Acc: 79.66%, Time: 11.86s
# Epoch: 19
# Iter: 1530, Train Loss: 0.08661, Train Acc: 96.88%, Val Loss:  2.058, Val Acc: 79.50%, Time: 3.19s
# Iter: 1560, Train Loss: 0.1284, Train Acc: 96.88%, Val Loss:  1.757, Val Acc: 80.00%, Time: 8.00s
# Iter: 1590, Train Loss: 0.2286, Train Acc: 96.88%, Val Loss:  2.029, Val Acc: 75.80%, Time: 12.89s
# Epoch: 20
# Iter: 1620, Train Loss: 0.05817, Train Acc: 100.00%, Val Loss:  1.876, Val Acc: 77.65%, Time: 3.97s
# Iter: 1650, Train Loss: 0.1308, Train Acc: 96.88%, Val Loss:  1.938, Val Acc: 78.49%, Time: 8.77s
# Iter: 1680, Train Loss: 0.02795, Train Acc: 100.00%, Val Loss:  1.985, Val Acc: 79.83%, Time: 13.64s
# Epoch: 21
# Iter: 1710, Train Loss: 0.1408, Train Acc: 96.88%, Val Loss:  2.116, Val Acc: 77.98%, Time: 4.82s
# Iter: 1740, Train Loss: 0.2165, Train Acc: 96.88%, Val Loss:  2.068, Val Acc: 77.48%, Time: 9.64s
# Epoch: 22
# Iter: 1770, Train Loss:  0.182, Train Acc: 96.88%, Val Loss:  2.069, Val Acc: 77.14%, Time: 1.49s
# Iter: 1800, Train Loss: 0.0784, Train Acc: 98.44%, Val Loss:  2.144, Val Acc: 77.31%, Time: 6.33s
# Iter: 1830, Train Loss: 0.1448, Train Acc: 98.44%, Val Loss:  1.944, Val Acc: 78.66%, Time: 11.20s
# Epoch: 23
# Iter: 1860, Train Loss: 0.1035, Train Acc: 96.88%, Val Loss:  1.904, Val Acc: 78.99%, Time: 2.32s
# Iter: 1890, Train Loss: 0.07134, Train Acc: 98.44%, Val Loss:  1.975, Val Acc: 77.98%, Time: 7.10s
# Iter: 1920, Train Loss: 0.07188, Train Acc: 98.44%, Val Loss:  2.174, Val Acc: 78.99%, Time: 11.88s
# Epoch: 24
# Iter: 1950, Train Loss: 0.1902, Train Acc: 95.31%, Val Loss:  2.112, Val Acc: 79.16%, Time: 3.15s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.50      0.67         8
#         DESC       0.64      0.75      0.69       109
#         ENTY       0.73      0.82      0.78       154
#          HUM       0.88      0.80      0.84       123
#          LOC       0.93      0.71      0.81        90
#          NUM       0.90      0.86      0.88       111
#
#    micro avg       0.79      0.79      0.79       595
#    macro avg       0.85      0.74      0.78       595
# weighted avg       0.81      0.79      0.80       595
#
# Confusion Matrix...
# [[  4   2   0   1   0   1]
#  [  0  82  22   3   0   2]
#  [  0  13 127  10   1   3]
#  [  0  10  10  99   2   2]
#  [  0  16   7   0  64   3]
#  [  0   6   7   0   2  96]]
# Fold:  6
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.268, Train Acc: 34.38%, Val Loss:   3.35, Val Acc: 26.22%, Time: 5.83s *
# Iter: 60, Train Loss:   3.01, Train Acc: 43.75%, Val Loss:  2.998, Val Acc: 47.90%, Time: 10.63s *
# Epoch: 2
# Iter: 90, Train Loss:  2.646, Train Acc: 54.69%, Val Loss:  2.598, Val Acc: 53.45%, Time: 1.48s *
# Iter: 120, Train Loss:  2.223, Train Acc: 62.50%, Val Loss:  2.317, Val Acc: 59.50%, Time: 6.28s *
# Iter: 150, Train Loss:  1.941, Train Acc: 65.62%, Val Loss:  2.009, Val Acc: 65.21%, Time: 11.03s *
# Epoch: 3
# Iter: 180, Train Loss:  1.542, Train Acc: 70.31%, Val Loss:  1.918, Val Acc: 64.20%, Time: 2.30s
# Iter: 210, Train Loss:  1.368, Train Acc: 79.69%, Val Loss:  1.752, Val Acc: 67.06%, Time: 7.06s *
# Iter: 240, Train Loss:  1.353, Train Acc: 78.12%, Val Loss:  1.526, Val Acc: 72.61%, Time: 11.82s *
# Epoch: 4
# Iter: 270, Train Loss: 0.8303, Train Acc: 84.38%, Val Loss:  1.475, Val Acc: 73.61%, Time: 3.14s *
# Iter: 300, Train Loss:  1.158, Train Acc: 78.12%, Val Loss:  1.353, Val Acc: 76.97%, Time: 7.92s *
# Iter: 330, Train Loss:  1.633, Train Acc: 78.12%, Val Loss:  1.496, Val Acc: 72.77%, Time: 12.69s
# Epoch: 5
# Iter: 360, Train Loss: 0.6392, Train Acc: 92.19%, Val Loss:  1.295, Val Acc: 75.29%, Time: 4.02s
# Iter: 390, Train Loss:  1.144, Train Acc: 82.81%, Val Loss:  1.378, Val Acc: 73.28%, Time: 8.77s
# Iter: 420, Train Loss: 0.9302, Train Acc: 82.22%, Val Loss:  1.238, Val Acc: 78.32%, Time: 13.58s *
# Epoch: 6
# Iter: 450, Train Loss: 0.6077, Train Acc: 87.50%, Val Loss:  1.337, Val Acc: 76.30%, Time: 4.79s
# Iter: 480, Train Loss: 0.6375, Train Acc: 87.50%, Val Loss:  1.339, Val Acc: 75.29%, Time: 9.59s
# Epoch: 7
# Iter: 510, Train Loss: 0.4573, Train Acc: 93.75%, Val Loss:  1.321, Val Acc: 76.13%, Time: 1.52s
# Iter: 540, Train Loss: 0.3189, Train Acc: 95.31%, Val Loss:   1.28, Val Acc: 79.16%, Time: 6.32s *
# Iter: 570, Train Loss: 0.4848, Train Acc: 90.62%, Val Loss:  1.354, Val Acc: 76.13%, Time: 11.00s
# Epoch: 8
# Iter: 600, Train Loss: 0.5104, Train Acc: 92.19%, Val Loss:   1.36, Val Acc: 77.65%, Time: 2.32s
# Iter: 630, Train Loss: 0.3869, Train Acc: 93.75%, Val Loss:  1.391, Val Acc: 75.80%, Time: 7.05s
# Iter: 660, Train Loss:  0.657, Train Acc: 90.62%, Val Loss:  1.376, Val Acc: 77.98%, Time: 11.88s
# Epoch: 9
# Iter: 690, Train Loss:   0.41, Train Acc: 95.31%, Val Loss:  1.281, Val Acc: 78.99%, Time: 3.14s
# Iter: 720, Train Loss: 0.06848, Train Acc: 100.00%, Val Loss:  1.539, Val Acc: 77.14%, Time: 7.87s
# Iter: 750, Train Loss: 0.6441, Train Acc: 89.06%, Val Loss:  1.552, Val Acc: 75.97%, Time: 12.75s
# Epoch: 10
# Iter: 780, Train Loss: 0.3988, Train Acc: 90.62%, Val Loss:  1.634, Val Acc: 77.98%, Time: 4.03s
# Iter: 810, Train Loss: 0.1855, Train Acc: 98.44%, Val Loss:  1.446, Val Acc: 78.99%, Time: 8.80s
# Iter: 840, Train Loss: 0.8409, Train Acc: 88.89%, Val Loss:  1.524, Val Acc: 78.99%, Time: 13.55s
# Epoch: 11
# Iter: 870, Train Loss: 0.2652, Train Acc: 95.31%, Val Loss:  1.626, Val Acc: 78.49%, Time: 4.84s
# Iter: 900, Train Loss: 0.2631, Train Acc: 96.88%, Val Loss:  1.587, Val Acc: 77.31%, Time: 9.72s
# Epoch: 12
# Iter: 930, Train Loss:  0.202, Train Acc: 95.31%, Val Loss:  1.586, Val Acc: 78.82%, Time: 1.48s
# Iter: 960, Train Loss: 0.09508, Train Acc: 98.44%, Val Loss:  1.604, Val Acc: 77.98%, Time: 6.24s
# Iter: 990, Train Loss: 0.2044, Train Acc: 96.88%, Val Loss:  1.612, Val Acc: 78.15%, Time: 10.97s
# Epoch: 13
# Iter: 1020, Train Loss: 0.1063, Train Acc: 98.44%, Val Loss:   1.67, Val Acc: 78.49%, Time: 2.31s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.78      0.64      0.70        11
#         DESC       0.77      0.64      0.70       117
#         ENTY       0.64      0.86      0.73       133
#          HUM       0.90      0.72      0.80       149
#          LOC       0.89      0.84      0.86        91
#          NUM       0.81      0.90      0.85        94
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.80      0.77      0.77       595
# weighted avg       0.80      0.78      0.78       595
#
# Confusion Matrix...
# [[  7   2   2   0   0   0]
#  [  2  75  26   2   6   6]
#  [  0   7 114   6   1   5]
#  [  0   8  28 107   2   4]
#  [  0   2   5   3  76   5]
#  [  0   4   4   1   0  85]]
# Fold:  7
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:   3.19, Train Acc: 34.38%, Val Loss:  3.266, Val Acc: 23.87%, Time: 5.94s *
# Iter: 60, Train Loss:  3.051, Train Acc: 37.50%, Val Loss:  2.934, Val Acc: 42.52%, Time: 10.79s *
# Epoch: 2
# Iter: 90, Train Loss:  2.658, Train Acc: 51.56%, Val Loss:  2.566, Val Acc: 54.45%, Time: 1.47s *
# Iter: 120, Train Loss:  1.811, Train Acc: 70.31%, Val Loss:  2.268, Val Acc: 57.98%, Time: 6.27s *
# Iter: 150, Train Loss:  2.186, Train Acc: 59.38%, Val Loss:  2.038, Val Acc: 63.53%, Time: 11.12s *
# Epoch: 3
# Iter: 180, Train Loss:   1.56, Train Acc: 71.88%, Val Loss:  1.742, Val Acc: 70.08%, Time: 2.25s *
# Iter: 210, Train Loss:  1.645, Train Acc: 71.88%, Val Loss:  1.601, Val Acc: 69.58%, Time: 7.06s
# Iter: 240, Train Loss:  1.445, Train Acc: 67.19%, Val Loss:  1.588, Val Acc: 71.26%, Time: 11.87s *
# Epoch: 4
# Iter: 270, Train Loss:  1.119, Train Acc: 78.12%, Val Loss:  1.424, Val Acc: 74.96%, Time: 3.14s *
# Iter: 300, Train Loss: 0.8682, Train Acc: 84.38%, Val Loss:   1.43, Val Acc: 73.78%, Time: 7.91s
# Iter: 330, Train Loss: 0.9425, Train Acc: 87.50%, Val Loss:  1.386, Val Acc: 76.30%, Time: 12.69s *
# Epoch: 5
# Iter: 360, Train Loss:  0.955, Train Acc: 84.38%, Val Loss:  1.394, Val Acc: 75.63%, Time: 3.97s
# Iter: 390, Train Loss: 0.7708, Train Acc: 87.50%, Val Loss:  1.317, Val Acc: 79.16%, Time: 8.72s *
# Iter: 420, Train Loss:  1.033, Train Acc: 82.22%, Val Loss:  1.243, Val Acc: 79.16%, Time: 13.55s
# Epoch: 6
# Iter: 450, Train Loss: 0.8839, Train Acc: 82.81%, Val Loss:  1.216, Val Acc: 78.49%, Time: 4.72s
# Iter: 480, Train Loss: 0.7476, Train Acc: 84.38%, Val Loss:  1.292, Val Acc: 77.82%, Time: 9.53s
# Epoch: 7
# Iter: 510, Train Loss: 0.7566, Train Acc: 81.25%, Val Loss:  1.332, Val Acc: 76.97%, Time: 1.47s
# Iter: 540, Train Loss: 0.5005, Train Acc: 90.62%, Val Loss:  1.224, Val Acc: 78.99%, Time: 6.25s
# Iter: 570, Train Loss: 0.6495, Train Acc: 89.06%, Val Loss:   1.22, Val Acc: 80.00%, Time: 11.01s *
# Epoch: 8
# Iter: 600, Train Loss: 0.4672, Train Acc: 87.50%, Val Loss:   1.38, Val Acc: 76.64%, Time: 2.33s
# Iter: 630, Train Loss: 0.8345, Train Acc: 85.94%, Val Loss:  1.301, Val Acc: 78.99%, Time: 7.06s
# Iter: 660, Train Loss: 0.3706, Train Acc: 95.31%, Val Loss:  1.317, Val Acc: 78.49%, Time: 11.88s
# Epoch: 9
# Iter: 690, Train Loss: 0.3873, Train Acc: 92.19%, Val Loss:  1.358, Val Acc: 78.49%, Time: 3.14s
# Iter: 720, Train Loss: 0.6575, Train Acc: 89.06%, Val Loss:  1.385, Val Acc: 79.50%, Time: 7.93s
# Iter: 750, Train Loss: 0.6382, Train Acc: 89.06%, Val Loss:  1.725, Val Acc: 77.31%, Time: 12.74s
# Epoch: 10
# Iter: 780, Train Loss: 0.3412, Train Acc: 93.75%, Val Loss:  1.506, Val Acc: 77.65%, Time: 3.98s
# Iter: 810, Train Loss: 0.3814, Train Acc: 93.75%, Val Loss:  1.553, Val Acc: 78.49%, Time: 8.84s
# Iter: 840, Train Loss: 0.1394, Train Acc: 97.78%, Val Loss:  1.456, Val Acc: 79.66%, Time: 13.64s
# Epoch: 11
# Iter: 870, Train Loss:  0.397, Train Acc: 93.75%, Val Loss:  1.491, Val Acc: 77.48%, Time: 4.71s
# Iter: 900, Train Loss: 0.4051, Train Acc: 92.19%, Val Loss:  1.498, Val Acc: 79.50%, Time: 9.48s
# Epoch: 12
# Iter: 930, Train Loss: 0.3337, Train Acc: 92.19%, Val Loss:  1.519, Val Acc: 76.97%, Time: 1.49s
# Iter: 960, Train Loss: 0.1707, Train Acc: 95.31%, Val Loss:  1.577, Val Acc: 78.15%, Time: 6.24s
# Iter: 990, Train Loss: 0.07696, Train Acc: 100.00%, Val Loss:  1.494, Val Acc: 78.82%, Time: 11.11s
# Epoch: 13
# Iter: 1020, Train Loss: 0.3196, Train Acc: 93.75%, Val Loss:  1.713, Val Acc: 78.49%, Time: 2.32s
# Iter: 1050, Train Loss: 0.4312, Train Acc: 90.62%, Val Loss:   1.65, Val Acc: 78.15%, Time: 7.16s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.80      0.89        10
#         DESC       0.74      0.68      0.71       135
#         ENTY       0.67      0.83      0.74       143
#          HUM       0.84      0.74      0.79       117
#          LOC       0.89      0.72      0.80        95
#          NUM       0.81      0.91      0.86        95
#
#    micro avg       0.77      0.77      0.77       595
#    macro avg       0.83      0.78      0.80       595
# weighted avg       0.78      0.77      0.77       595
#
# Confusion Matrix...
# [[  8   1   1   0   0   0]
#  [  0  92  29   5   5   4]
#  [  0  10 119   9   2   3]
#  [  0   3  17  87   1   9]
#  [  0  15   7   1  68   4]
#  [  0   3   5   1   0  86]]
# Fold:  8
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.096, Train Acc: 28.12%, Val Loss:  3.263, Val Acc: 22.35%, Time: 5.90s *
# Iter: 60, Train Loss:  3.038, Train Acc: 40.62%, Val Loss:  2.922, Val Acc: 43.70%, Time: 10.71s *
# Epoch: 2
# Iter: 90, Train Loss:  2.766, Train Acc: 54.69%, Val Loss:  2.638, Val Acc: 52.61%, Time: 1.50s *
# Iter: 120, Train Loss:  2.492, Train Acc: 54.69%, Val Loss:  2.434, Val Acc: 53.61%, Time: 6.28s *
# Iter: 150, Train Loss:  2.159, Train Acc: 59.38%, Val Loss:  2.131, Val Acc: 62.35%, Time: 11.07s *
# Epoch: 3
# Iter: 180, Train Loss:  1.503, Train Acc: 76.56%, Val Loss:  1.866, Val Acc: 66.22%, Time: 2.29s *
# Iter: 210, Train Loss:  1.673, Train Acc: 68.75%, Val Loss:  1.738, Val Acc: 69.58%, Time: 7.07s *
# Iter: 240, Train Loss:  1.243, Train Acc: 78.12%, Val Loss:  1.647, Val Acc: 69.24%, Time: 11.89s
# Epoch: 4
# Iter: 270, Train Loss:  1.636, Train Acc: 70.31%, Val Loss:  1.547, Val Acc: 69.41%, Time: 3.18s
# Iter: 300, Train Loss: 0.9358, Train Acc: 87.50%, Val Loss:  1.487, Val Acc: 73.11%, Time: 7.98s *
# Iter: 330, Train Loss:  1.175, Train Acc: 78.12%, Val Loss:  1.402, Val Acc: 73.28%, Time: 12.78s *
# Epoch: 5
# Iter: 360, Train Loss: 0.9889, Train Acc: 85.94%, Val Loss:  1.467, Val Acc: 73.95%, Time: 3.95s *
# Iter: 390, Train Loss: 0.6326, Train Acc: 90.62%, Val Loss:  1.426, Val Acc: 75.46%, Time: 8.71s *
# Iter: 420, Train Loss: 0.6835, Train Acc: 88.89%, Val Loss:  1.435, Val Acc: 74.79%, Time: 13.49s
# Epoch: 6
# Iter: 450, Train Loss: 0.5246, Train Acc: 89.06%, Val Loss:  1.373, Val Acc: 76.30%, Time: 4.76s *
# Iter: 480, Train Loss: 0.5957, Train Acc: 90.62%, Val Loss:  1.501, Val Acc: 73.78%, Time: 9.56s
# Epoch: 7
# Iter: 510, Train Loss: 0.4711, Train Acc: 93.75%, Val Loss:  1.369, Val Acc: 76.13%, Time: 1.44s
# Iter: 540, Train Loss: 0.3914, Train Acc: 92.19%, Val Loss:   1.49, Val Acc: 76.47%, Time: 6.20s *
# Iter: 570, Train Loss: 0.2273, Train Acc: 95.31%, Val Loss:  1.465, Val Acc: 76.47%, Time: 11.00s *
# Epoch: 8
# Iter: 600, Train Loss: 0.6164, Train Acc: 90.62%, Val Loss:  1.528, Val Acc: 75.97%, Time: 2.34s
# Iter: 630, Train Loss: 0.3149, Train Acc: 95.31%, Val Loss:  1.494, Val Acc: 76.30%, Time: 7.10s
# Iter: 660, Train Loss: 0.4052, Train Acc: 95.31%, Val Loss:  1.453, Val Acc: 76.97%, Time: 11.89s *
# Epoch: 9
# Iter: 690, Train Loss: 0.3637, Train Acc: 96.88%, Val Loss:  1.632, Val Acc: 75.63%, Time: 3.14s
# Iter: 720, Train Loss: 0.1556, Train Acc: 96.88%, Val Loss:  1.648, Val Acc: 78.49%, Time: 7.96s *
# Iter: 750, Train Loss: 0.5293, Train Acc: 92.19%, Val Loss:  1.501, Val Acc: 77.82%, Time: 12.76s
# Epoch: 10
# Iter: 780, Train Loss: 0.3286, Train Acc: 96.88%, Val Loss:  1.623, Val Acc: 77.48%, Time: 3.99s
# Iter: 810, Train Loss: 0.2365, Train Acc: 95.31%, Val Loss:  1.741, Val Acc: 76.64%, Time: 8.79s
# Iter: 840, Train Loss:  0.208, Train Acc: 95.56%, Val Loss:  1.655, Val Acc: 77.98%, Time: 13.67s
# Epoch: 11
# Iter: 870, Train Loss: 0.2304, Train Acc: 95.31%, Val Loss:  1.826, Val Acc: 75.97%, Time: 4.80s
# Iter: 900, Train Loss: 0.1971, Train Acc: 96.88%, Val Loss:  1.785, Val Acc: 76.81%, Time: 9.57s
# Epoch: 12
# Iter: 930, Train Loss:  0.151, Train Acc: 96.88%, Val Loss:  1.829, Val Acc: 75.80%, Time: 1.50s
# Iter: 960, Train Loss: 0.2313, Train Acc: 96.88%, Val Loss:  1.711, Val Acc: 77.48%, Time: 6.29s
# Iter: 990, Train Loss: 0.2228, Train Acc: 95.31%, Val Loss:  1.845, Val Acc: 75.63%, Time: 11.07s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2733, Train Acc: 96.88%, Val Loss:  1.887, Val Acc: 74.79%, Time: 2.34s
# Iter: 1050, Train Loss: 0.2305, Train Acc: 95.31%, Val Loss:  1.974, Val Acc: 76.81%, Time: 7.17s
# Iter: 1080, Train Loss: 0.3596, Train Acc: 93.75%, Val Loss:  2.013, Val Acc: 72.94%, Time: 11.92s
# Epoch: 14
# Iter: 1110, Train Loss: 0.2335, Train Acc: 95.31%, Val Loss:  1.913, Val Acc: 77.65%, Time: 3.13s
# Iter: 1140, Train Loss: 0.1566, Train Acc: 96.88%, Val Loss:  2.006, Val Acc: 74.96%, Time: 7.89s
# Iter: 1170, Train Loss: 0.2011, Train Acc: 95.31%, Val Loss:  1.935, Val Acc: 77.82%, Time: 12.66s
# Epoch: 15
# Iter: 1200, Train Loss:  0.165, Train Acc: 98.44%, Val Loss:  2.002, Val Acc: 74.45%, Time: 3.93s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.57      0.57      0.57         7
#         DESC       0.75      0.65      0.70       131
#         ENTY       0.69      0.70      0.70       140
#          HUM       0.77      0.81      0.79       138
#          LOC       0.75      0.79      0.77        87
#          NUM       0.87      0.90      0.89        92
#
#    micro avg       0.76      0.76      0.76       595
#    macro avg       0.73      0.74      0.74       595
# weighted avg       0.76      0.76      0.76       595
#
# Confusion Matrix...
# [[  4   2   0   0   0   1]
#  [  3  85  21   5  13   4]
#  [  0  11  98  23   5   3]
#  [  0   6  13 112   4   3]
#  [  0   8   6   3  69   1]
#  [  0   1   4   3   1  83]]
# Fold:  9
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.204, Train Acc: 32.81%, Val Loss:  3.307, Val Acc: 22.18%, Time: 5.83s *
# Iter: 60, Train Loss:  2.934, Train Acc: 40.62%, Val Loss:   3.07, Val Acc: 42.69%, Time: 10.66s *
# Epoch: 2
# Iter: 90, Train Loss:  2.538, Train Acc: 50.00%, Val Loss:  2.696, Val Acc: 48.91%, Time: 1.45s *
# Iter: 120, Train Loss:  2.056, Train Acc: 62.50%, Val Loss:   2.39, Val Acc: 56.81%, Time: 6.23s *
# Iter: 150, Train Loss:   1.68, Train Acc: 73.44%, Val Loss:  2.084, Val Acc: 63.19%, Time: 11.05s *
# Epoch: 3
# Iter: 180, Train Loss:  1.651, Train Acc: 68.75%, Val Loss:  1.832, Val Acc: 67.23%, Time: 2.35s *
# Iter: 210, Train Loss:  1.379, Train Acc: 79.69%, Val Loss:  1.689, Val Acc: 71.26%, Time: 7.14s *
# Iter: 240, Train Loss:  1.346, Train Acc: 75.00%, Val Loss:  1.594, Val Acc: 73.61%, Time: 11.89s *
# Epoch: 4
# Iter: 270, Train Loss: 0.9094, Train Acc: 85.94%, Val Loss:  1.482, Val Acc: 75.63%, Time: 3.17s *
# Iter: 300, Train Loss: 0.7378, Train Acc: 90.62%, Val Loss:  1.411, Val Acc: 72.94%, Time: 7.89s
# Iter: 330, Train Loss:  1.155, Train Acc: 82.81%, Val Loss:  1.358, Val Acc: 76.47%, Time: 12.69s *
# Epoch: 5
# Iter: 360, Train Loss: 0.9452, Train Acc: 84.38%, Val Loss:  1.375, Val Acc: 76.47%, Time: 4.01s
# Iter: 390, Train Loss: 0.7509, Train Acc: 87.50%, Val Loss:  1.342, Val Acc: 77.65%, Time: 8.81s *
# Iter: 420, Train Loss: 0.9205, Train Acc: 86.67%, Val Loss:  1.329, Val Acc: 76.13%, Time: 13.58s
# Epoch: 6
# Iter: 450, Train Loss: 0.6289, Train Acc: 90.62%, Val Loss:  1.339, Val Acc: 77.82%, Time: 4.79s *
# Iter: 480, Train Loss: 0.7535, Train Acc: 85.94%, Val Loss:  1.217, Val Acc: 78.82%, Time: 9.56s *
# Epoch: 7
# Iter: 510, Train Loss: 0.7418, Train Acc: 89.06%, Val Loss:  1.285, Val Acc: 77.98%, Time: 1.46s
# Iter: 540, Train Loss: 0.8976, Train Acc: 85.94%, Val Loss:  1.347, Val Acc: 78.49%, Time: 6.28s
# Iter: 570, Train Loss: 0.5516, Train Acc: 92.19%, Val Loss:  1.301, Val Acc: 78.99%, Time: 11.02s *
# Epoch: 8
# Iter: 600, Train Loss: 0.3401, Train Acc: 90.62%, Val Loss:  1.408, Val Acc: 78.66%, Time: 2.34s
# Iter: 630, Train Loss: 0.3782, Train Acc: 95.31%, Val Loss:  1.406, Val Acc: 77.65%, Time: 7.08s
# Iter: 660, Train Loss: 0.2772, Train Acc: 98.44%, Val Loss:  1.365, Val Acc: 77.14%, Time: 11.83s
# Epoch: 9
# Iter: 690, Train Loss: 0.4619, Train Acc: 90.62%, Val Loss:   1.33, Val Acc: 78.99%, Time: 3.17s
# Iter: 720, Train Loss: 0.3693, Train Acc: 95.31%, Val Loss:  1.463, Val Acc: 78.66%, Time: 8.00s
# Iter: 750, Train Loss: 0.3537, Train Acc: 93.75%, Val Loss:  1.263, Val Acc: 78.99%, Time: 12.85s
# Epoch: 10
# Iter: 780, Train Loss:  0.392, Train Acc: 93.75%, Val Loss:  1.527, Val Acc: 79.66%, Time: 3.98s *
# Iter: 810, Train Loss: 0.4523, Train Acc: 95.31%, Val Loss:  1.399, Val Acc: 78.99%, Time: 8.78s
# Iter: 840, Train Loss: 0.1751, Train Acc: 97.78%, Val Loss:  1.346, Val Acc: 80.17%, Time: 13.54s *
# Epoch: 11
# Iter: 870, Train Loss: 0.2651, Train Acc: 93.75%, Val Loss:  1.628, Val Acc: 77.48%, Time: 4.78s
# Iter: 900, Train Loss: 0.3282, Train Acc: 93.75%, Val Loss:  1.622, Val Acc: 80.00%, Time: 9.57s
# Epoch: 12
# Iter: 930, Train Loss: 0.1116, Train Acc: 98.44%, Val Loss:  1.443, Val Acc: 79.16%, Time: 1.48s
# Iter: 960, Train Loss: 0.3088, Train Acc: 95.31%, Val Loss:   1.75, Val Acc: 78.32%, Time: 6.28s
# Iter: 990, Train Loss:  0.151, Train Acc: 96.88%, Val Loss:  1.566, Val Acc: 77.98%, Time: 11.11s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2077, Train Acc: 98.44%, Val Loss:   1.66, Val Acc: 79.33%, Time: 2.31s
# Iter: 1050, Train Loss: 0.1594, Train Acc: 98.44%, Val Loss:  1.611, Val Acc: 78.66%, Time: 7.14s
# Iter: 1080, Train Loss: 0.3532, Train Acc: 92.19%, Val Loss:   1.61, Val Acc: 78.32%, Time: 11.93s
# Epoch: 14
# Iter: 1110, Train Loss: 0.1176, Train Acc: 98.44%, Val Loss:  1.643, Val Acc: 78.49%, Time: 3.19s
# Iter: 1140, Train Loss:  0.232, Train Acc: 95.31%, Val Loss:  1.708, Val Acc: 78.82%, Time: 8.02s
# Iter: 1170, Train Loss: 0.1263, Train Acc: 98.44%, Val Loss:  1.652, Val Acc: 79.83%, Time: 12.81s
# Epoch: 15
# Iter: 1200, Train Loss: 0.1031, Train Acc: 98.44%, Val Loss:  1.799, Val Acc: 79.33%, Time: 3.97s
# Iter: 1230, Train Loss: 0.08312, Train Acc: 98.44%, Val Loss:  1.841, Val Acc: 78.15%, Time: 8.78s
# Iter: 1260, Train Loss: 0.1007, Train Acc: 97.78%, Val Loss:  1.659, Val Acc: 79.66%, Time: 13.64s
# Epoch: 16
# Iter: 1290, Train Loss: 0.3661, Train Acc: 93.75%, Val Loss:  1.799, Val Acc: 77.31%, Time: 4.77s
# Iter: 1320, Train Loss: 0.1738, Train Acc: 96.88%, Val Loss:  1.895, Val Acc: 76.64%, Time: 9.55s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.83      0.83      0.83        12
#         DESC       0.74      0.77      0.75       146
#         ENTY       0.70      0.75      0.72       107
#          HUM       0.78      0.84      0.81       133
#          LOC       0.92      0.69      0.79        94
#          NUM       0.87      0.85      0.86       103
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.81      0.79      0.79       595
# weighted avg       0.79      0.78      0.79       595
#
# Confusion Matrix...
# [[ 10   2   0   0   0   0]
#  [  1 112  18   9   1   5]
#  [  0  13  80  11   0   3]
#  [  0   6  10 112   3   2]
#  [  0  14   5   7  65   3]
#  [  1   5   2   5   2  88]]
# Fold:  10
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.428, Train Acc: 23.44%, Val Loss:  3.277, Val Acc: 28.74%, Time: 5.90s *
# Iter: 60, Train Loss:  3.014, Train Acc: 35.94%, Val Loss:  3.117, Val Acc: 31.60%, Time: 10.71s *
# Epoch: 2
# Iter: 90, Train Loss:  2.623, Train Acc: 51.56%, Val Loss:  2.706, Val Acc: 50.42%, Time: 1.48s *
# Iter: 120, Train Loss:  2.021, Train Acc: 67.19%, Val Loss:  2.412, Val Acc: 54.79%, Time: 6.35s *
# Iter: 150, Train Loss:  2.085, Train Acc: 64.06%, Val Loss:  2.162, Val Acc: 57.48%, Time: 11.13s *
# Epoch: 3
# Iter: 180, Train Loss:  1.499, Train Acc: 73.44%, Val Loss:  1.828, Val Acc: 67.06%, Time: 2.31s *
# Iter: 210, Train Loss:   1.27, Train Acc: 79.69%, Val Loss:  1.668, Val Acc: 69.75%, Time: 7.07s *
# Iter: 240, Train Loss:  1.538, Train Acc: 73.44%, Val Loss:  1.536, Val Acc: 72.10%, Time: 11.85s *
# Epoch: 4
# Iter: 270, Train Loss: 0.9801, Train Acc: 84.38%, Val Loss:  1.461, Val Acc: 72.61%, Time: 3.13s *
# Iter: 300, Train Loss: 0.9839, Train Acc: 82.81%, Val Loss:  1.496, Val Acc: 73.95%, Time: 7.92s *
# Iter: 330, Train Loss: 0.9858, Train Acc: 87.50%, Val Loss:  1.315, Val Acc: 75.29%, Time: 12.67s *
# Epoch: 5
# Iter: 360, Train Loss: 0.8946, Train Acc: 84.38%, Val Loss:   1.37, Val Acc: 75.29%, Time: 4.04s *
# Iter: 390, Train Loss: 0.7456, Train Acc: 90.62%, Val Loss:  1.426, Val Acc: 76.81%, Time: 8.86s *
# Iter: 420, Train Loss:   0.29, Train Acc: 100.00%, Val Loss:  1.259, Val Acc: 77.14%, Time: 13.69s *
# Epoch: 6
# Iter: 450, Train Loss: 0.5836, Train Acc: 92.19%, Val Loss:  1.272, Val Acc: 75.80%, Time: 4.78s
# Iter: 480, Train Loss: 0.7912, Train Acc: 85.94%, Val Loss:  1.283, Val Acc: 78.32%, Time: 9.58s *
# Epoch: 7
# Iter: 510, Train Loss: 0.4759, Train Acc: 92.19%, Val Loss:   1.27, Val Acc: 77.82%, Time: 1.48s
# Iter: 540, Train Loss: 0.7247, Train Acc: 87.50%, Val Loss:  1.286, Val Acc: 76.47%, Time: 6.26s
# Iter: 570, Train Loss: 0.7039, Train Acc: 89.06%, Val Loss:  1.346, Val Acc: 76.64%, Time: 11.05s
# Epoch: 8
# Iter: 600, Train Loss: 0.3924, Train Acc: 93.75%, Val Loss:   1.36, Val Acc: 77.14%, Time: 2.34s
# Iter: 630, Train Loss:  0.408, Train Acc: 89.06%, Val Loss:  1.369, Val Acc: 77.65%, Time: 7.15s
# Iter: 660, Train Loss: 0.5051, Train Acc: 92.19%, Val Loss:  1.343, Val Acc: 77.14%, Time: 11.97s
# Epoch: 9
# Iter: 690, Train Loss: 0.3953, Train Acc: 92.19%, Val Loss:  1.385, Val Acc: 80.00%, Time: 3.11s *
# Iter: 720, Train Loss: 0.3278, Train Acc: 95.31%, Val Loss:  1.415, Val Acc: 77.48%, Time: 7.90s
# Iter: 750, Train Loss: 0.1624, Train Acc: 100.00%, Val Loss:  1.413, Val Acc: 77.65%, Time: 12.73s
# Epoch: 10
# Iter: 780, Train Loss: 0.1398, Train Acc: 96.88%, Val Loss:  1.417, Val Acc: 77.82%, Time: 3.96s
# Iter: 810, Train Loss: 0.3879, Train Acc: 90.62%, Val Loss:  1.652, Val Acc: 77.48%, Time: 8.77s
# Iter: 840, Train Loss:  0.237, Train Acc: 97.78%, Val Loss:  1.452, Val Acc: 77.31%, Time: 13.58s
# Epoch: 11
# Iter: 870, Train Loss: 0.2815, Train Acc: 93.75%, Val Loss:  1.521, Val Acc: 77.65%, Time: 4.76s
# Iter: 900, Train Loss: 0.2357, Train Acc: 96.88%, Val Loss:  1.442, Val Acc: 78.82%, Time: 9.57s
# Epoch: 12
# Iter: 930, Train Loss: 0.1432, Train Acc: 98.44%, Val Loss:  1.611, Val Acc: 77.48%, Time: 1.48s
# Iter: 960, Train Loss: 0.1396, Train Acc: 96.88%, Val Loss:  1.635, Val Acc: 77.65%, Time: 6.24s
# Iter: 990, Train Loss:  0.159, Train Acc: 98.44%, Val Loss:  1.652, Val Acc: 77.98%, Time: 11.00s
# Epoch: 13
# Iter: 1020, Train Loss: 0.2769, Train Acc: 93.75%, Val Loss:   1.75, Val Acc: 76.47%, Time: 2.28s
# Iter: 1050, Train Loss: 0.09335, Train Acc: 98.44%, Val Loss:  1.874, Val Acc: 76.97%, Time: 7.01s
# Iter: 1080, Train Loss: 0.05907, Train Acc: 100.00%, Val Loss:  1.744, Val Acc: 76.13%, Time: 11.83s
# Epoch: 14
# Iter: 1110, Train Loss: 0.4509, Train Acc: 90.62%, Val Loss:  1.751, Val Acc: 77.14%, Time: 3.16s
# Iter: 1140, Train Loss: 0.1318, Train Acc: 100.00%, Val Loss:  1.785, Val Acc: 77.14%, Time: 7.93s
# Iter: 1170, Train Loss: 0.1949, Train Acc: 96.88%, Val Loss:  1.869, Val Acc: 78.15%, Time: 12.71s
# Epoch: 15
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.83      0.45      0.59        11
#         DESC       0.78      0.64      0.71       132
#         ENTY       0.72      0.72      0.72       120
#          HUM       0.75      0.92      0.82       131
#          LOC       0.78      0.75      0.76       104
#          NUM       0.85      0.88      0.86        97
#
#    micro avg       0.77      0.77      0.77       595
#    macro avg       0.79      0.73      0.74       595
# weighted avg       0.77      0.77      0.77       595
#
# Confusion Matrix...
# [[  5   1   1   4   0   0]
#  [  1  85  23   8  10   5]
#  [  0  10  86  15   5   4]
#  [  0   3   2 120   4   2]
#  [  0   7   4  11  78   4]
#  [  0   3   3   3   3  85]]
# [0.010067114093959731, 0.010067114093959731, 0.015126050420168067, 0.025210084033613446, 0.013445378151260505, 0.018487394957983194, 0.01680672268907563, 0.011764705882352941, 0.020168067226890758, 0.018487394957983194]
# 0.01596300265072472, 0.004591684662473479, 0.004840060610225889, 2.1083568039594188e-05
# [0.010067114093959731,
#  0.010067114093959731,
#  0.015126050420168067,
#  0.025210084033613446,
#  0.013445378151260505,
#  0.018487394957983194,
#  0.01680672268907563,
#  0.011764705882352941,
#  0.020168067226890758,
#  0.018487394957983194]
