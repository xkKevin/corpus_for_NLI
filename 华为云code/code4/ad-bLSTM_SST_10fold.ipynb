# %%
import numpy as np
import tensorflow as tf
import sys
import time
from datetime import timedelta
import tensorflow.contrib.keras as kr
from sklearn import metrics
from sklearn.model_selection import KFold

import moxing as mox
mox.file.shift('os', 'mox')
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2

# %%
trainDataPath = "s3://corpus-2/dataset/SST.txt"
vocabPath = "s3://corpus-text-classification1/data/glove.6B.100d.txt"

# %%
def readfile(filePath):
    """读取文件内容，返回文本和标签列表"""
    train_data = []
    seq_length = 0
    with open(filePath, 'r', encoding='utf-8') as f:
        for line in f.readlines():
            word = line.strip().split()
            label = int(word[0])
            content = word[1:]
            train_data.append([content,label])
            
            if (len(content) > seq_length):
                seq_length = len(content)
    
    np.random.shuffle(train_data)
    return np.asarray(train_data), seq_length


def loadGloVe(filename):
    vocab = []
    embd = []
    print('Loading GloVe!')
    # vocab.append('unk') #装载不认识的词
    # embd.append([0] * emb_size) #这个emb_size可能需要指定
    file = open(filename,'r',encoding='utf-8')
    for line in file.readlines():
        row = line.strip().split(' ')
        vocab.append(row[0])
        embd.append([float(ei) for ei in row[1:]])
    file.close()
    print('Completed!')
    return vocab,embd


def process_file(contents, labels, word_to_id, num_classes, pad_max_length):
    """
    将文件转换为id表示,并且将每个单独的样本长度固定为pad_max_lengtn
    """
    # contents, labels = readfile(filePath)
    data_id, label_id = [], []
    # 将文本内容转换为对应的id形式
    for i in range(len(contents)):
        data_id.append([word_to_id[x] for x in contents[i] if x in word_to_id])
        label_id.append(labels[i])  # label_id.append(cat_to_id[labels[i]])
    # 使用keras提供的pad_sequences来将文本pad为固定长度
    x_pad = kr.preprocessing.sequence.pad_sequences(data_id, pad_max_length)
    ''' https://blog.csdn.net/TH_NUM/article/details/80904900
    pad_sequences(sequences, maxlen=None, dtype=’int32’, padding=’pre’, truncating=’pre’, value=0.) 
        sequences：浮点数或整数构成的两层嵌套列表
        maxlen：None或整数，为序列的最大长度。大于此长度的序列将被截短，小于此长度的序列将在后部填0.
        dtype：返回的numpy array的数据类型
        padding：‘pre’或‘post’，确定当需要补0时，在序列的起始还是结尾补
        truncating：‘pre’或‘post’，确定当需要截断序列时，从起始还是结尾截断
        value：浮点数，此值将在填充时代替默认的填充值0
    '''
    y_pad = kr.utils.to_categorical(label_id, num_classes=num_classes)  # 将标签转换为one-hot表示
    ''' https://blog.csdn.net/nima1994/article/details/82468965
    to_categorical(y, num_classes=None, dtype='float32')
        将整型标签转为onehot。y为int数组，num_classes为标签类别总数，大于max(y)（标签从0开始的）。
        返回：如果num_classes=None，返回len(y) * [max(y)+1]（维度，m*n表示m行n列矩阵，下同），否则为len(y) * num_classes。
    '''
    return x_pad, y_pad

# %%
categories = ['very negative', 'negative', 'neutral', 'positive', 'very positive']
num_classes = len(categories)

vocab, embd = loadGloVe(vocabPath)
vocab_size = len(vocab)
embedding_dim = len(embd[0])
embedding = np.asarray(embd)
word_to_id = dict(zip(vocab, range(vocab_size)))

print(len(embedding),embedding_dim,vocab_size)

trainData, seq_length = readfile(trainDataPath)
print(len(trainData), seq_length)

# seq_length = 37
# Out:
# Loading GloVe!
# Completed!
# 400000 100 400000
# 11748 56

# %%
def train_split_data(model, train_data, categories):
    test_acc = []
    fold_id = 0

    tx, ty = process_file(train_data[:,0], train_data[:,1], word_to_id, num_classes, seq_length)
    print(len(tx),len(tx[0]),len(tx[1]))

    kf = KFold(n_splits=10)
    for train_i, test_i in kf.split(tx):
        fold_id += 1
        print("Fold: ", fold_id)
        test_acc.append(model_train(model,tx[train_i], ty[train_i],tx[test_i], ty[test_i],categories))
        
    print(test_acc)
    print("%s, %s, %s, %s" % (np.mean(test_acc),np.std(test_acc),np.std(test_acc,ddof=1),np.var(test_acc)))
    return test_acc


def batch_iter(x_pad, y_pad, batch_size):
    """生成批次数据"""
    data_len = len(x_pad)
    num_batch = int((data_len - 1) / batch_size) + 1
    # np.arange()生成0到data_len的等差数列，默认等差为1；np.random.permutation()打乱生成的等差序列的顺序
    # 下面三句语句是为了将训练或测试文本的顺序打乱，因为原文本中每个分类的样本全部挨在一起，这样每个batch训练的都是同一个分类，不太好，打乱后每个batch可包含不同分类
    indices = np.random.permutation(np.arange(data_len))
    x_shuffle = x_pad[indices]
    y_shuffle = y_pad[indices]

    # 返回所有batch的数据
    for i in range(num_batch):
        start_id = i * batch_size
        end_id = min((i + 1) * batch_size, data_len)
        yield x_shuffle[start_id:end_id], y_shuffle[start_id:end_id]
        
        
def evaluate(sess, model, x_pad, y_pad, loss1, acc1, batch_size):
    """评估在某一数据上的准确率和损失"""
    data_len = len(x_pad)
    batch_eval = batch_iter(x_pad, y_pad, batch_size)  # 128
    total_loss = 0.0
    total_acc = 0.0
    for x_batch1, y_batch1 in batch_eval:
        batch_len = len(x_batch1)
        feed_dict1 = {model.inputX: x_batch1, model.inputY: y_batch1, model.dropoutKeepProb: 1.0}
        lossTmp, accTmp = sess.run([loss1, acc1], feed_dict=feed_dict1)
        total_loss += lossTmp * batch_len
        total_acc += accTmp * batch_len

    return total_loss / data_len, total_acc / data_len


def model_train(model, x_train, y_train, x_val, y_val, categories):
    
    # save_path = "%s/%s/%s/%s" % (savePath, split_type, fold_id, fold_id)
    # 创建session
    session = tf.Session()
    session.run(tf.global_variables_initializer())

    print('Training and evaluating...')
    
    total_batch = 0  # 总批次
    best_acc_train = 0.0  # 最佳验证集准确率
    last_improved = 0  # 记录上一次提升批次
    require_improvement = 500  # 如果超过1000轮未提升，提前结束训练
    flag = False

    for epoch in range(num_epochs):  # 20
        start_time = time.time()
        
        print('Epoch:', epoch + 1)
        batch_train = batch_iter(x_train, y_train, batch_size)
        for x_batch, y_batch in batch_train:
            feed_dict = {model.inputX: x_batch, model.inputY: y_batch, model.dropoutKeepProb: dropout_keep_prob}
            session.run(model.trainOp, feed_dict=feed_dict)  # 运行优化
            total_batch += 1

            if total_batch % print_per_batch == 0:
                # 每多少轮次输出在训练集和验证集上的性能
                feed_dict[model.dropoutKeepProb] = 1.0
                loss_train, acc_train = session.run([model.loss, model.acc], feed_dict=feed_dict)
                loss_val, acc_val = evaluate(session, model, x_val, y_val, model.loss, model.acc, 64)
                if acc_val > best_acc_train:
                    # 保存最好结果
                    best_acc_train = acc_val
                    last_improved = total_batch
                    # saver.save(sess=session, save_path=save_path)
                    improved_str = '*'
                else:
                    improved_str = ''
                
                duration = time.time() - start_time
                output = 'Iter: {:>1}, Train Loss: {:>6.4}, Train Acc: {:>6.2%}, Val Loss: {:>6.4}, Val Acc: {:>6.2%}, Time: {:.2f}s {}'
                print(output.format(total_batch, loss_train, acc_train, loss_val, acc_val, duration, improved_str))

            if total_batch - last_improved > require_improvement:
                # 验证集正确率长期不提升，提前结束训练
                print("No optimization for a long time, auto-stopping...")
                
                test_data_len = len(x_val)
                test_num_batch = int((test_data_len - 1) / batch_size) + 1

                y_test_cls = np.argmax(y_val, 1)  # 获得类别
                y_test_pred_cls = np.zeros(shape=len(x_val), dtype=np.int32)  # 保存预测结果  len(x_test) 表示有多少个文本
                accuracy_score = metrics.accuracy_score(y_test_cls, y_test_pred_cls)

                for i in range(test_num_batch):  # 逐批次处理
                    start_id = i * batch_size
                    end_id = min((i + 1) * batch_size, test_data_len)
                    feed_dict = {
                        model.inputX: x_val[start_id:end_id],
                        model.dropoutKeepProb: 1.0
                    }
                    y_test_pred_cls[start_id:end_id] = session.run(model.y_pred_cls, feed_dict=feed_dict)

                # 评估
                print("Precision, Recall and F1-Score...")
                print(metrics.classification_report(y_test_cls, y_test_pred_cls, target_names=categories))
                '''
                sklearn中的classification_report函数用于显示主要分类指标的文本报告．在报告中显示每个类的精确度，召回率，F1值等信息。
                    y_true：1维数组，或标签指示器数组/稀疏矩阵，目标值。 
                    y_pred：1维数组，或标签指示器数组/稀疏矩阵，分类器返回的估计值。 
                    labels：array，shape = [n_labels]，报表中包含的标签索引的可选列表。 
                    target_names：字符串列表，与标签匹配的可选显示名称（相同顺序）。 
                    原文链接：https://blog.csdn.net/akadiao/article/details/78788864
                '''

                # 混淆矩阵
                print("Confusion Matrix...")
                cm = metrics.confusion_matrix(y_test_cls, y_test_pred_cls)
                '''
                混淆矩阵是机器学习中总结分类模型预测结果的情形分析表，以矩阵形式将数据集中的记录按照真实的类别与分类模型作出的分类判断两个标准进行汇总。
                这个名字来源于它可以非常容易的表明多个类别是否有混淆（也就是一个class被预测成另一个class）
                https://blog.csdn.net/u011734144/article/details/80277225
                '''
                print(cm)
                
                flag = True
                break  # 跳出循环
        if flag:  # 同上
            break

    session.close()
    return accuracy_score

# %%
# 构建adversarailLSTM模型
class AdversarailLSTM(object):

    def __init__(self, wordEmbedding):
        # 定义输入
        self.inputX = tf.placeholder(tf.int32, [None, seq_length], name='inputX')
        self.inputY = tf.placeholder(tf.int32, [None, num_classes], name='inputY')

        self.dropoutKeepProb = tf.placeholder(tf.float64, name='keep_prob')

        # 词嵌入层
        with tf.name_scope("wordEmbedding"):
            wordEmbedding = tf.Variable(initial_value=wordEmbedding)
            self.embeddedWords = tf.nn.embedding_lookup(wordEmbedding, self.inputX)

        # 计算softmax交叉熵损失
        with tf.name_scope("loss"):
            with tf.variable_scope("Bi-LSTM", reuse=None):
                self.predictions = self._Bi_LSTMAttention(self.embeddedWords)
                # self.y_pred_cls = tf.cast(tf.greater_equal(self.predictions, 0.5), tf.float32, name="binaryPreds")
                self.y_pred_cls = tf.argmax(tf.nn.softmax(self.predictions),1)  # 预测类别 tf.argmax：返回每一行或每一列的最大值 1为里面（每一行），0为外面（每一列）
                # losses = tf.nn.sigmoid_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
                losses = tf.nn.softmax_cross_entropy_with_logits(logits=self.predictions, labels=self.inputY)
                loss = tf.reduce_mean(losses)

        
        with tf.name_scope("perturloss"):
            with tf.variable_scope("Bi-LSTM", reuse=True):
                perturWordEmbedding = self._addPerturbation(self.embeddedWords, loss)
                print("perturbSize:{}".format(perturWordEmbedding))
                perturPredictions = self._Bi_LSTMAttention(perturWordEmbedding)
                # perturLosses = tf.nn.sigmoid_cross_entropy_with_logits(logits=perturPredictions, labels=self.inputY)
                perturLosses = tf.nn.softmax_cross_entropy_with_logits(logits=perturPredictions, labels=self.inputY)
                perturLoss = tf.reduce_mean(perturLosses)

        self.loss = loss + perturLoss
        
        globalStep = tf.Variable(0, name="globalStep", trainable=False)
        # 定义优化函数，传入学习速率参数
        optimizer = tf.train.AdamOptimizer(learning_rate)
        # 计算梯度,得到梯度和变量
        gradsAndVars = optimizer.compute_gradients(self.loss)
        # 将梯度应用到变量下，生成训练器
        self.trainOp = optimizer.apply_gradients(gradsAndVars, global_step=globalStep)

        # 准确率
        correct_pred = tf.equal(tf.argmax(self.inputY, 1), self.y_pred_cls)
        self.acc = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
        
        # self.loss = loss
        
        
    def _Bi_LSTMAttention(self, embeddedWords):
        # 定义两层双向LSTM的模型结构
        with tf.name_scope("Bi-LSTM"):
            fwHiddenLayers = []
            bwHiddenLayers = []
            for idx, hiddenSize in enumerate(hiddenSizes):
                with tf.name_scope("Bi-LSTM" + str(idx)):
                    # 定义前向网络结构
                    lstmFwCell = tf.nn.rnn_cell.DropoutWrapper(
                        tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                        output_keep_prob=self.dropoutKeepProb)

                    # 定义反向网络结构
                    lstmBwCell = tf.nn.rnn_cell.DropoutWrapper(
                        tf.nn.rnn_cell.LSTMCell(num_units=hiddenSize, state_is_tuple=True),
                        output_keep_prob=self.dropoutKeepProb)

                fwHiddenLayers.append(lstmFwCell)
                bwHiddenLayers.append(lstmBwCell)

            # 实现多层的LSTM结构， state_is_tuple=True，则状态会以元祖的形式组合(h, c)，否则列向拼接
            fwMultiLstm = tf.nn.rnn_cell.MultiRNNCell(cells=fwHiddenLayers, state_is_tuple=True)
            bwMultiLstm = tf.nn.rnn_cell.MultiRNNCell(cells=bwHiddenLayers, state_is_tuple=True)
            # 采用动态rnn，可以动态地输入序列的长度，若没有输入，则取序列的全长
            # outputs是一个元组(output_fw, output_bw), 其中两个元素的维度都是[batch_size, max_time, hidden_size], fw和bw的hiddensize一样
            # self.current_state是最终的状态，二元组(state_fw, state_bw), state_fw=[batch_size, s], s是一个元组(h, c)
            outputs, self.current_state = tf.nn.bidirectional_dynamic_rnn(fwMultiLstm, bwMultiLstm,
                                                                          self.embeddedWords, dtype=tf.float64,
                                                                          scope="bi-lstm" + str(idx))

        # 在bi-lstm+attention论文中，将前向和后向的输出相加
        with tf.name_scope("Attention"):
            H = outputs[0] + outputs[1]

            # 得到attention的输出
            output = self.attention(H)
            outputSize = hiddenSizes[-1]
            print("outputSize:{}".format(outputSize))

        # 全连接层的输出
        with tf.name_scope("output"):
            outputW = tf.get_variable(
                "outputW", dtype=tf.float64,
                shape=[outputSize, num_classes],
                initializer=tf.contrib.layers.xavier_initializer())

            outputB = tf.Variable(tf.constant(0.1, dtype=tf.float64, shape=[num_classes]), name="outputB")

            predictions = tf.nn.xw_plus_b(output, outputW, outputB, name="predictions")

            return predictions

    def attention(self, H):
        """
        利用Attention机制得到句子的向量表示
        """
        # 获得最后一层lstm神经元的数量
        hiddenSize = hiddenSizes[-1]

        # 初始化一个权重向量，是可训练的参数
        W = tf.Variable(tf.random_normal([hiddenSize], stddev=0.1, dtype=tf.float64))

        # 对bi-lstm的输出用激活函数做非线性转换
        M = tf.tanh(H)

        # 对W和M做矩阵运算，W=[batch_size, time_step, hidden_size], 计算前做维度转换成[batch_size * time_step, hidden_size]
        # newM = [batch_size, time_step, 1], 每一个时间步的输出由向量转换成一个数字
        newM = tf.matmul(tf.reshape(M, [-1, hiddenSize]), tf.reshape(W, [-1, 1]))

        # 对newM做维度转换成[batch_size, time_step]
        restoreM = tf.reshape(newM, [-1, seq_length])

        # 用softmax做归一化处理[batch_size, time_step]
        self.alpha = tf.nn.softmax(restoreM)

        # 利用求得的alpha的值对H进行加权求和，用矩阵运算直接操作
        r = tf.matmul(tf.transpose(H, [0, 2, 1]), tf.reshape(self.alpha, [-1, seq_length, 1]))

        # 将三维压缩成二维sequeezeR = [batch_size, hissen_size]
        sequeezeR = tf.squeeze(r)

        sentenceRepren = tf.tanh(sequeezeR)

        # 对attention的输出可以做dropout处理
        output = tf.nn.dropout(sentenceRepren, self.dropoutKeepProb)

        return output

    def _normalize(self, wordEmbedding, weights):
        """
        对word embedding 结合权重做标准化处理
        """
        mean = tf.matmul(weights, wordEmbedding)
        powWordEmbedding = tf.pow(wordEmbedding - mean, 2.)

        var = tf.matmul(weights, powWordEmbedding)
        stddev = tf.sqrt(1e-6 + var)

        return (wordEmbedding - mean) / stddev

    def _addPerturbation(self, embedded, loss):
        """
        添加波动到word embedding
        """
        grad, = tf.gradients(
            loss,
            embedded,
            aggregation_method=tf.AggregationMethod.EXPERIMENTAL_ACCUMULATE_N)
        grad = tf.stop_gradient(grad)
        perturb = self._scaleL2(grad, epsilon)
        # print("perturbSize:{}".format(embedded+perturb))
        return embedded + perturb

    def _scaleL2(self, x, norm_length):
        # shape(x) = [batch, num_step, d]
        # divide x by max(abs(x)) for a numerically stable L2 norm
        # 2norm(x) = a * 2norm(x/a)
        # scale over the full sequence, dim(1, 2)
        alpha = tf.reduce_max(tf.abs(x), (1, 2), keep_dims=True) + 1e-12
        l2_norm = alpha * tf.sqrt(tf.reduce_sum(tf.pow(x / alpha, 2), (1, 2), keep_dims=True) + 1e-6)
        x_unit = x / l2_norm
        return norm_length * x_unit

# %%
hiddenSizes = [128]  # 定义LSTM的隐藏层（一层，128个神经元）
epsilon = 5

num_filters = 256
kernel_size = 5
hidden_dim = 128
learning_rate = 1e-3
dropout_keep_prob = 0.5

num_epochs = 50
batch_size = 64
print_per_batch = 30  # 每多少轮输出一次结果

lstm = AdversarailLSTM(embedding)
# Out:
# outputSize:128
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:23: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:171: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:171: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:172: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From <ipython-input-6-a79079a13536>:172: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# perturbSize:Tensor("perturloss/Bi-LSTM/add_2:0", shape=(?, 56, 100), dtype=float64)
# outputSize:128

# %%
train_split_data(lstm,trainData,categories)
# Out:
# 11748 56 56
# Fold:  1
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.176, Train Acc: 21.88%, Val Loss:  3.144, Val Acc: 29.36%, Time: 10.87s *
# Iter: 60, Train Loss:  3.145, Train Acc: 23.44%, Val Loss:  3.097, Val Acc: 28.09%, Time: 18.53s
# Iter: 90, Train Loss:  2.946, Train Acc: 34.38%, Val Loss:  3.005, Val Acc: 31.74%, Time: 26.20s *
# Iter: 120, Train Loss:  2.984, Train Acc: 34.38%, Val Loss:  2.943, Val Acc: 32.17%, Time: 33.78s *
# Iter: 150, Train Loss:   2.69, Train Acc: 43.75%, Val Loss:  2.844, Val Acc: 37.28%, Time: 41.43s *
# Epoch: 2
# Iter: 180, Train Loss:  2.528, Train Acc: 46.88%, Val Loss:  2.723, Val Acc: 39.32%, Time: 4.39s *
# Iter: 210, Train Loss:   2.52, Train Acc: 42.19%, Val Loss:  2.662, Val Acc: 41.11%, Time: 12.05s *
# Iter: 240, Train Loss:  2.625, Train Acc: 45.31%, Val Loss:  2.617, Val Acc: 42.72%, Time: 19.52s *
# Iter: 270, Train Loss:  2.266, Train Acc: 53.12%, Val Loss:  2.603, Val Acc: 42.47%, Time: 27.16s
# Iter: 300, Train Loss:  2.614, Train Acc: 39.06%, Val Loss:  2.593, Val Acc: 43.32%, Time: 34.85s *
# Iter: 330, Train Loss:  2.479, Train Acc: 40.62%, Val Loss:  2.593, Val Acc: 42.47%, Time: 42.45s
# Epoch: 3
# Iter: 360, Train Loss:  2.166, Train Acc: 57.81%, Val Loss:  2.581, Val Acc: 43.74%, Time: 7.18s *
# Iter: 390, Train Loss:  1.902, Train Acc: 54.69%, Val Loss:  2.595, Val Acc: 41.96%, Time: 14.89s
# Iter: 420, Train Loss:  2.189, Train Acc: 54.69%, Val Loss:  2.587, Val Acc: 43.15%, Time: 22.51s
# Iter: 450, Train Loss:  1.772, Train Acc: 64.06%, Val Loss:  2.602, Val Acc: 44.09%, Time: 30.18s *
# Iter: 480, Train Loss:  2.013, Train Acc: 59.38%, Val Loss:   2.55, Val Acc: 46.38%, Time: 37.76s *
# Epoch: 4
# Iter: 510, Train Loss:  1.889, Train Acc: 65.62%, Val Loss:   2.61, Val Acc: 43.83%, Time: 4.04s
# Iter: 540, Train Loss:  1.834, Train Acc: 62.50%, Val Loss:  2.688, Val Acc: 43.91%, Time: 11.67s
# Iter: 570, Train Loss:  1.885, Train Acc: 60.94%, Val Loss:  2.603, Val Acc: 42.72%, Time: 19.32s
# Iter: 600, Train Loss:  2.037, Train Acc: 56.25%, Val Loss:  2.775, Val Acc: 42.38%, Time: 27.01s
# Iter: 630, Train Loss:  1.792, Train Acc: 62.50%, Val Loss:  2.718, Val Acc: 45.19%, Time: 34.65s
# Iter: 660, Train Loss:  1.842, Train Acc: 60.94%, Val Loss:  2.642, Val Acc: 44.34%, Time: 42.22s
# Epoch: 5
# Iter: 690, Train Loss:  1.328, Train Acc: 73.44%, Val Loss:  2.984, Val Acc: 43.40%, Time: 6.89s
# Iter: 720, Train Loss:  1.669, Train Acc: 71.88%, Val Loss:  2.896, Val Acc: 43.74%, Time: 14.49s
# Iter: 750, Train Loss:  1.497, Train Acc: 73.44%, Val Loss:  2.937, Val Acc: 43.83%, Time: 22.06s
# Iter: 780, Train Loss:  1.556, Train Acc: 65.62%, Val Loss:  2.926, Val Acc: 42.98%, Time: 29.72s
# Iter: 810, Train Loss:  1.333, Train Acc: 71.88%, Val Loss:  2.974, Val Acc: 43.74%, Time: 37.32s
# Epoch: 6
# Iter: 840, Train Loss:  1.295, Train Acc: 79.69%, Val Loss:  3.048, Val Acc: 42.55%, Time: 3.67s
# Iter: 870, Train Loss:  1.228, Train Acc: 75.00%, Val Loss:  3.443, Val Acc: 44.34%, Time: 11.20s
# Iter: 900, Train Loss:  1.026, Train Acc: 81.25%, Val Loss:  3.281, Val Acc: 42.30%, Time: 18.75s
# Iter: 930, Train Loss:  1.383, Train Acc: 75.00%, Val Loss:  3.407, Val Acc: 42.98%, Time: 26.41s
# Iter: 960, Train Loss:  1.431, Train Acc: 67.19%, Val Loss:  3.161, Val Acc: 42.81%, Time: 33.99s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.47      0.31      0.37       160
#      negative       0.40      0.48      0.44       295
#       neutral       0.29      0.34      0.31       236
#      positive       0.47      0.47      0.47       305
# very positive       0.60      0.43      0.50       179
#
#     micro avg       0.42      0.42      0.42      1175
#     macro avg       0.45      0.41      0.42      1175
#  weighted avg       0.44      0.42      0.42      1175
#
# Confusion Matrix...
# [[ 49  81  21   9   0]
#  [ 33 143  79  34   6]
#  [ 17  82  81  49   7]
#  [  6  41  76 144  38]
#  [  0   8  26  68  77]]
# Fold:  2
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.183, Train Acc: 26.56%, Val Loss:  3.124, Val Acc: 26.38%, Time: 8.94s *
# Iter: 60, Train Loss:  3.084, Train Acc: 28.12%, Val Loss:  3.068, Val Acc: 33.28%, Time: 16.63s *
# Iter: 90, Train Loss:  2.946, Train Acc: 35.94%, Val Loss:  2.977, Val Acc: 36.85%, Time: 24.38s *
# Iter: 120, Train Loss:  2.776, Train Acc: 42.19%, Val Loss:  2.821, Val Acc: 40.00%, Time: 31.99s *
# Iter: 150, Train Loss:  2.902, Train Acc: 32.81%, Val Loss:  2.715, Val Acc: 40.00%, Time: 39.65s
# Epoch: 2
# Iter: 180, Train Loss:  2.508, Train Acc: 42.19%, Val Loss:  2.632, Val Acc: 43.15%, Time: 4.47s *
# Iter: 210, Train Loss:  2.485, Train Acc: 45.31%, Val Loss:  2.602, Val Acc: 43.23%, Time: 12.05s *
# Iter: 240, Train Loss:  2.677, Train Acc: 42.19%, Val Loss:  2.565, Val Acc: 43.15%, Time: 19.64s
# Iter: 270, Train Loss:  2.259, Train Acc: 57.81%, Val Loss:  2.524, Val Acc: 44.51%, Time: 27.30s *
# Iter: 300, Train Loss:  2.374, Train Acc: 42.19%, Val Loss:  2.486, Val Acc: 45.87%, Time: 34.95s *
# Iter: 330, Train Loss:  2.368, Train Acc: 46.88%, Val Loss:  2.547, Val Acc: 44.51%, Time: 42.47s
# Epoch: 3
# Iter: 360, Train Loss:  2.099, Train Acc: 53.12%, Val Loss:  2.476, Val Acc: 46.55%, Time: 7.28s *
# Iter: 390, Train Loss:  2.039, Train Acc: 50.00%, Val Loss:  2.458, Val Acc: 45.79%, Time: 14.93s
# Iter: 420, Train Loss:  2.008, Train Acc: 54.69%, Val Loss:  2.458, Val Acc: 45.87%, Time: 22.55s
# Iter: 450, Train Loss:  2.171, Train Acc: 50.00%, Val Loss:  2.448, Val Acc: 46.47%, Time: 30.21s
# Iter: 480, Train Loss:  2.041, Train Acc: 50.00%, Val Loss:  2.422, Val Acc: 46.13%, Time: 37.75s
# Epoch: 4
# Iter: 510, Train Loss:  1.854, Train Acc: 64.06%, Val Loss:  2.488, Val Acc: 45.36%, Time: 4.08s
# Iter: 540, Train Loss:  2.033, Train Acc: 65.62%, Val Loss:  2.613, Val Acc: 44.85%, Time: 11.63s
# Iter: 570, Train Loss:  1.783, Train Acc: 54.69%, Val Loss:   2.55, Val Acc: 45.19%, Time: 19.26s
# Iter: 600, Train Loss:  1.941, Train Acc: 59.38%, Val Loss:  2.478, Val Acc: 45.28%, Time: 26.88s
# Iter: 630, Train Loss:  1.996, Train Acc: 51.56%, Val Loss:  2.593, Val Acc: 45.36%, Time: 34.55s
# Iter: 660, Train Loss:  1.889, Train Acc: 68.75%, Val Loss:  2.528, Val Acc: 45.62%, Time: 42.16s
# Epoch: 5
# Iter: 690, Train Loss:  1.512, Train Acc: 70.31%, Val Loss:  2.683, Val Acc: 44.94%, Time: 6.86s
# Iter: 720, Train Loss:  1.326, Train Acc: 79.69%, Val Loss:   2.73, Val Acc: 45.62%, Time: 14.44s
# Iter: 750, Train Loss:  1.803, Train Acc: 59.38%, Val Loss:  2.816, Val Acc: 45.53%, Time: 22.07s
# Iter: 780, Train Loss:  1.615, Train Acc: 62.50%, Val Loss:  2.814, Val Acc: 43.91%, Time: 29.66s
# Iter: 810, Train Loss:  1.416, Train Acc: 71.88%, Val Loss:  2.789, Val Acc: 44.77%, Time: 37.16s
# Epoch: 6
# Iter: 840, Train Loss:  1.237, Train Acc: 71.88%, Val Loss:  2.862, Val Acc: 43.40%, Time: 3.62s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.40      0.27      0.33       142
#      negative       0.49      0.51      0.50       304
#       neutral       0.31      0.38      0.34       234
#      positive       0.45      0.48      0.46       307
# very positive       0.54      0.40      0.46       188
#
#     micro avg       0.43      0.43      0.43      1175
#     macro avg       0.44      0.41      0.42      1175
#  weighted avg       0.44      0.43      0.43      1175
#
# Confusion Matrix...
# [[ 39  68  24  10   1]
#  [ 38 155  79  29   3]
#  [ 12  66  90  62   4]
#  [  6  20  77 148  56]
#  [  2   5  23  82  76]]
# Fold:  3
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.135, Train Acc: 34.38%, Val Loss:  3.134, Val Acc: 30.13%, Time: 9.01s *
# Iter: 60, Train Loss:  3.113, Train Acc: 29.69%, Val Loss:  3.102, Val Acc: 26.81%, Time: 16.62s
# Iter: 90, Train Loss:  2.894, Train Acc: 42.19%, Val Loss:    3.0, Val Acc: 34.81%, Time: 24.30s *
# Iter: 120, Train Loss:  2.798, Train Acc: 45.31%, Val Loss:  2.877, Val Acc: 38.47%, Time: 32.02s *
# Iter: 150, Train Loss:  2.422, Train Acc: 45.31%, Val Loss:  2.764, Val Acc: 38.81%, Time: 39.65s *
# Epoch: 2
# Iter: 180, Train Loss:  2.451, Train Acc: 46.88%, Val Loss:  2.713, Val Acc: 40.00%, Time: 4.42s *
# Iter: 210, Train Loss:  2.555, Train Acc: 42.19%, Val Loss:  2.635, Val Acc: 41.02%, Time: 12.05s *
# Iter: 240, Train Loss:  2.297, Train Acc: 56.25%, Val Loss:  2.623, Val Acc: 41.79%, Time: 19.82s *
# Iter: 270, Train Loss:  2.382, Train Acc: 51.56%, Val Loss:  2.601, Val Acc: 42.81%, Time: 27.37s *
# Iter: 300, Train Loss:  2.479, Train Acc: 34.38%, Val Loss:  2.596, Val Acc: 41.28%, Time: 35.00s
# Iter: 330, Train Loss:   2.52, Train Acc: 46.88%, Val Loss:  2.539, Val Acc: 42.64%, Time: 42.65s
# Epoch: 3
# Iter: 360, Train Loss:  2.311, Train Acc: 46.88%, Val Loss:  2.612, Val Acc: 43.66%, Time: 7.25s *
# Iter: 390, Train Loss:  1.959, Train Acc: 56.25%, Val Loss:  2.499, Val Acc: 45.70%, Time: 14.79s *
# Iter: 420, Train Loss:   2.33, Train Acc: 53.12%, Val Loss:  2.502, Val Acc: 43.32%, Time: 22.37s
# Iter: 450, Train Loss:  2.103, Train Acc: 53.12%, Val Loss:  2.598, Val Acc: 42.30%, Time: 29.92s
# Iter: 480, Train Loss:  2.374, Train Acc: 46.88%, Val Loss:  2.477, Val Acc: 43.32%, Time: 37.48s
# Epoch: 4
# Iter: 510, Train Loss:  1.804, Train Acc: 59.38%, Val Loss:  2.549, Val Acc: 43.15%, Time: 4.17s
# Iter: 540, Train Loss:  1.839, Train Acc: 57.81%, Val Loss:  2.576, Val Acc: 42.81%, Time: 11.92s
# Iter: 570, Train Loss:  2.024, Train Acc: 60.94%, Val Loss:  2.611, Val Acc: 42.72%, Time: 19.58s
# Iter: 600, Train Loss:  1.594, Train Acc: 67.19%, Val Loss:  2.587, Val Acc: 43.74%, Time: 27.34s
# Iter: 630, Train Loss:  1.989, Train Acc: 51.56%, Val Loss:  2.598, Val Acc: 42.89%, Time: 34.98s
# Iter: 660, Train Loss:  2.194, Train Acc: 45.31%, Val Loss:  2.662, Val Acc: 42.72%, Time: 42.68s
# Epoch: 5
# Iter: 690, Train Loss:  1.465, Train Acc: 68.75%, Val Loss:  2.913, Val Acc: 44.00%, Time: 6.75s
# Iter: 720, Train Loss:  1.797, Train Acc: 57.81%, Val Loss:  2.882, Val Acc: 42.55%, Time: 14.45s
# Iter: 750, Train Loss:  1.615, Train Acc: 68.75%, Val Loss:  2.909, Val Acc: 43.15%, Time: 21.99s
# Iter: 780, Train Loss:  1.911, Train Acc: 56.25%, Val Loss:  2.883, Val Acc: 43.57%, Time: 29.47s
# Iter: 810, Train Loss:   1.47, Train Acc: 64.06%, Val Loss:  2.832, Val Acc: 41.79%, Time: 37.00s
# Epoch: 6
# Iter: 840, Train Loss: 0.9372, Train Acc: 85.94%, Val Loss:  3.047, Val Acc: 39.40%, Time: 3.64s
# Iter: 870, Train Loss:  1.477, Train Acc: 70.31%, Val Loss:   3.02, Val Acc: 40.26%, Time: 11.25s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.40      0.29      0.34       154
#      negative       0.45      0.46      0.46       315
#       neutral       0.25      0.23      0.24       213
#      positive       0.42      0.55      0.47       304
# very positive       0.58      0.46      0.51       189
#
#     micro avg       0.42      0.42      0.42      1175
#     macro avg       0.42      0.40      0.40      1175
#  weighted avg       0.42      0.42      0.41      1175
#
# Confusion Matrix...
# [[ 45  71  25  13   0]
#  [ 47 145  60  57   6]
#  [ 12  72  48  74   7]
#  [  7  27  53 166  51]
#  [  2   7   8  85  87]]
# Fold:  4
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.104, Train Acc: 34.38%, Val Loss:  3.198, Val Acc: 24.94%, Time: 8.94s *
# Iter: 60, Train Loss:  3.073, Train Acc: 42.19%, Val Loss:  3.111, Val Acc: 29.19%, Time: 16.67s *
# Iter: 90, Train Loss:  3.066, Train Acc: 35.94%, Val Loss:  3.045, Val Acc: 30.21%, Time: 24.35s *
# Iter: 120, Train Loss:   2.91, Train Acc: 35.94%, Val Loss:  2.872, Val Acc: 37.11%, Time: 31.95s *
# Iter: 150, Train Loss:  2.664, Train Acc: 43.75%, Val Loss:   2.76, Val Acc: 40.60%, Time: 39.61s *
# Epoch: 2
# Iter: 180, Train Loss:   2.64, Train Acc: 37.50%, Val Loss:   2.74, Val Acc: 40.26%, Time: 4.43s
# Iter: 210, Train Loss:  2.537, Train Acc: 46.88%, Val Loss:  2.693, Val Acc: 40.34%, Time: 11.95s
# Iter: 240, Train Loss:  2.463, Train Acc: 51.56%, Val Loss:  2.673, Val Acc: 41.87%, Time: 19.58s *
# Iter: 270, Train Loss:  2.263, Train Acc: 54.69%, Val Loss:  2.576, Val Acc: 42.30%, Time: 27.36s *
# Iter: 300, Train Loss:  2.503, Train Acc: 45.31%, Val Loss:  2.562, Val Acc: 43.23%, Time: 34.97s *
# Iter: 330, Train Loss:  2.573, Train Acc: 50.00%, Val Loss:  2.553, Val Acc: 44.17%, Time: 42.55s *
# Epoch: 3
# Iter: 360, Train Loss:  2.363, Train Acc: 45.31%, Val Loss:  2.551, Val Acc: 43.23%, Time: 7.18s
# Iter: 390, Train Loss:  2.124, Train Acc: 53.12%, Val Loss:  2.511, Val Acc: 43.06%, Time: 14.76s
# Iter: 420, Train Loss:  2.111, Train Acc: 53.12%, Val Loss:  2.571, Val Acc: 43.06%, Time: 22.32s
# Iter: 450, Train Loss:   2.31, Train Acc: 43.75%, Val Loss:  2.472, Val Acc: 44.77%, Time: 30.01s *
# Iter: 480, Train Loss:  2.163, Train Acc: 48.44%, Val Loss:  2.494, Val Acc: 43.57%, Time: 37.66s
# Epoch: 4
# Iter: 510, Train Loss:  1.526, Train Acc: 76.56%, Val Loss:  2.548, Val Acc: 44.43%, Time: 4.10s
# Iter: 540, Train Loss:  1.736, Train Acc: 62.50%, Val Loss:  2.637, Val Acc: 42.81%, Time: 11.74s
# Iter: 570, Train Loss:  1.639, Train Acc: 65.62%, Val Loss:  2.571, Val Acc: 43.15%, Time: 19.42s
# Iter: 600, Train Loss:  1.691, Train Acc: 54.69%, Val Loss:  2.591, Val Acc: 45.70%, Time: 27.06s *
# Iter: 630, Train Loss:  1.533, Train Acc: 68.75%, Val Loss:  2.598, Val Acc: 43.74%, Time: 34.74s
# Iter: 660, Train Loss:   1.99, Train Acc: 57.81%, Val Loss:  2.588, Val Acc: 44.00%, Time: 42.32s
# Epoch: 5
# Iter: 690, Train Loss:  1.332, Train Acc: 71.88%, Val Loss:  2.833, Val Acc: 42.98%, Time: 6.86s
# Iter: 720, Train Loss:  1.689, Train Acc: 64.06%, Val Loss:    2.8, Val Acc: 44.77%, Time: 14.60s
# Iter: 750, Train Loss:  1.509, Train Acc: 71.88%, Val Loss:  2.966, Val Acc: 42.72%, Time: 22.35s
# Iter: 780, Train Loss:   1.47, Train Acc: 73.44%, Val Loss:  2.989, Val Acc: 45.02%, Time: 29.91s
# Iter: 810, Train Loss:  1.313, Train Acc: 75.00%, Val Loss:  2.849, Val Acc: 44.17%, Time: 37.43s
# Epoch: 6
# Iter: 840, Train Loss:  1.179, Train Acc: 79.69%, Val Loss:  2.948, Val Acc: 44.00%, Time: 3.67s
# Iter: 870, Train Loss:  1.044, Train Acc: 81.25%, Val Loss:  3.247, Val Acc: 43.74%, Time: 11.33s
# Iter: 900, Train Loss:  1.021, Train Acc: 79.69%, Val Loss:  3.179, Val Acc: 41.96%, Time: 18.91s
# Iter: 930, Train Loss:  1.257, Train Acc: 68.75%, Val Loss:   3.29, Val Acc: 41.96%, Time: 26.51s
# Iter: 960, Train Loss:  1.249, Train Acc: 73.44%, Val Loss:  3.276, Val Acc: 43.91%, Time: 34.15s
# Iter: 990, Train Loss: 0.9928, Train Acc: 85.94%, Val Loss:  3.271, Val Acc: 44.26%, Time: 41.80s
# Epoch: 7
# Iter: 1020, Train Loss:  1.102, Train Acc: 85.94%, Val Loss:  3.605, Val Acc: 44.34%, Time: 6.50s
# Iter: 1050, Train Loss: 0.8952, Train Acc: 82.81%, Val Loss:  3.674, Val Acc: 42.89%, Time: 14.24s
# Iter: 1080, Train Loss: 0.8095, Train Acc: 87.50%, Val Loss:  3.654, Val Acc: 42.55%, Time: 21.89s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.38      0.20      0.26       149
#      negative       0.42      0.51      0.46       292
#       neutral       0.31      0.42      0.36       216
#      positive       0.46      0.43      0.45       314
# very positive       0.58      0.44      0.50       204
#
#     micro avg       0.42      0.42      0.42      1175
#     macro avg       0.43      0.40      0.41      1175
#  weighted avg       0.43      0.42      0.42      1175
#
# Confusion Matrix...
# [[ 30  81  27  10   1]
#  [ 30 149  83  27   3]
#  [ 17  64  91  40   4]
#  [  3  51  68 136  56]
#  [  0  10  23  82  89]]
# Fold:  5
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.319, Train Acc: 26.56%, Val Loss:  3.116, Val Acc: 26.98%, Time: 8.90s *
# Iter: 60, Train Loss:  3.085, Train Acc: 25.00%, Val Loss:  3.071, Val Acc: 32.77%, Time: 16.50s *
# Iter: 90, Train Loss:  2.813, Train Acc: 37.50%, Val Loss:  2.964, Val Acc: 35.06%, Time: 24.09s *
# Iter: 120, Train Loss:   3.01, Train Acc: 35.94%, Val Loss:  2.812, Val Acc: 40.77%, Time: 31.66s *
# Iter: 150, Train Loss:  2.706, Train Acc: 42.19%, Val Loss:  2.738, Val Acc: 42.21%, Time: 39.19s *
# Epoch: 2
# Iter: 180, Train Loss:  2.711, Train Acc: 51.56%, Val Loss:  2.629, Val Acc: 46.30%, Time: 4.44s *
# Iter: 210, Train Loss:  2.529, Train Acc: 51.56%, Val Loss:  2.575, Val Acc: 45.79%, Time: 11.98s
# Iter: 240, Train Loss:   2.37, Train Acc: 40.62%, Val Loss:  2.533, Val Acc: 45.28%, Time: 19.62s
# Iter: 270, Train Loss:  2.207, Train Acc: 56.25%, Val Loss:  2.524, Val Acc: 45.79%, Time: 27.14s
# Iter: 300, Train Loss:  2.422, Train Acc: 45.31%, Val Loss:   2.51, Val Acc: 47.66%, Time: 34.68s *
# Iter: 330, Train Loss:  2.417, Train Acc: 45.31%, Val Loss:  2.478, Val Acc: 46.47%, Time: 42.30s
# Epoch: 3
# Iter: 360, Train Loss:  2.481, Train Acc: 48.44%, Val Loss:  2.498, Val Acc: 44.68%, Time: 7.25s
# Iter: 390, Train Loss:  2.054, Train Acc: 51.56%, Val Loss:  2.496, Val Acc: 45.70%, Time: 14.77s
# Iter: 420, Train Loss:  2.169, Train Acc: 53.12%, Val Loss:  2.517, Val Acc: 44.51%, Time: 22.25s
# Iter: 450, Train Loss:  2.233, Train Acc: 50.00%, Val Loss:  2.514, Val Acc: 47.23%, Time: 29.82s
# Iter: 480, Train Loss:   2.11, Train Acc: 51.56%, Val Loss:  2.481, Val Acc: 47.32%, Time: 37.41s
# Epoch: 4
# Iter: 510, Train Loss:  1.983, Train Acc: 53.12%, Val Loss:  2.563, Val Acc: 45.28%, Time: 4.07s
# Iter: 540, Train Loss:  1.665, Train Acc: 67.19%, Val Loss:  2.541, Val Acc: 46.98%, Time: 11.62s
# Iter: 570, Train Loss:  1.632, Train Acc: 71.88%, Val Loss:  2.685, Val Acc: 43.40%, Time: 19.17s
# Iter: 600, Train Loss:  2.023, Train Acc: 60.94%, Val Loss:  2.565, Val Acc: 44.68%, Time: 26.90s
# Iter: 630, Train Loss:   1.99, Train Acc: 57.81%, Val Loss:  2.645, Val Acc: 45.53%, Time: 34.39s
# Iter: 660, Train Loss:  2.026, Train Acc: 62.50%, Val Loss:  2.624, Val Acc: 45.70%, Time: 41.93s
# Epoch: 5
# Iter: 690, Train Loss:  1.499, Train Acc: 76.56%, Val Loss:  2.807, Val Acc: 45.19%, Time: 6.85s
# Iter: 720, Train Loss:  1.387, Train Acc: 71.88%, Val Loss:  3.024, Val Acc: 43.32%, Time: 14.49s
# Iter: 750, Train Loss:  1.448, Train Acc: 68.75%, Val Loss:  2.868, Val Acc: 45.28%, Time: 22.11s
# Iter: 780, Train Loss:  1.452, Train Acc: 70.31%, Val Loss:  2.914, Val Acc: 44.43%, Time: 29.71s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.44      0.33      0.37       147
#      negative       0.49      0.52      0.51       336
#       neutral       0.27      0.22      0.24       211
#      positive       0.46      0.55      0.50       317
# very positive       0.52      0.49      0.50       164
#
#     micro avg       0.45      0.45      0.45      1175
#     macro avg       0.44      0.42      0.43      1175
#  weighted avg       0.44      0.45      0.44      1175
#
# Confusion Matrix...
# [[ 48  63  19  15   2]
#  [ 45 176  59  52   4]
#  [ 13  70  47  67  14]
#  [  3  41  43 175  55]
#  [  1   7   5  71  80]]
# Fold:  6
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.266, Train Acc: 23.44%, Val Loss:  3.127, Val Acc: 29.02%, Time: 8.89s *
# Iter: 60, Train Loss:  3.209, Train Acc: 29.69%, Val Loss:  3.115, Val Acc: 26.98%, Time: 16.38s
# Iter: 90, Train Loss:  3.044, Train Acc: 25.00%, Val Loss:  2.965, Val Acc: 34.98%, Time: 23.97s *
# Iter: 120, Train Loss:  3.032, Train Acc: 28.12%, Val Loss:  2.995, Val Acc: 32.17%, Time: 31.54s
# Iter: 150, Train Loss:  2.773, Train Acc: 32.81%, Val Loss:  2.774, Val Acc: 37.96%, Time: 39.16s *
# Epoch: 2
# Iter: 180, Train Loss:  2.592, Train Acc: 54.69%, Val Loss:  2.752, Val Acc: 40.68%, Time: 4.44s *
# Iter: 210, Train Loss:  2.473, Train Acc: 35.94%, Val Loss:  2.686, Val Acc: 39.66%, Time: 11.97s
# Iter: 240, Train Loss:    2.7, Train Acc: 35.94%, Val Loss:  2.689, Val Acc: 41.45%, Time: 19.53s *
# Iter: 270, Train Loss:  2.543, Train Acc: 43.75%, Val Loss:  2.599, Val Acc: 43.40%, Time: 27.22s *
# Iter: 300, Train Loss:  2.551, Train Acc: 42.19%, Val Loss:  2.598, Val Acc: 42.21%, Time: 34.77s
# Iter: 330, Train Loss:  2.229, Train Acc: 50.00%, Val Loss:  2.588, Val Acc: 44.43%, Time: 42.30s *
# Epoch: 3
# Iter: 360, Train Loss:  2.097, Train Acc: 51.56%, Val Loss:  2.659, Val Acc: 43.06%, Time: 7.26s
# Iter: 390, Train Loss:  2.245, Train Acc: 56.25%, Val Loss:  2.598, Val Acc: 43.06%, Time: 14.96s
# Iter: 420, Train Loss:  1.992, Train Acc: 54.69%, Val Loss:  2.613, Val Acc: 45.19%, Time: 22.63s *
# Iter: 450, Train Loss:  2.136, Train Acc: 50.00%, Val Loss:  2.582, Val Acc: 43.49%, Time: 30.25s
# Iter: 480, Train Loss:  2.042, Train Acc: 56.25%, Val Loss:  2.565, Val Acc: 44.60%, Time: 37.77s
# Epoch: 4
# Iter: 510, Train Loss:  2.075, Train Acc: 59.38%, Val Loss:  2.633, Val Acc: 44.60%, Time: 4.08s
# Iter: 540, Train Loss:  1.656, Train Acc: 65.62%, Val Loss:  2.629, Val Acc: 40.94%, Time: 11.67s
# Iter: 570, Train Loss:  2.058, Train Acc: 53.12%, Val Loss:  2.651, Val Acc: 44.09%, Time: 19.19s
# Iter: 600, Train Loss:  1.888, Train Acc: 56.25%, Val Loss:  2.621, Val Acc: 44.09%, Time: 26.73s
# Iter: 630, Train Loss:  2.188, Train Acc: 51.56%, Val Loss:  2.623, Val Acc: 44.51%, Time: 34.29s
# Iter: 660, Train Loss:  1.758, Train Acc: 64.06%, Val Loss:  2.646, Val Acc: 43.40%, Time: 41.99s
# Epoch: 5
# Iter: 690, Train Loss:  1.418, Train Acc: 73.44%, Val Loss:  2.859, Val Acc: 43.23%, Time: 6.85s
# Iter: 720, Train Loss:  1.724, Train Acc: 68.75%, Val Loss:  2.782, Val Acc: 44.77%, Time: 14.46s
# Iter: 750, Train Loss:  1.235, Train Acc: 78.12%, Val Loss:  2.819, Val Acc: 44.94%, Time: 21.99s
# Iter: 780, Train Loss:  1.534, Train Acc: 76.56%, Val Loss:  2.849, Val Acc: 44.09%, Time: 29.57s
# Iter: 810, Train Loss:  1.408, Train Acc: 65.62%, Val Loss:   2.84, Val Acc: 43.23%, Time: 37.12s
# Epoch: 6
# Iter: 840, Train Loss: 0.9547, Train Acc: 85.94%, Val Loss:  2.962, Val Acc: 43.32%, Time: 3.66s
# Iter: 870, Train Loss:   1.13, Train Acc: 81.25%, Val Loss:  3.145, Val Acc: 43.83%, Time: 11.21s
# Iter: 900, Train Loss:  1.548, Train Acc: 64.06%, Val Loss:  3.167, Val Acc: 42.30%, Time: 18.77s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.51      0.21      0.29       141
#      negative       0.43      0.62      0.51       316
#       neutral       0.29      0.24      0.26       230
#      positive       0.42      0.55      0.48       298
# very positive       0.72      0.34      0.46       190
#
#     micro avg       0.43      0.43      0.43      1175
#     macro avg       0.48      0.39      0.40      1175
#  weighted avg       0.46      0.43      0.42      1175
#
# Confusion Matrix...
# [[ 29  91  10  11   0]
#  [ 19 196  54  45   2]
#  [  6 103  55  65   1]
#  [  2  47  63 164  22]
#  [  1  14   9 101  65]]
# Fold:  7
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.305, Train Acc: 25.00%, Val Loss:  3.186, Val Acc: 30.04%, Time: 8.87s *
# Iter: 60, Train Loss:  3.039, Train Acc: 35.94%, Val Loss:  3.078, Val Acc: 33.45%, Time: 16.39s *
# Iter: 90, Train Loss:  2.986, Train Acc: 28.12%, Val Loss:  2.971, Val Acc: 33.70%, Time: 23.89s *
# Iter: 120, Train Loss:  2.833, Train Acc: 42.19%, Val Loss:  2.827, Val Acc: 38.47%, Time: 31.47s *
# Iter: 150, Train Loss:  2.882, Train Acc: 43.75%, Val Loss:  2.751, Val Acc: 39.15%, Time: 39.13s *
# Epoch: 2
# Iter: 180, Train Loss:  2.356, Train Acc: 46.88%, Val Loss:  2.631, Val Acc: 41.70%, Time: 4.49s *
# Iter: 210, Train Loss:  2.694, Train Acc: 42.19%, Val Loss:   2.65, Val Acc: 40.09%, Time: 12.03s
# Iter: 240, Train Loss:  2.547, Train Acc: 53.12%, Val Loss:  2.645, Val Acc: 40.94%, Time: 19.66s
# Iter: 270, Train Loss:  2.613, Train Acc: 35.94%, Val Loss:  2.573, Val Acc: 42.21%, Time: 27.22s *
# Iter: 300, Train Loss:  2.691, Train Acc: 45.31%, Val Loss:  2.549, Val Acc: 43.66%, Time: 34.79s *
# Iter: 330, Train Loss:  2.585, Train Acc: 42.19%, Val Loss:  2.538, Val Acc: 43.49%, Time: 42.22s
# Epoch: 3
# Iter: 360, Train Loss:  2.375, Train Acc: 42.19%, Val Loss:  2.511, Val Acc: 44.00%, Time: 7.14s *
# Iter: 390, Train Loss:  2.104, Train Acc: 62.50%, Val Loss:  2.576, Val Acc: 44.09%, Time: 14.70s *
# Iter: 420, Train Loss:  2.176, Train Acc: 51.56%, Val Loss:  2.593, Val Acc: 44.60%, Time: 22.25s *
# Iter: 450, Train Loss:  2.186, Train Acc: 48.44%, Val Loss:  2.541, Val Acc: 42.38%, Time: 29.66s
# Iter: 480, Train Loss:  2.186, Train Acc: 56.25%, Val Loss:  2.517, Val Acc: 46.04%, Time: 37.35s *
# Epoch: 4
# Iter: 510, Train Loss:  1.816, Train Acc: 60.94%, Val Loss:  2.466, Val Acc: 46.04%, Time: 4.08s
# Iter: 540, Train Loss:  1.737, Train Acc: 65.62%, Val Loss:  2.552, Val Acc: 44.09%, Time: 11.64s
# Iter: 570, Train Loss:  1.856, Train Acc: 62.50%, Val Loss:  2.533, Val Acc: 45.11%, Time: 19.12s
# Iter: 600, Train Loss:  1.841, Train Acc: 57.81%, Val Loss:  2.602, Val Acc: 44.51%, Time: 26.58s
# Iter: 630, Train Loss:  1.905, Train Acc: 54.69%, Val Loss:  2.524, Val Acc: 44.00%, Time: 34.04s
# Iter: 660, Train Loss:  2.189, Train Acc: 46.88%, Val Loss:  2.576, Val Acc: 44.43%, Time: 41.50s
# Epoch: 5
# Iter: 690, Train Loss:  1.456, Train Acc: 75.00%, Val Loss:  2.772, Val Acc: 43.74%, Time: 6.71s
# Iter: 720, Train Loss:   1.73, Train Acc: 65.62%, Val Loss:  2.858, Val Acc: 44.94%, Time: 14.19s
# Iter: 750, Train Loss:  1.487, Train Acc: 70.31%, Val Loss:  2.731, Val Acc: 43.40%, Time: 21.76s
# Iter: 780, Train Loss:  1.438, Train Acc: 67.19%, Val Loss:  2.822, Val Acc: 45.19%, Time: 29.27s
# Iter: 810, Train Loss:  1.212, Train Acc: 79.69%, Val Loss:  2.807, Val Acc: 42.89%, Time: 36.88s
# Epoch: 6
# Iter: 840, Train Loss:  1.481, Train Acc: 70.31%, Val Loss:  2.897, Val Acc: 44.60%, Time: 3.66s
# Iter: 870, Train Loss:  1.007, Train Acc: 81.25%, Val Loss:  3.042, Val Acc: 44.60%, Time: 11.14s
# Iter: 900, Train Loss:  0.755, Train Acc: 89.06%, Val Loss:  3.168, Val Acc: 44.17%, Time: 18.63s
# Iter: 930, Train Loss:    1.2, Train Acc: 82.81%, Val Loss:  3.103, Val Acc: 45.02%, Time: 26.18s
# Iter: 960, Train Loss:  1.344, Train Acc: 73.44%, Val Loss:   3.04, Val Acc: 44.43%, Time: 33.72s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.54      0.29      0.38       170
#      negative       0.45      0.60      0.52       303
#       neutral       0.38      0.29      0.33       217
#      positive       0.41      0.41      0.41       295
# very positive       0.48      0.56      0.52       190
#
#     micro avg       0.44      0.44      0.44      1175
#     macro avg       0.45      0.43      0.43      1175
#  weighted avg       0.45      0.44      0.44      1175
#
# Confusion Matrix...
# [[ 49  95  11  13   2]
#  [ 33 182  41  35  12]
#  [  5  70  62  65  15]
#  [  3  43  39 122  88]
#  [  1  12   9  61 107]]
# Fold:  8
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:    3.1, Train Acc: 26.56%, Val Loss:  3.144, Val Acc: 27.06%, Time: 8.77s *
# Iter: 60, Train Loss:  3.123, Train Acc: 34.38%, Val Loss:  3.064, Val Acc: 30.81%, Time: 16.38s *
# Iter: 90, Train Loss:  2.924, Train Acc: 35.94%, Val Loss:   2.94, Val Acc: 37.45%, Time: 23.94s *
# Iter: 120, Train Loss:  2.672, Train Acc: 40.62%, Val Loss:  2.805, Val Acc: 40.00%, Time: 31.46s *
# Iter: 150, Train Loss:  2.791, Train Acc: 35.94%, Val Loss:  2.738, Val Acc: 40.09%, Time: 39.05s *
# Epoch: 2
# Iter: 180, Train Loss:  2.536, Train Acc: 50.00%, Val Loss:  2.677, Val Acc: 41.28%, Time: 4.41s *
# Iter: 210, Train Loss:  2.628, Train Acc: 40.62%, Val Loss:  2.633, Val Acc: 44.17%, Time: 11.94s *
# Iter: 240, Train Loss:  2.515, Train Acc: 45.31%, Val Loss:  2.615, Val Acc: 44.77%, Time: 19.50s *
# Iter: 270, Train Loss:  2.248, Train Acc: 51.56%, Val Loss:   2.59, Val Acc: 44.34%, Time: 27.12s
# Iter: 300, Train Loss:  2.527, Train Acc: 45.31%, Val Loss:  2.554, Val Acc: 45.79%, Time: 34.64s *
# Iter: 330, Train Loss:  2.669, Train Acc: 42.19%, Val Loss:  2.524, Val Acc: 46.81%, Time: 42.21s *
# Epoch: 3
# Iter: 360, Train Loss:  2.256, Train Acc: 45.31%, Val Loss:  2.523, Val Acc: 47.23%, Time: 7.08s *
# Iter: 390, Train Loss:   1.83, Train Acc: 56.25%, Val Loss:  2.561, Val Acc: 46.13%, Time: 14.59s
# Iter: 420, Train Loss:  1.993, Train Acc: 59.38%, Val Loss:  2.557, Val Acc: 44.68%, Time: 22.05s
# Iter: 450, Train Loss:  2.313, Train Acc: 51.56%, Val Loss:  2.671, Val Acc: 43.40%, Time: 29.55s
# Iter: 480, Train Loss:  2.134, Train Acc: 59.38%, Val Loss:  2.489, Val Acc: 46.72%, Time: 37.07s
# Epoch: 4
# Iter: 510, Train Loss:  1.707, Train Acc: 65.62%, Val Loss:  2.569, Val Acc: 46.30%, Time: 4.00s
# Iter: 540, Train Loss:  1.655, Train Acc: 60.94%, Val Loss:   2.65, Val Acc: 45.87%, Time: 11.50s
# Iter: 570, Train Loss:  1.723, Train Acc: 62.50%, Val Loss:  2.677, Val Acc: 45.87%, Time: 19.03s
# Iter: 600, Train Loss:  1.894, Train Acc: 59.38%, Val Loss:  2.588, Val Acc: 46.72%, Time: 26.59s
# Iter: 630, Train Loss:  1.626, Train Acc: 64.06%, Val Loss:  2.586, Val Acc: 46.55%, Time: 34.11s
# Iter: 660, Train Loss:  1.984, Train Acc: 60.94%, Val Loss:   2.52, Val Acc: 47.32%, Time: 41.65s *
# Epoch: 5
# Iter: 690, Train Loss:  1.665, Train Acc: 65.62%, Val Loss:   2.89, Val Acc: 45.28%, Time: 6.72s
# Iter: 720, Train Loss:  1.608, Train Acc: 68.75%, Val Loss:  2.763, Val Acc: 45.96%, Time: 14.21s
# Iter: 750, Train Loss:  1.799, Train Acc: 65.62%, Val Loss:  2.787, Val Acc: 46.04%, Time: 21.78s
# Iter: 780, Train Loss:  1.156, Train Acc: 73.44%, Val Loss:  2.905, Val Acc: 45.28%, Time: 29.31s
# Iter: 810, Train Loss:    1.8, Train Acc: 70.31%, Val Loss:  2.774, Val Acc: 45.11%, Time: 36.84s
# Epoch: 6
# Iter: 840, Train Loss:  1.302, Train Acc: 76.56%, Val Loss:  2.937, Val Acc: 43.32%, Time: 3.66s
# Iter: 870, Train Loss: 0.9551, Train Acc: 81.25%, Val Loss:  3.126, Val Acc: 44.00%, Time: 11.12s
# Iter: 900, Train Loss:  1.274, Train Acc: 71.88%, Val Loss:  3.347, Val Acc: 44.26%, Time: 18.58s
# Iter: 930, Train Loss:  1.285, Train Acc: 78.12%, Val Loss:  3.241, Val Acc: 43.91%, Time: 26.03s
# Iter: 960, Train Loss:  1.244, Train Acc: 79.69%, Val Loss:  3.183, Val Acc: 44.17%, Time: 33.63s
# Iter: 990, Train Loss: 0.9373, Train Acc: 81.25%, Val Loss:  3.298, Val Acc: 43.40%, Time: 41.24s
# Epoch: 7
# Iter: 1020, Train Loss: 0.8459, Train Acc: 87.50%, Val Loss:  4.065, Val Acc: 44.34%, Time: 6.24s
# Iter: 1050, Train Loss: 0.8474, Train Acc: 82.81%, Val Loss:  3.809, Val Acc: 42.47%, Time: 13.91s
# Iter: 1080, Train Loss: 0.9628, Train Acc: 82.81%, Val Loss:  3.695, Val Acc: 42.47%, Time: 21.39s
# Iter: 1110, Train Loss: 0.7321, Train Acc: 85.94%, Val Loss:  3.609, Val Acc: 41.96%, Time: 28.85s
# Iter: 1140, Train Loss: 0.9086, Train Acc: 79.69%, Val Loss:  3.597, Val Acc: 43.66%, Time: 36.35s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.33      0.28      0.30       148
#      negative       0.44      0.39      0.41       314
#       neutral       0.30      0.40      0.34       211
#      positive       0.48      0.48      0.48       317
# very positive       0.52      0.49      0.51       185
#
#     micro avg       0.42      0.42      0.42      1175
#     macro avg       0.41      0.41      0.41      1175
#  weighted avg       0.42      0.42      0.42      1175
#
# Confusion Matrix...
# [[ 41  66  27  10   4]
#  [ 50 121  92  42   9]
#  [ 17  59  85  41   9]
#  [ 13  26  65 151  62]
#  [  2   5  18  69  91]]
# Fold:  9
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.162, Train Acc: 29.69%, Val Loss:   3.14, Val Acc: 28.88%, Time: 8.76s *
# Iter: 60, Train Loss:  3.127, Train Acc: 32.81%, Val Loss:  3.067, Val Acc: 33.73%, Time: 16.26s *
# Iter: 90, Train Loss:  3.045, Train Acc: 35.94%, Val Loss:  3.034, Val Acc: 32.54%, Time: 23.72s
# Iter: 120, Train Loss:  2.757, Train Acc: 42.19%, Val Loss:  2.879, Val Acc: 35.69%, Time: 31.20s *
# Iter: 150, Train Loss:  2.659, Train Acc: 43.75%, Val Loss:  2.835, Val Acc: 37.65%, Time: 38.80s *
# Epoch: 2
# Iter: 180, Train Loss:  2.436, Train Acc: 51.56%, Val Loss:  2.785, Val Acc: 38.67%, Time: 4.44s *
# Iter: 210, Train Loss:   2.61, Train Acc: 42.19%, Val Loss:  2.752, Val Acc: 39.78%, Time: 11.96s *
# Iter: 240, Train Loss:   2.57, Train Acc: 43.75%, Val Loss:  2.737, Val Acc: 40.89%, Time: 19.49s *
# Iter: 270, Train Loss:  2.396, Train Acc: 51.56%, Val Loss:  2.683, Val Acc: 42.08%, Time: 27.17s *
# Iter: 300, Train Loss:  2.294, Train Acc: 46.88%, Val Loss:   2.63, Val Acc: 43.44%, Time: 34.69s *
# Iter: 330, Train Loss:  2.611, Train Acc: 48.44%, Val Loss:  2.588, Val Acc: 44.97%, Time: 42.14s *
# Epoch: 3
# Iter: 360, Train Loss:  2.306, Train Acc: 46.88%, Val Loss:  2.595, Val Acc: 45.23%, Time: 7.16s *
# Iter: 390, Train Loss:  2.259, Train Acc: 51.56%, Val Loss:  2.582, Val Acc: 44.72%, Time: 14.64s
# Iter: 420, Train Loss:    2.5, Train Acc: 54.69%, Val Loss:  2.611, Val Acc: 45.66%, Time: 22.17s *
# Iter: 450, Train Loss:  1.882, Train Acc: 60.94%, Val Loss:  2.611, Val Acc: 43.78%, Time: 29.70s
# Iter: 480, Train Loss:  2.392, Train Acc: 50.00%, Val Loss:  2.616, Val Acc: 44.63%, Time: 37.23s
# Epoch: 4
# Iter: 510, Train Loss:  1.832, Train Acc: 68.75%, Val Loss:  2.614, Val Acc: 44.38%, Time: 4.03s
# Iter: 540, Train Loss:  1.824, Train Acc: 64.06%, Val Loss:  2.659, Val Acc: 45.06%, Time: 11.52s
# Iter: 570, Train Loss:  1.525, Train Acc: 68.75%, Val Loss:  2.745, Val Acc: 44.12%, Time: 18.94s
# Iter: 600, Train Loss:  1.742, Train Acc: 67.19%, Val Loss:  2.647, Val Acc: 43.95%, Time: 26.47s
# Iter: 630, Train Loss:   1.93, Train Acc: 56.25%, Val Loss:  2.651, Val Acc: 46.00%, Time: 34.03s *
# Iter: 660, Train Loss:  1.597, Train Acc: 70.31%, Val Loss:  2.652, Val Acc: 44.97%, Time: 41.62s
# Epoch: 5
# Iter: 690, Train Loss:  1.324, Train Acc: 81.25%, Val Loss:  2.816, Val Acc: 45.06%, Time: 6.90s
# Iter: 720, Train Loss:  1.592, Train Acc: 65.62%, Val Loss:  2.924, Val Acc: 44.55%, Time: 14.31s
# Iter: 750, Train Loss:  1.326, Train Acc: 68.75%, Val Loss:  2.873, Val Acc: 45.57%, Time: 21.82s
# Iter: 780, Train Loss:  1.837, Train Acc: 60.94%, Val Loss:  3.101, Val Acc: 44.80%, Time: 29.33s
# Iter: 810, Train Loss:  1.301, Train Acc: 78.12%, Val Loss:  2.876, Val Acc: 44.29%, Time: 36.75s
# Epoch: 6
# Iter: 840, Train Loss:   1.37, Train Acc: 78.12%, Val Loss:  3.011, Val Acc: 44.12%, Time: 3.63s
# Iter: 870, Train Loss:  1.011, Train Acc: 84.38%, Val Loss:  3.422, Val Acc: 42.42%, Time: 11.12s
# Iter: 900, Train Loss:  1.219, Train Acc: 70.31%, Val Loss:  3.276, Val Acc: 44.12%, Time: 18.54s
# Iter: 930, Train Loss:  1.055, Train Acc: 75.00%, Val Loss:  3.293, Val Acc: 43.61%, Time: 26.04s
# Iter: 960, Train Loss: 0.9138, Train Acc: 82.81%, Val Loss:  3.344, Val Acc: 43.44%, Time: 33.47s
# Iter: 990, Train Loss:   1.15, Train Acc: 76.56%, Val Loss:   3.29, Val Acc: 42.67%, Time: 40.95s
# Epoch: 7
# Iter: 1020, Train Loss: 0.8882, Train Acc: 82.81%, Val Loss:   3.98, Val Acc: 40.72%, Time: 6.25s
# Iter: 1050, Train Loss: 0.6342, Train Acc: 89.06%, Val Loss:  3.796, Val Acc: 41.91%, Time: 13.68s
# Iter: 1080, Train Loss: 0.7587, Train Acc: 87.50%, Val Loss:  3.739, Val Acc: 41.65%, Time: 21.12s
# Iter: 1110, Train Loss: 0.8708, Train Acc: 84.38%, Val Loss:  3.909, Val Acc: 41.74%, Time: 28.60s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#                precision    recall  f1-score   support
#
# very negative       0.41      0.31      0.35       141
#      negative       0.45      0.48      0.46       324
#       neutral       0.29      0.37      0.32       233
#      positive       0.47      0.40      0.43       314
# very positive       0.47      0.45      0.46       162
#
#     micro avg       0.41      0.41      0.41      1174
#     macro avg       0.42      0.40      0.41      1174
#  weighted avg       0.42      0.41      0.41      1174
#
# Confusion Matrix...
# [[ 44  67  23   5   2]
#  [ 44 154  86  32   8]
#  [ 10  74  86  49  14]
#  [  7  38  86 125  58]
#  [  2  11  19  57  73]]
# Fold:  10
# Training and evaluating...
# Epoch: 1
# Iter: 30, Train Loss:  3.136, Train Acc: 31.25%, Val Loss:  3.157, Val Acc: 29.64%, Time: 8.75s *
# Iter: 60, Train Loss:  3.041, Train Acc: 37.50%, Val Loss:  3.096, Val Acc: 30.07%, Time: 16.30s *
# Iter: 90, Train Loss:   2.93, Train Acc: 39.06%, Val Loss:  3.013, Val Acc: 34.75%, Time: 23.92s *
# Iter: 120, Train Loss:  2.949, Train Acc: 35.94%, Val Loss:  2.945, Val Acc: 31.94%, Time: 31.46s
# Iter: 150, Train Loss:  2.816, Train Acc: 37.50%, Val Loss:  2.807, Val Acc: 38.42%, Time: 38.99s *
# Epoch: 2
# Iter: 180, Train Loss:  2.386, Train Acc: 56.25%, Val Loss:  2.707, Val Acc: 40.72%, Time: 4.50s *
# Iter: 210, Train Loss:  2.559, Train Acc: 43.75%, Val Loss:  2.726, Val Acc: 40.12%, Time: 12.07s
# Iter: 240, Train Loss:  2.337, Train Acc: 40.62%, Val Loss:  2.661, Val Acc: 41.91%, Time: 19.54s *
# Iter: 270, Train Loss:  2.558, Train Acc: 53.12%, Val Loss:  2.625, Val Acc: 40.03%, Time: 27.03s
# Iter: 300, Train Loss:  2.374, Train Acc: 42.19%, Val Loss:  2.604, Val Acc: 42.93%, Time: 34.48s *
# Iter: 330, Train Loss:  2.367, Train Acc: 39.06%, Val Loss:  2.589, Val Acc: 43.02%, Time: 42.21s *
# Epoch: 3
# Iter: 360, Train Loss:  2.072, Train Acc: 54.69%, Val Loss:  2.576, Val Acc: 43.10%, Time: 7.12s *
# Iter: 390, Train Loss:  2.044, Train Acc: 46.88%, Val Loss:   2.55, Val Acc: 43.02%, Time: 14.64s
# Iter: 420, Train Loss:  2.234, Train Acc: 48.44%, Val Loss:  2.551, Val Acc: 42.67%, Time: 22.19s
# Iter: 450, Train Loss:  1.941, Train Acc: 62.50%, Val Loss:  2.494, Val Acc: 43.27%, Time: 29.62s *
# Iter: 480, Train Loss:  1.938, Train Acc: 62.50%, Val Loss:  2.589, Val Acc: 44.12%, Time: 37.18s *
# Epoch: 4
# Iter: 510, Train Loss:   1.99, Train Acc: 56.25%, Val Loss:  2.567, Val Acc: 43.44%, Time: 3.95s
# Iter: 540, Train Loss:  1.756, Train Acc: 62.50%, Val Loss:  2.634, Val Acc: 43.70%, Time: 11.50s
# Iter: 570, Train Loss:  2.048, Train Acc: 50.00%, Val Loss:  2.685, Val Acc: 41.82%, Time: 19.10s
# Iter: 600, Train Loss:   1.97, Train Acc: 60.94%, Val Loss:  2.689, Val Acc: 42.16%, Time: 26.64s
# Iter: 630, Train Loss:  1.521, Train Acc: 73.44%, Val Loss:  2.623, Val Acc: 42.76%, Time: 34.13s
# Iter: 660, Train Loss:   2.01, Train Acc: 50.00%, Val Loss:  2.646, Val Acc: 43.95%, Time: 41.63s
# Epoch: 5
# Iter: 690, Train Loss:  1.475, Train Acc: 73.44%, Val Loss:  2.889, Val Acc: 40.29%, Time: 6.70s
# Iter: 720, Train Loss:   1.59, Train Acc: 71.88%, Val Loss:  2.788, Val Acc: 43.78%, Time: 14.22s
# Iter: 750, Train Loss:  1.295, Train Acc: 76.56%, Val Loss:    2.9, Val Acc: 43.95%, Time: 21.77s
# Iter: 780, Train Loss:  1.379, Train Acc: 65.62%, Val Loss:  2.988, Val Acc: 44.04%, Time: 29.42s
# Iter: 810, Train Loss:  1.396, Train Acc: 79.69%, Val Loss:  3.016, Val Acc: 41.74%, Time: 37.04s
# Epoch: 6
# Iter: 840, Train Loss: 0.9725, Train Acc: 84.38%, Val Loss:  3.011, Val Acc: 42.76%, Time: 3.63s
# Iter: 870, Train Loss:   1.23, Train Acc: 76.56%, Val Loss:  3.325, Val Acc: 44.80%, Time: 11.12s *
# Iter: 900, Train Loss:  1.084, Train Acc: 78.12%, Val Loss:  3.326, Val Acc: 44.21%, Time: 18.68s
# Iter: 930, Train Loss:  1.006, Train Acc: 79.69%, Val Loss:  3.248, Val Acc: 41.65%, Time: 26.20s
# Iter: 960, Train Loss:    1.2, Train Acc: 79.69%, Val Loss:  3.287, Val Acc: 40.72%, Time: 33.80s
# Iter: 990, Train Loss:  1.073, Train Acc: 79.69%, Val Loss:  3.478, Val Acc: 41.57%, Time: 41.28s
# Epoch: 7
# Iter: 1020, Train Loss: 0.7948, Train Acc: 84.38%, Val Loss:  3.672, Val Acc: 41.57%, Time: 6.33s
# Iter: 1050, Train Loss: 0.8428, Train Acc: 82.81%, Val Loss:  3.784, Val Acc: 41.06%, Time: 13.99s
# Iter: 1080, Train Loss:  0.578, Train Acc: 92.19%, Val Loss:  3.671, Val Acc: 41.23%, Time: 21.58s
# Iter: 1110, Train Loss:  1.105, Train Acc: 79.69%, Val Loss:  3.736, Val Acc: 42.08%, Time: 29.05s
# Iter: 1140, Train Loss:  1.068, Train Acc: 79.69%, Val Loss:  3.793, Val Acc: 41.40%, Time: 36.48s
# Epoch: 8
# Iter: 1170, Train Loss: 0.5279, Train Acc: 89.06%, Val Loss:  3.873, Val Acc: 41.65%, Time: 3.22s
# Iter: 1200, Train Loss: 0.6442, Train Acc: 90.62%, Val Loss:  4.354, Val Acc: 40.37%, Time: 10.76s
# Iter: 1230, Train Loss: 0.4657, Train Acc: 92.19%, Val Loss:  4.185, Val Acc: 40.29%, Time: 18.45s
# Iter: 1260, Train Loss: 0.7269, Train Acc: 90.62%, Val Loss:  4.342, Val Acc: 40.29%, Time: 26.10s
