# %%
import numpy as np
import tensorflow as tf
import sys
import time
from datetime import timedelta
import tensorflow.contrib.keras as kr
from sklearn import metrics
from sklearn.model_selection import KFold

import moxing as mox
mox.file.shift('os', 'mox')
# Out:
# INFO:root:Using MoXing-v1.14.1-ddfd6c9a
# INFO:root:Using OBS-Python-SDK-3.1.2

# %%
trainDataPath = "s3://corpus-text-classification1/data/train_5500.label.txt"
testDataPath = "s3://corpus-text-classification1/data/TREC_10.label.txt"
vocabPath = "s3://corpus-text-classification1/data/glove.6B.100d.txt"

# %%
def readfile(filePath):
    """读取文件内容，返回文本和标签列表"""
    train_data = []
    with open(filePath, 'r', encoding='utf-8', errors='ignore') as f:
        for line in f.readlines():
            word = line.strip().split()
            label = word[0].split(":")[0]
            content = word[1:]
            train_data.append([content,label])
    
    np.random.shuffle(train_data)
    return np.asarray(train_data)


def loadGloVe(filename):
    vocab = []
    embd = []
    print('Loading GloVe!')
    # vocab.append('unk') #装载不认识的词
    # embd.append([0] * emb_size) #这个emb_size可能需要指定
    file = open(filename,'r',encoding='utf-8')
    for line in file.readlines():
        row = line.strip().split(' ')
        vocab.append(row[0])
        embd.append([float(ei) for ei in row[1:]])
    file.close()
    print('Completed!')
    return vocab,embd


def process_file(contents, labels, word_to_id, cat_to_id, num_classes, pad_max_length):
    """
    将文件转换为id表示,并且将每个单独的样本长度固定为pad_max_lengtn
    """
    # contents, labels = readfile(filePath)
    data_id, label_id = [], []
    # 将文本内容转换为对应的id形式
    for i in range(len(contents)):
        data_id.append([word_to_id[x] for x in contents[i] if x in word_to_id])
        label_id.append(cat_to_id[labels[i]])
    # 使用keras提供的pad_sequences来将文本pad为固定长度
    x_pad = kr.preprocessing.sequence.pad_sequences(data_id, pad_max_length)
    ''' https://blog.csdn.net/TH_NUM/article/details/80904900
    pad_sequences(sequences, maxlen=None, dtype=’int32’, padding=’pre’, truncating=’pre’, value=0.) 
        sequences：浮点数或整数构成的两层嵌套列表
        maxlen：None或整数，为序列的最大长度。大于此长度的序列将被截短，小于此长度的序列将在后部填0.
        dtype：返回的numpy array的数据类型
        padding：‘pre’或‘post’，确定当需要补0时，在序列的起始还是结尾补
        truncating：‘pre’或‘post’，确定当需要截断序列时，从起始还是结尾截断
        value：浮点数，此值将在填充时代替默认的填充值0
    '''
    y_pad = kr.utils.to_categorical(label_id, num_classes=num_classes)  # 将标签转换为one-hot表示
    ''' https://blog.csdn.net/nima1994/article/details/82468965
    to_categorical(y, num_classes=None, dtype='float32')
        将整型标签转为onehot。y为int数组，num_classes为标签类别总数，大于max(y)（标签从0开始的）。
        返回：如果num_classes=None，返回len(y) * [max(y)+1]（维度，m*n表示m行n列矩阵，下同），否则为len(y) * num_classes。
    '''
    return x_pad, y_pad

# %%
categories = ['ABBR', 'DESC', 'ENTY', 'HUM', 'LOC', 'NUM']
num_classes = len(categories)

cat_to_id = {'ABBR': 0, 'DESC': 1, 'ENTY': 2, 'HUM': 3, 'LOC': 4, 'NUM': 5}

vocab, embd = loadGloVe(vocabPath)
vocab_size = len(vocab)
embedding_dim = len(embd[0])
embedding = np.asarray(embd)
word_to_id = dict(zip(vocab, range(vocab_size)))

print(len(embedding),embedding_dim,vocab_size)

testData = readfile(testDataPath)
trainData = readfile(trainDataPath)

print(len(testData),len(trainData))
trainData = np.r_[trainData,testData]
np.random.shuffle(trainData)
len(trainData)

seq_length = 37
# Out:
# Loading GloVe!
# Completed!
# 400000 100 400000
# 500 5452

# %%
def train_10_fold(train_data, categories):
    
    tx, ty = process_file(train_data[:,0], train_data[:,1], word_to_id, cat_to_id, num_classes, seq_length)
    print(len(tx),len(tx[0]),len(tx[1]))
    
    fold_id = 0
    test_acc = []
    
    kf = KFold(n_splits=10)
    for train_i, test_i in kf.split(tx):
        fold_id += 1
        print("Fold: ", fold_id)
        test_acc.append(classifier.train(
            X_train=tx[train_i],
            y_train=ty[train_i],
            X_eval=tx[test_i],
            y_eval=ty[test_i],
            categories=categories,
            epochs=30
        ))
    print(test_acc)
    print("%s, %s, %s, %s" % (np.mean(test_acc),np.std(test_acc),np.std(test_acc,ddof=1),np.var(test_acc)))
    return test_acc

# %%
class Classifier:

    def __init__(self, model, input_length, output_length):
        self.model = model
        self.input_length = input_length
        self.output_length = output_length

    def compile(self, batch_size=32):
        self._ds_x = tf.placeholder(tf.float32, [None, self.input_length])
        self._ds_y = tf.placeholder(tf.float32, [None, self.output_length])

        ds = tf.data.Dataset.from_tensor_slices((self._ds_x, self._ds_y))
        ds = ds.batch(batch_size)

        self._ds_it = ds.make_initializable_iterator()
        self._input, self._labels = self._ds_it.get_next()

        self._features = self.model(self._input)
        self._output = _create_dense_layer(self._features, self.output_length)

        self._create_acc_computations()
        self._create_backpropagation()

    def _create_acc_computations(self):
        self._predictions = tf.argmax(self._output, 1)
        labels = tf.argmax(self._labels, 1)
        self._accuracy = tf.reduce_mean(
            tf.cast(tf.equal(self._predictions, labels), 'float32'))

    def _create_backpropagation(self):
        losses = tf.nn.softmax_cross_entropy_with_logits_v2(
            logits=self._output,
            labels=self._labels)
        self._loss = tf.reduce_mean(losses)

        optimizer = tf.train.AdamOptimizer(0.001)
        global_step = tf.Variable(0, name="global_step", trainable=False)
        grads_and_vars = optimizer.compute_gradients(self._loss)

        self._train_op = optimizer.apply_gradients(
            grads_and_vars, global_step=global_step)

    def summary(self):
        print('input:', self._input.shape)
        self.model.summary()
        print('output:', self._output.shape)

    def train(self, X_train, y_train, X_eval, y_eval, categories, epochs=20, require_improve=3):
        
        session = tf.Session()
        session.run(tf.global_variables_initializer())
        session.run(tf.local_variables_initializer())
        
        best_vac_acc = 0.0
        last_improved = 0
        
        for e in range(epochs):
            start_time = time.time()
            loss, acc = self._train(X_train, y_train, session)
            duration = time.time() - start_time

            val_loss, val_acc = self._eval(X_eval, y_eval, session)
            
            if val_acc > best_vac_acc:
                best_vac_acc = val_acc
                last_improved = e
                improved_str = '*'
            else:
                improved_str = ''
            
            output = 'Epoch: {:>1}, Train Loss: {:>6.4}, Train Acc: {:>6.2%}, Val Loss: {:>6.4}, Val Acc: {:>6.2%}, Time: {:.2f}s {}'
            print(output.format(e + 1, loss, acc, val_loss, val_acc, duration, improved_str))
            
            if e - last_improved > require_improve:
                print("No optimization for a long time, auto-stopping...")
                
                y_test_cls = np.argmax(y_eval, 1)  # 获得类别
                y_test_pred_cls = np.argmax(self.predict(X_eval, session), 1)
                accuracy_score = metrics.accuracy_score(y_test_cls, y_test_pred_cls)
                
                # evaluate
                print("Precision, Recall and F1-Score...")
                print(metrics.classification_report(y_test_cls, y_test_pred_cls, target_names=categories))
                '''
                sklearn中的classification_report函数用于显示主要分类指标的文本报告．在报告中显示每个类的精确度，召回率，F1值等信息。
                    y_true：1维数组，或标签指示器数组/稀疏矩阵，目标值。 
                    y_pred：1维数组，或标签指示器数组/稀疏矩阵，分类器返回的估计值。 
                    labels：array，shape = [n_labels]，报表中包含的标签索引的可选列表。 
                    target_names：字符串列表，与标签匹配的可选显示名称（相同顺序）。 
                    原文链接：https://blog.csdn.net/akadiao/article/details/78788864
                '''

                print("Confusion Matrix...")
                print(metrics.confusion_matrix(y_test_cls, y_test_pred_cls))
                '''
                混淆矩阵是机器学习中总结分类模型预测结果的情形分析表，以矩阵形式将数据集中的记录按照真实的类别与分类模型作出的分类判断两个标准进行汇总。
                这个名字来源于它可以非常容易的表明多个类别是否有混淆（也就是一个class被预测成另一个class）
                https://blog.csdn.net/u011734144/article/details/80277225
                '''
                break
        # endfor
        session.close()
        return accuracy_score

    def _train(self, X_train, y_train, session):
        import numpy as np

        session.run(
            fetches=self._ds_it.initializer,
            feed_dict={
                self._ds_x: X_train,
                self._ds_y: y_train
            })
        loss, acc, = [], []
        while True:
            try:
                _, vloss, vacc = session.run(
                    fetches=[self._train_op, self._loss, self._accuracy])

                loss.append(vloss)
                acc.append(vacc)
            except tf.errors.OutOfRangeError:
                break
        # endwhile

        loss, acc = np.mean(loss), np.mean(acc)
        return loss, acc

    def _eval(self, X_val, y_val, session):
        session.run(
            fetches=self._ds_it.initializer,
            feed_dict={
                self._ds_x: X_val,
                self._ds_y: y_val
            })

        loss, acc, = 0, 0
        while True:
            try:
                l, vloss, vacc = session.run(
                    fetches=[self._labels, self._loss, self._accuracy])

                loss += vloss * len(l)
                acc += vacc * len(l)
            except tf.errors.OutOfRangeError:
                break

        return loss / len(X_val), acc / len(X_val)

    def predict(self, X, session):
        

        session.run(self._ds_it.initializer,
                         feed_dict={
                             self._ds_x: X,
                             self._ds_y: np.empty((len(X), self.output_length))
                         }
                         )

        pred = list()
        while True:
            try:
                ppred = session.run(tf.nn.softmax(self._output))

                pred.extend(map(lambda l: l.tolist(), ppred))
            except tf.errors.OutOfRangeError:
                break

        return pred

def _create_dense_layer(x, output_length):
    '''Creates a dense layer
    '''
    input_size = x.shape[1].value
    W = tf.Variable(
        initial_value=tf.truncated_normal(
            shape=[input_size, output_length],
            stddev=0.1))
    b = tf.Variable(
        initial_value=tf.truncated_normal(
            shape=[output_length]))

    dense = tf.nn.xw_plus_b(x, W, b)

    return dense

# %%
class KimConvolutionalModel:
    '''
    Implementation proposal of: https://arxiv.org/pdf/1408.5882.pdf
    '''
    def __init__(self,
        embeddings_configuration,
        conv_configurations = [(3, 100), (4, 100), (5, 100)],
        drop_rate           = 0.5):
        '''Constructor.
        # Parameters:
        embeddings: List of embeddings configuration. Each configuration is a
            pair of the form (embedding, trainable). `embedding` is a numpy
            array and `trainable` is a boolean that indicates whether that
            embedding is trainable or not.
        conv_configurations: List of pairs. Each pair represents a
            convolution configuration. Each configuration determines the
            size and number of each filter.
        '''

        self._embeddings_configuration = embeddings_configuration
        self._conv_configurations = conv_configurations
        self._drop_rate = drop_rate

    def __call__(self, input):
        self._embeddings_tf = tf.stack(
            values = [
                self._create_embedding_layer(e, input)
                for e in self._embeddings_configuration],
            axis = 1
        )

        self._convolutions_tf = self._create_convolutional_layers(
            self._conv_configurations, self._embeddings_tf)
        
        self._add_tf = self._create_add_layers(self._convolutions_tf)

        self._poolings_tf = self._create_maxpooling_layer(
            self._add_tf)

        self._reshape_tf = self._create_reshape_layer(self._poolings_tf)
        self._dropout_tf = tf.nn.dropout(
            self._reshape_tf,
            keep_prob = self._drop_rate)

        return self._dropout_tf

    def summary(self):
        print('embedding:', str(self._embeddings_tf.shape))
        for c in self._convolutions_tf:
            print('conv:', str(c.shape))
        for a in self._add_tf:
            print('add:', str(a.shape))
        for p in self._poolings_tf:
            print('pool:', str(p.shape))
        print('reshape:', str(self._reshape_tf.shape))

    def _create_embedding_layer(self, embedding_configuration, input_x):
        return tf.nn.embedding_lookup(
            params = tf.Variable(
                initial_value = embedding_configuration[0],
                trainable     = embedding_configuration[1]),
            ids = tf.cast(input_x, 'int32')
        )

    def _create_convolutional_layers(self, configuration, input_embedding):
        '''Creates the convolutional layers.
        # Parameters:
        configuration: A list. It must be of the form
            [(filter_size, num_filters), ...]
        # Returns:
        A list of tensorflow nodes. Each node 'i' computes the configuration 'i'.
        '''
        convolutions = []
        for filter_height, num_filters in configuration:
            filter_width = input_embedding.shape[3].value
            filter_shape = [1, filter_height, filter_width, num_filters]

            # Create weights and bias
            W = tf.Variable(
                initial_value=tf.truncated_normal(
                    shape=filter_shape,
                    stddev=0.1))
            b = tf.Variable(
                initial_value=tf.truncated_normal(
                    shape=[num_filters]))

            conv = tf.nn.conv2d(
                input=input_embedding,
                filter=W,
                strides=[1, 1, 1, 1],
                padding="VALID")
            bias = tf.nn.bias_add(conv, b)
            h = tf.nn.relu(bias)
            convolutions.append(h)

        return convolutions

    def _create_add_layers(self, convolutions):
        return [
            tf.reduce_sum(
                input_tensor = c,
                axis=1,
                keepdims=True)
            for c in convolutions
        ]

    def _create_maxpooling_layer(self, tensors):
        '''Creates the maxpooling layer. Computes maxpooling on each node
        # Parameters:
        input_convolutions: List of tensorflow nodes.
        # Returns:
        A list of tensorflow nodes. Each node 'i' computes the maxpooling of node 'i'
        '''
        return [
            tf.reshape(
                tensor = tf.nn.max_pool(
                    value=t,
                    ksize=[1, 1, t.shape[2], 1],
                    strides=[1, 1, 1, 1],
                    padding='VALID'),
                shape = [-1, t.shape[3]]
            )
            for t in tensors
        ]

    def _create_reshape_layer(self, tensors):
        '''Creates a flatten layer
        '''
        return tf.concat(tensors, axis=1)

# %%
word_vector = embedding.astype('float32')
model = KimConvolutionalModel(
        embeddings_configuration=[
            (word_vector, True)
        ]
    )

classifier = Classifier(
    model=model,
    input_length=seq_length,
    output_length=num_classes)

classifier.compile(batch_size=32)
classifier.summary()
# Out:
# input: (?, 37)
# embedding: (?, 1, 37, 100)
# conv: (?, 1, 35, 100)
# conv: (?, 1, 34, 100)
# conv: (?, 1, 33, 100)
# add: (?, 1, 35, 100)
# add: (?, 1, 34, 100)
# add: (?, 1, 33, 100)
# pool: (?, 100)
# pool: (?, 100)
# pool: (?, 100)
# reshape: (?, 300)
# output: (?, 6)

# %%
train_10_fold(trainData, categories)
# Out:
# 5952 37 37
# Fold:  1
# Epoch: 1, Train Loss:  1.755, Train Acc: 41.67%, Val Loss:  1.207, Val Acc: 56.88%, Time: 21.24s *
# Epoch: 2, Train Loss: 0.9805, Train Acc: 64.07%, Val Loss: 0.9755, Val Acc: 64.26%, Time: 22.44s *
# Epoch: 3, Train Loss:  0.728, Train Acc: 73.73%, Val Loss:  0.916, Val Acc: 66.28%, Time: 22.59s *
# Epoch: 4, Train Loss: 0.5807, Train Acc: 79.53%, Val Loss: 0.7895, Val Acc: 71.81%, Time: 22.25s *
# Epoch: 5, Train Loss: 0.4607, Train Acc: 84.44%, Val Loss: 0.7655, Val Acc: 75.00%, Time: 22.74s *
# Epoch: 6, Train Loss: 0.3705, Train Acc: 87.25%, Val Loss: 0.7367, Val Acc: 75.84%, Time: 22.36s *
# Epoch: 7, Train Loss: 0.3184, Train Acc: 88.90%, Val Loss:  0.725, Val Acc: 75.84%, Time: 22.58s *
# Epoch: 8, Train Loss: 0.2623, Train Acc: 91.21%, Val Loss: 0.7406, Val Acc: 77.18%, Time: 22.70s *
# Epoch: 9, Train Loss: 0.2234, Train Acc: 92.18%, Val Loss: 0.7047, Val Acc: 77.01%, Time: 22.46s
# Epoch: 10, Train Loss:  0.191, Train Acc: 93.74%, Val Loss: 0.7558, Val Acc: 77.85%, Time: 22.37s *
# Epoch: 11, Train Loss: 0.1668, Train Acc: 94.18%, Val Loss: 0.7543, Val Acc: 77.35%, Time: 22.61s
# Epoch: 12, Train Loss: 0.1524, Train Acc: 94.64%, Val Loss: 0.6665, Val Acc: 79.03%, Time: 22.46s *
# Epoch: 13, Train Loss:  0.132, Train Acc: 95.50%, Val Loss: 0.7737, Val Acc: 78.36%, Time: 19.59s
# Epoch: 14, Train Loss:  0.124, Train Acc: 95.59%, Val Loss:  0.765, Val Acc: 79.87%, Time: 22.42s *
# Epoch: 15, Train Loss: 0.1144, Train Acc: 95.94%, Val Loss:  0.773, Val Acc: 78.52%, Time: 22.27s
# Epoch: 16, Train Loss: 0.1082, Train Acc: 96.19%, Val Loss: 0.7159, Val Acc: 80.54%, Time: 22.54s *
# Epoch: 17, Train Loss:  0.103, Train Acc: 96.28%, Val Loss: 0.8206, Val Acc: 77.52%, Time: 22.39s
# Epoch: 18, Train Loss: 0.09749, Train Acc: 96.54%, Val Loss: 0.7658, Val Acc: 80.20%, Time: 22.89s
# Epoch: 19, Train Loss: 0.09408, Train Acc: 96.65%, Val Loss: 0.7756, Val Acc: 78.36%, Time: 23.98s
# Epoch: 20, Train Loss: 0.0897, Train Acc: 96.73%, Val Loss: 0.8718, Val Acc: 79.03%, Time: 22.70s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.60      0.43      0.50         7
#         DESC       0.77      0.70      0.73       132
#         ENTY       0.71      0.79      0.75       126
#          HUM       0.80      0.87      0.83       131
#          LOC       0.86      0.80      0.83        97
#          NUM       0.90      0.84      0.87       103
#
#    micro avg       0.80      0.80      0.80       596
#    macro avg       0.77      0.74      0.75       596
# weighted avg       0.80      0.80      0.79       596
#
# Confusion Matrix...
# [[  3   3   1   0   0   0]
#  [  2  92  22   9   5   2]
#  [  0   5 100  14   3   4]
#  [  0   5   9 114   1   2]
#  [  0   9   5   3  78   2]
#  [  0   6   3   3   4  87]]
# Fold:  2
# Epoch: 1, Train Loss:  1.818, Train Acc: 40.52%, Val Loss:  1.172, Val Acc: 56.21%, Time: 22.40s *
# Epoch: 2, Train Loss:  0.987, Train Acc: 63.40%, Val Loss: 0.9498, Val Acc: 65.10%, Time: 22.53s *
# Epoch: 3, Train Loss: 0.7302, Train Acc: 73.89%, Val Loss:  0.887, Val Acc: 69.30%, Time: 22.27s *
# Epoch: 4, Train Loss: 0.5709, Train Acc: 79.82%, Val Loss: 0.8009, Val Acc: 72.48%, Time: 22.47s *
# Epoch: 5, Train Loss: 0.4501, Train Acc: 84.46%, Val Loss: 0.7783, Val Acc: 73.83%, Time: 22.51s *
# Epoch: 6, Train Loss: 0.3778, Train Acc: 86.71%, Val Loss: 0.7438, Val Acc: 73.99%, Time: 22.22s *
# Epoch: 7, Train Loss: 0.3067, Train Acc: 89.61%, Val Loss: 0.7218, Val Acc: 75.67%, Time: 19.55s *
# Epoch: 8, Train Loss: 0.2688, Train Acc: 91.06%, Val Loss: 0.7279, Val Acc: 76.51%, Time: 22.40s *
# Epoch: 9, Train Loss:  0.226, Train Acc: 92.39%, Val Loss: 0.7314, Val Acc: 78.02%, Time: 23.10s *
# Epoch: 10, Train Loss: 0.1979, Train Acc: 93.32%, Val Loss: 0.7763, Val Acc: 75.84%, Time: 24.16s
# Epoch: 11, Train Loss: 0.1666, Train Acc: 94.26%, Val Loss: 0.8402, Val Acc: 75.84%, Time: 24.35s
# Epoch: 12, Train Loss: 0.1588, Train Acc: 94.20%, Val Loss: 0.8025, Val Acc: 77.52%, Time: 24.73s
# Epoch: 13, Train Loss: 0.1381, Train Acc: 95.24%, Val Loss:  0.836, Val Acc: 76.51%, Time: 24.91s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.78      0.88      0.82         8
#         DESC       0.73      0.74      0.74       133
#         ENTY       0.74      0.80      0.77       139
#          HUM       0.82      0.76      0.79       129
#          LOC       0.75      0.73      0.74        81
#          NUM       0.85      0.82      0.84       106
#
#    micro avg       0.77      0.77      0.77       596
#    macro avg       0.78      0.79      0.78       596
# weighted avg       0.78      0.77      0.77       596
#
# Confusion Matrix...
# [[  7   1   0   0   0   0]
#  [  1  99  18   2   7   6]
#  [  0  15 111  10   3   0]
#  [  0   6  13  98   7   5]
#  [  1   9   4   4  59   4]
#  [  0   6   5   5   3  87]]
# Fold:  3
# Epoch: 1, Train Loss:  1.651, Train Acc: 42.04%, Val Loss:  1.197, Val Acc: 54.96%, Time: 25.21s *
# Epoch: 2, Train Loss: 0.9744, Train Acc: 64.20%, Val Loss:  0.935, Val Acc: 66.55%, Time: 24.48s *
# Epoch: 3, Train Loss:  0.721, Train Acc: 73.33%, Val Loss: 0.8357, Val Acc: 68.91%, Time: 25.16s *
# Epoch: 4, Train Loss: 0.5672, Train Acc: 80.02%, Val Loss: 0.7394, Val Acc: 73.61%, Time: 24.98s *
# Epoch: 5, Train Loss: 0.4556, Train Acc: 84.20%, Val Loss: 0.7599, Val Acc: 73.61%, Time: 24.91s *
# Epoch: 6, Train Loss: 0.3713, Train Acc: 87.27%, Val Loss: 0.7452, Val Acc: 74.45%, Time: 21.76s *
# Epoch: 7, Train Loss: 0.3086, Train Acc: 89.56%, Val Loss: 0.7593, Val Acc: 75.63%, Time: 24.50s *
# Epoch: 8, Train Loss: 0.2574, Train Acc: 91.49%, Val Loss: 0.7459, Val Acc: 75.29%, Time: 24.74s
# Epoch: 9, Train Loss: 0.2195, Train Acc: 92.52%, Val Loss: 0.7458, Val Acc: 77.31%, Time: 24.81s *
# Epoch: 10, Train Loss:  0.193, Train Acc: 93.70%, Val Loss: 0.7281, Val Acc: 76.64%, Time: 24.78s
# Epoch: 11, Train Loss: 0.1644, Train Acc: 94.40%, Val Loss: 0.8237, Val Acc: 76.30%, Time: 24.86s
# Epoch: 12, Train Loss:   0.16, Train Acc: 94.47%, Val Loss: 0.7293, Val Acc: 78.32%, Time: 25.09s *
# Epoch: 13, Train Loss: 0.1453, Train Acc: 94.81%, Val Loss: 0.8166, Val Acc: 78.32%, Time: 24.72s
# Epoch: 14, Train Loss: 0.1208, Train Acc: 95.97%, Val Loss: 0.7572, Val Acc: 77.98%, Time: 25.37s
# Epoch: 15, Train Loss: 0.1196, Train Acc: 95.67%, Val Loss: 0.8635, Val Acc: 76.97%, Time: 25.11s
# Epoch: 16, Train Loss: 0.1152, Train Acc: 95.86%, Val Loss:  0.865, Val Acc: 78.49%, Time: 24.97s *
# Epoch: 17, Train Loss: 0.1131, Train Acc: 96.01%, Val Loss: 0.8468, Val Acc: 78.82%, Time: 25.40s *
# Epoch: 18, Train Loss: 0.1045, Train Acc: 95.91%, Val Loss: 0.8512, Val Acc: 77.48%, Time: 24.64s
# Epoch: 19, Train Loss: 0.1006, Train Acc: 96.68%, Val Loss: 0.8839, Val Acc: 77.98%, Time: 24.88s
# Epoch: 20, Train Loss: 0.09328, Train Acc: 96.46%, Val Loss: 0.8216, Val Acc: 80.00%, Time: 25.07s *
# Epoch: 21, Train Loss: 0.09555, Train Acc: 96.41%, Val Loss: 0.8367, Val Acc: 80.17%, Time: 24.91s *
# Epoch: 22, Train Loss: 0.0854, Train Acc: 96.80%, Val Loss: 0.9534, Val Acc: 76.30%, Time: 24.91s
# Epoch: 23, Train Loss: 0.08737, Train Acc: 96.77%, Val Loss: 0.9454, Val Acc: 76.97%, Time: 21.78s
# Epoch: 24, Train Loss: 0.08624, Train Acc: 97.03%, Val Loss: 0.8971, Val Acc: 77.98%, Time: 25.17s
# Epoch: 25, Train Loss: 0.07916, Train Acc: 96.80%, Val Loss: 0.9246, Val Acc: 77.98%, Time: 24.49s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      1.00      1.00         8
#         DESC       0.76      0.71      0.73       131
#         ENTY       0.77      0.74      0.75       134
#          HUM       0.73      0.81      0.77       127
#          LOC       0.76      0.78      0.77        99
#          NUM       0.90      0.88      0.89        96
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.82      0.82      0.82       595
# weighted avg       0.78      0.78      0.78       595
#
# Confusion Matrix...
# [[  8   0   0   0   0   0]
#  [  0  93  11  12  11   4]
#  [  0  15  99  14   6   0]
#  [  0   5  14 103   1   4]
#  [  0   7   5   9  77   1]
#  [  0   3   0   3   6  84]]
# Fold:  4
# Epoch: 1, Train Loss:  1.809, Train Acc: 40.29%, Val Loss:  1.152, Val Acc: 57.31%, Time: 25.15s *
# Epoch: 2, Train Loss: 0.9967, Train Acc: 63.70%, Val Loss: 0.9202, Val Acc: 66.89%, Time: 24.92s *
# Epoch: 3, Train Loss: 0.7233, Train Acc: 74.21%, Val Loss: 0.7761, Val Acc: 69.08%, Time: 24.41s *
# Epoch: 4, Train Loss:  0.579, Train Acc: 78.91%, Val Loss: 0.7043, Val Acc: 74.29%, Time: 24.81s *
# Epoch: 5, Train Loss: 0.4716, Train Acc: 83.53%, Val Loss: 0.6274, Val Acc: 77.48%, Time: 24.61s *
# Epoch: 6, Train Loss: 0.3819, Train Acc: 87.02%, Val Loss: 0.7028, Val Acc: 73.78%, Time: 24.45s
# Epoch: 7, Train Loss: 0.3197, Train Acc: 89.10%, Val Loss: 0.6442, Val Acc: 77.31%, Time: 24.79s
# Epoch: 8, Train Loss: 0.2753, Train Acc: 90.69%, Val Loss: 0.6172, Val Acc: 78.49%, Time: 24.55s *
# Epoch: 9, Train Loss:  0.228, Train Acc: 92.44%, Val Loss: 0.5674, Val Acc: 79.33%, Time: 24.62s *
# Epoch: 10, Train Loss: 0.1932, Train Acc: 93.42%, Val Loss: 0.6438, Val Acc: 75.46%, Time: 24.27s
# Epoch: 11, Train Loss: 0.1733, Train Acc: 94.27%, Val Loss:  0.694, Val Acc: 77.82%, Time: 24.34s
# Epoch: 12, Train Loss: 0.1633, Train Acc: 94.49%, Val Loss: 0.6217, Val Acc: 80.00%, Time: 24.32s *
# Epoch: 13, Train Loss: 0.1492, Train Acc: 94.92%, Val Loss: 0.6491, Val Acc: 78.49%, Time: 24.58s
# Epoch: 14, Train Loss: 0.1304, Train Acc: 95.44%, Val Loss: 0.6167, Val Acc: 79.83%, Time: 26.47s
# Epoch: 15, Train Loss: 0.1238, Train Acc: 95.76%, Val Loss: 0.7447, Val Acc: 78.15%, Time: 24.71s
# Epoch: 16, Train Loss: 0.1169, Train Acc: 95.89%, Val Loss:  0.758, Val Acc: 78.49%, Time: 24.65s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.78      0.88         9
#         DESC       0.65      0.84      0.73       114
#         ENTY       0.82      0.72      0.76       149
#          HUM       0.86      0.80      0.83       122
#          LOC       0.77      0.74      0.75        95
#          NUM       0.85      0.83      0.84       106
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.82      0.78      0.80       595
# weighted avg       0.79      0.78      0.78       595
#
# Confusion Matrix...
# [[  7   2   0   0   0   0]
#  [  0  96   7   0   7   4]
#  [  0  20 107  10   7   5]
#  [  0   9  10  98   2   3]
#  [  0  13   4   4  70   4]
#  [  0   8   3   2   5  88]]
# Fold:  5
# Epoch: 1, Train Loss:  1.864, Train Acc: 39.54%, Val Loss:  1.228, Val Acc: 54.96%, Time: 21.92s *
# Epoch: 2, Train Loss: 0.9981, Train Acc: 63.65%, Val Loss: 0.9443, Val Acc: 65.71%, Time: 24.57s *
# Epoch: 3, Train Loss: 0.7457, Train Acc: 72.41%, Val Loss: 0.8264, Val Acc: 69.92%, Time: 24.43s *
# Epoch: 4, Train Loss: 0.5708, Train Acc: 80.04%, Val Loss: 0.7662, Val Acc: 73.28%, Time: 24.14s *
# Epoch: 5, Train Loss: 0.4695, Train Acc: 83.42%, Val Loss: 0.7598, Val Acc: 73.95%, Time: 24.46s *
# Epoch: 6, Train Loss: 0.3846, Train Acc: 86.74%, Val Loss: 0.8232, Val Acc: 71.60%, Time: 24.37s
# Epoch: 7, Train Loss: 0.3293, Train Acc: 88.42%, Val Loss: 0.7907, Val Acc: 74.79%, Time: 24.31s *
# Epoch: 8, Train Loss: 0.2705, Train Acc: 90.91%, Val Loss: 0.7435, Val Acc: 75.63%, Time: 24.34s *
# Epoch: 9, Train Loss: 0.2373, Train Acc: 92.05%, Val Loss:  0.728, Val Acc: 76.30%, Time: 24.48s *
# Epoch: 10, Train Loss: 0.2025, Train Acc: 93.33%, Val Loss: 0.8137, Val Acc: 74.62%, Time: 24.74s
# Epoch: 11, Train Loss: 0.1755, Train Acc: 94.12%, Val Loss: 0.8462, Val Acc: 76.47%, Time: 24.38s *
# Epoch: 12, Train Loss: 0.1564, Train Acc: 94.81%, Val Loss: 0.7918, Val Acc: 76.81%, Time: 24.70s *
# Epoch: 13, Train Loss: 0.1414, Train Acc: 95.40%, Val Loss: 0.8643, Val Acc: 74.96%, Time: 24.64s
# Epoch: 14, Train Loss: 0.1367, Train Acc: 95.26%, Val Loss: 0.8961, Val Acc: 77.98%, Time: 24.78s *
# Epoch: 15, Train Loss: 0.1216, Train Acc: 95.66%, Val Loss: 0.8194, Val Acc: 77.31%, Time: 24.62s
# Epoch: 16, Train Loss: 0.1157, Train Acc: 95.91%, Val Loss:  0.849, Val Acc: 77.98%, Time: 24.67s *
# Epoch: 17, Train Loss: 0.1091, Train Acc: 96.22%, Val Loss: 0.9042, Val Acc: 77.31%, Time: 24.68s
# Epoch: 18, Train Loss: 0.1019, Train Acc: 96.41%, Val Loss: 0.9519, Val Acc: 76.81%, Time: 24.68s
# Epoch: 19, Train Loss: 0.09501, Train Acc: 96.48%, Val Loss:  0.914, Val Acc: 78.66%, Time: 21.80s *
# Epoch: 20, Train Loss: 0.09493, Train Acc: 96.84%, Val Loss: 0.9804, Val Acc: 76.81%, Time: 24.65s
# Epoch: 21, Train Loss: 0.09267, Train Acc: 96.56%, Val Loss: 0.9679, Val Acc: 76.64%, Time: 24.24s
# Epoch: 22, Train Loss: 0.09384, Train Acc: 96.65%, Val Loss:  1.016, Val Acc: 76.13%, Time: 24.41s
# Epoch: 23, Train Loss: 0.0889, Train Acc: 96.78%, Val Loss:  1.014, Val Acc: 76.64%, Time: 24.09s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.78      0.78      0.78         9
#         DESC       0.78      0.72      0.74       130
#         ENTY       0.70      0.73      0.71       129
#          HUM       0.79      0.81      0.80       139
#          LOC       0.75      0.86      0.80        88
#          NUM       0.92      0.83      0.87       100
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.79      0.79      0.79       595
# weighted avg       0.79      0.78      0.78       595
#
# Confusion Matrix...
# [[  7   1   1   0   0   0]
#  [  2  93  13  14   7   1]
#  [  0  13  94   9   8   5]
#  [  0   6  13 112   7   1]
#  [  0   3   6   3  76   0]
#  [  0   4   7   3   3  83]]
# Fold:  6
# Epoch: 1, Train Loss:  1.628, Train Acc: 43.47%, Val Loss:  1.271, Val Acc: 52.10%, Time: 24.72s *
# Epoch: 2, Train Loss: 0.9488, Train Acc: 64.15%, Val Loss:  1.017, Val Acc: 59.33%, Time: 24.21s *
# Epoch: 3, Train Loss: 0.6945, Train Acc: 74.60%, Val Loss: 0.9421, Val Acc: 65.21%, Time: 24.08s *
# Epoch: 4, Train Loss: 0.5554, Train Acc: 80.46%, Val Loss: 0.8579, Val Acc: 71.09%, Time: 24.74s *
# Epoch: 5, Train Loss: 0.4443, Train Acc: 84.55%, Val Loss: 0.8083, Val Acc: 70.59%, Time: 24.06s
# Epoch: 6, Train Loss: 0.3662, Train Acc: 87.28%, Val Loss: 0.8014, Val Acc: 71.60%, Time: 24.22s *
# Epoch: 7, Train Loss: 0.2919, Train Acc: 90.02%, Val Loss: 0.8579, Val Acc: 70.25%, Time: 24.48s
# Epoch: 8, Train Loss: 0.2458, Train Acc: 91.25%, Val Loss: 0.8004, Val Acc: 72.44%, Time: 24.12s *
# Epoch: 9, Train Loss: 0.2095, Train Acc: 92.60%, Val Loss: 0.8527, Val Acc: 72.44%, Time: 21.90s *
# Epoch: 10, Train Loss: 0.1803, Train Acc: 94.00%, Val Loss: 0.8739, Val Acc: 71.76%, Time: 24.07s
# Epoch: 11, Train Loss: 0.1645, Train Acc: 94.68%, Val Loss: 0.8768, Val Acc: 72.27%, Time: 23.91s
# Epoch: 12, Train Loss: 0.1483, Train Acc: 95.24%, Val Loss: 0.8168, Val Acc: 75.80%, Time: 24.51s *
# Epoch: 13, Train Loss: 0.1322, Train Acc: 95.40%, Val Loss: 0.9005, Val Acc: 74.45%, Time: 24.29s
# Epoch: 14, Train Loss: 0.1195, Train Acc: 96.09%, Val Loss: 0.8855, Val Acc: 75.13%, Time: 24.49s
# Epoch: 15, Train Loss:  0.114, Train Acc: 95.97%, Val Loss: 0.9593, Val Acc: 74.12%, Time: 24.18s
# Epoch: 16, Train Loss: 0.1097, Train Acc: 96.01%, Val Loss: 0.9459, Val Acc: 74.62%, Time: 24.12s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.75      0.27      0.40        11
#         DESC       0.70      0.77      0.73       138
#         ENTY       0.66      0.63      0.65       127
#          HUM       0.78      0.78      0.78       111
#          LOC       0.73      0.76      0.75       104
#          NUM       0.85      0.82      0.83       104
#
#    micro avg       0.74      0.74      0.74       595
#    macro avg       0.75      0.67      0.69       595
# weighted avg       0.74      0.74      0.74       595
#
# Confusion Matrix...
# [[  3   7   0   0   0   1]
#  [  1 106  12   6   9   4]
#  [  0  21  80   7  14   5]
#  [  0   4  15  87   2   3]
#  [  0  10   7   6  79   2]
#  [  0   3   7   5   4  85]]
# Fold:  7
# Epoch: 1, Train Loss:  1.749, Train Acc: 41.28%, Val Loss:  1.277, Val Acc: 52.44%, Time: 26.25s *
# Epoch: 2, Train Loss:  0.967, Train Acc: 64.33%, Val Loss:  1.032, Val Acc: 64.71%, Time: 24.14s *
# Epoch: 3, Train Loss:   0.72, Train Acc: 74.03%, Val Loss: 0.8972, Val Acc: 67.90%, Time: 24.15s *
# Epoch: 4, Train Loss: 0.5626, Train Acc: 79.86%, Val Loss: 0.8232, Val Acc: 72.10%, Time: 24.54s *
# Epoch: 5, Train Loss: 0.4557, Train Acc: 83.89%, Val Loss: 0.8093, Val Acc: 71.76%, Time: 24.40s
# Epoch: 6, Train Loss: 0.3643, Train Acc: 87.45%, Val Loss: 0.7852, Val Acc: 73.45%, Time: 24.24s *
# Epoch: 7, Train Loss: 0.3059, Train Acc: 89.34%, Val Loss:  0.776, Val Acc: 73.61%, Time: 24.69s *
# Epoch: 8, Train Loss: 0.2579, Train Acc: 91.15%, Val Loss: 0.8493, Val Acc: 71.76%, Time: 23.56s
# Epoch: 9, Train Loss: 0.2251, Train Acc: 92.48%, Val Loss:  0.743, Val Acc: 75.13%, Time: 22.84s *
# Epoch: 10, Train Loss:   0.19, Train Acc: 93.63%, Val Loss: 0.8269, Val Acc: 75.97%, Time: 24.34s *
# Epoch: 11, Train Loss: 0.1631, Train Acc: 94.57%, Val Loss: 0.8694, Val Acc: 74.29%, Time: 24.75s
# Epoch: 12, Train Loss: 0.1555, Train Acc: 94.83%, Val Loss: 0.7945, Val Acc: 74.79%, Time: 24.42s
# Epoch: 13, Train Loss: 0.1329, Train Acc: 95.72%, Val Loss: 0.8287, Val Acc: 76.47%, Time: 24.27s *
# Epoch: 14, Train Loss: 0.1245, Train Acc: 95.52%, Val Loss: 0.8379, Val Acc: 76.81%, Time: 24.28s *
# Epoch: 15, Train Loss: 0.1177, Train Acc: 95.89%, Val Loss: 0.9048, Val Acc: 75.46%, Time: 24.74s
# Epoch: 16, Train Loss: 0.1149, Train Acc: 95.79%, Val Loss: 0.9061, Val Acc: 76.13%, Time: 24.41s
# Epoch: 17, Train Loss: 0.1031, Train Acc: 96.22%, Val Loss: 0.8665, Val Acc: 78.82%, Time: 24.38s *
# Epoch: 18, Train Loss: 0.09818, Train Acc: 96.48%, Val Loss: 0.8698, Val Acc: 76.47%, Time: 24.35s
# Epoch: 19, Train Loss: 0.09367, Train Acc: 96.69%, Val Loss: 0.9595, Val Acc: 77.48%, Time: 24.37s
# Epoch: 20, Train Loss: 0.09173, Train Acc: 96.65%, Val Loss:   1.02, Val Acc: 77.82%, Time: 21.98s
# Epoch: 21, Train Loss: 0.08938, Train Acc: 96.65%, Val Loss:  1.005, Val Acc: 77.48%, Time: 24.74s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       1.00      0.86      0.92         7
#         DESC       0.74      0.71      0.72       137
#         ENTY       0.74      0.78      0.76       130
#          HUM       0.82      0.81      0.82       145
#          LOC       0.75      0.69      0.72        85
#          NUM       0.82      0.88      0.85        91
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.81      0.79      0.80       595
# weighted avg       0.78      0.78      0.78       595
#
# Confusion Matrix...
# [[  6   1   0   0   0   0]
#  [  0  97  20   7   6   7]
#  [  0   9 102  12   2   5]
#  [  0   7  10 118   8   2]
#  [  0  15   4   4  59   3]
#  [  0   2   2   3   4  80]]
# Fold:  8
# Epoch: 1, Train Loss:  1.694, Train Acc: 41.19%, Val Loss:  1.166, Val Acc: 56.81%, Time: 24.66s *
# Epoch: 2, Train Loss: 0.9673, Train Acc: 64.22%, Val Loss: 0.9727, Val Acc: 64.03%, Time: 24.77s *
# Epoch: 3, Train Loss: 0.7043, Train Acc: 74.48%, Val Loss:  0.827, Val Acc: 70.76%, Time: 24.34s *
# Epoch: 4, Train Loss: 0.5464, Train Acc: 80.64%, Val Loss: 0.8301, Val Acc: 72.27%, Time: 24.64s *
# Epoch: 5, Train Loss: 0.4333, Train Acc: 85.02%, Val Loss: 0.7822, Val Acc: 73.28%, Time: 24.62s *
# Epoch: 6, Train Loss: 0.3645, Train Acc: 87.45%, Val Loss: 0.7492, Val Acc: 73.28%, Time: 24.83s *
# Epoch: 7, Train Loss:  0.286, Train Acc: 90.49%, Val Loss: 0.7771, Val Acc: 73.78%, Time: 24.39s *
# Epoch: 8, Train Loss: 0.2521, Train Acc: 91.58%, Val Loss: 0.7354, Val Acc: 73.61%, Time: 24.41s
# Epoch: 9, Train Loss: 0.2106, Train Acc: 93.25%, Val Loss: 0.8284, Val Acc: 71.76%, Time: 24.82s
# Epoch: 10, Train Loss: 0.1855, Train Acc: 93.56%, Val Loss: 0.8086, Val Acc: 73.78%, Time: 24.67s *
# Epoch: 11, Train Loss: 0.1681, Train Acc: 94.23%, Val Loss:  0.851, Val Acc: 74.79%, Time: 24.55s *
# Epoch: 12, Train Loss: 0.1428, Train Acc: 95.28%, Val Loss: 0.8218, Val Acc: 76.13%, Time: 24.59s *
# Epoch: 13, Train Loss: 0.1299, Train Acc: 95.96%, Val Loss: 0.9586, Val Acc: 72.27%, Time: 24.47s
# Epoch: 14, Train Loss: 0.1245, Train Acc: 95.78%, Val Loss: 0.8649, Val Acc: 74.62%, Time: 20.48s
# Epoch: 15, Train Loss: 0.1116, Train Acc: 96.08%, Val Loss: 0.9329, Val Acc: 73.61%, Time: 17.12s
# Epoch: 16, Train Loss: 0.1052, Train Acc: 96.40%, Val Loss: 0.9803, Val Acc: 72.77%, Time: 17.04s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.83      0.38      0.53        13
#         DESC       0.75      0.65      0.70       147
#         ENTY       0.65      0.80      0.72       127
#          HUM       0.82      0.77      0.80       127
#          LOC       0.69      0.80      0.74        88
#          NUM       0.90      0.81      0.85        93
#
#    micro avg       0.75      0.75      0.75       595
#    macro avg       0.77      0.70      0.72       595
# weighted avg       0.76      0.75      0.75       595
#
# Confusion Matrix...
# [[  5   4   3   0   1   0]
#  [  0  96  26   5  15   5]
#  [  1   6 102  11   6   1]
#  [  0   9  14  98   5   1]
#  [  0  10   5   2  70   1]
#  [  0   3   8   3   4  75]]
# Fold:  9
# Epoch: 1, Train Loss:  1.825, Train Acc: 39.71%, Val Loss:  1.247, Val Acc: 55.46%, Time: 17.25s *
# Epoch: 2, Train Loss:  1.005, Train Acc: 62.00%, Val Loss: 0.9499, Val Acc: 66.55%, Time: 17.14s *
# Epoch: 3, Train Loss: 0.7468, Train Acc: 73.35%, Val Loss: 0.8295, Val Acc: 72.77%, Time: 17.08s *
# Epoch: 4, Train Loss: 0.5886, Train Acc: 79.39%, Val Loss: 0.8072, Val Acc: 72.10%, Time: 17.03s
# Epoch: 5, Train Loss: 0.4714, Train Acc: 83.37%, Val Loss: 0.7775, Val Acc: 73.11%, Time: 17.08s *
# Epoch: 6, Train Loss: 0.3842, Train Acc: 86.96%, Val Loss: 0.7336, Val Acc: 75.29%, Time: 17.03s *
# Epoch: 7, Train Loss: 0.3117, Train Acc: 89.29%, Val Loss: 0.7531, Val Acc: 77.31%, Time: 17.02s *
# Epoch: 8, Train Loss: 0.2857, Train Acc: 90.54%, Val Loss: 0.7542, Val Acc: 77.31%, Time: 19.10s
# Epoch: 9, Train Loss: 0.2268, Train Acc: 91.99%, Val Loss: 0.7531, Val Acc: 76.47%, Time: 17.03s
# Epoch: 10, Train Loss: 0.1912, Train Acc: 93.63%, Val Loss:   0.72, Val Acc: 76.81%, Time: 17.08s
# Epoch: 11, Train Loss: 0.1683, Train Acc: 94.36%, Val Loss: 0.7967, Val Acc: 77.65%, Time: 17.03s *
# Epoch: 12, Train Loss: 0.1562, Train Acc: 94.70%, Val Loss:  0.842, Val Acc: 77.14%, Time: 17.08s
# Epoch: 13, Train Loss: 0.1432, Train Acc: 95.31%, Val Loss: 0.8205, Val Acc: 77.82%, Time: 17.06s *
# Epoch: 14, Train Loss: 0.1303, Train Acc: 95.58%, Val Loss: 0.9553, Val Acc: 75.46%, Time: 17.05s
# Epoch: 15, Train Loss:  0.122, Train Acc: 95.82%, Val Loss: 0.8914, Val Acc: 78.82%, Time: 17.07s *
# Epoch: 16, Train Loss: 0.1147, Train Acc: 95.81%, Val Loss: 0.9014, Val Acc: 78.66%, Time: 17.04s
# Epoch: 17, Train Loss: 0.1072, Train Acc: 96.00%, Val Loss: 0.8998, Val Acc: 77.82%, Time: 17.08s
# Epoch: 18, Train Loss: 0.1036, Train Acc: 96.26%, Val Loss: 0.9766, Val Acc: 77.48%, Time: 17.06s
# Epoch: 19, Train Loss:  0.103, Train Acc: 96.26%, Val Loss:  0.946, Val Acc: 78.49%, Time: 17.07s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.58      0.78      0.67         9
#         DESC       0.79      0.71      0.75       124
#         ENTY       0.68      0.81      0.74       134
#          HUM       0.82      0.76      0.79       136
#          LOC       0.75      0.76      0.75        83
#          NUM       0.92      0.85      0.89       109
#
#    micro avg       0.78      0.78      0.78       595
#    macro avg       0.76      0.78      0.76       595
# weighted avg       0.79      0.78      0.78       595
#
# Confusion Matrix...
# [[  7   1   0   0   1   0]
#  [  2  88  17   6   8   3]
#  [  1  13 109   4   3   4]
#  [  1   3  25 103   4   0]
#  [  0   4   4  11  63   1]
#  [  1   3   5   2   5  93]]
# Fold:  10
# Epoch: 1, Train Loss:  1.704, Train Acc: 42.77%, Val Loss:   1.25, Val Acc: 53.95%, Time: 17.21s *
# Epoch: 2, Train Loss: 0.9596, Train Acc: 64.71%, Val Loss: 0.9871, Val Acc: 62.86%, Time: 17.00s *
# Epoch: 3, Train Loss:  0.715, Train Acc: 74.74%, Val Loss: 0.9151, Val Acc: 66.89%, Time: 17.03s *
# Epoch: 4, Train Loss: 0.5615, Train Acc: 80.75%, Val Loss: 0.7904, Val Acc: 71.76%, Time: 17.05s *
# Epoch: 5, Train Loss: 0.4358, Train Acc: 85.17%, Val Loss: 0.8017, Val Acc: 70.25%, Time: 17.10s
# Epoch: 6, Train Loss: 0.3691, Train Acc: 87.17%, Val Loss: 0.7663, Val Acc: 72.27%, Time: 17.07s *
# Epoch: 7, Train Loss: 0.3041, Train Acc: 89.60%, Val Loss: 0.7724, Val Acc: 72.94%, Time: 17.08s *
# Epoch: 8, Train Loss: 0.2627, Train Acc: 90.78%, Val Loss: 0.7474, Val Acc: 73.45%, Time: 17.08s *
# Epoch: 9, Train Loss:  0.216, Train Acc: 92.86%, Val Loss: 0.7633, Val Acc: 74.12%, Time: 17.06s *
# Epoch: 10, Train Loss: 0.1938, Train Acc: 93.50%, Val Loss: 0.7533, Val Acc: 74.45%, Time: 17.07s *
# Epoch: 11, Train Loss: 0.1679, Train Acc: 94.40%, Val Loss: 0.7652, Val Acc: 76.81%, Time: 17.14s *
# Epoch: 12, Train Loss: 0.1435, Train Acc: 95.04%, Val Loss: 0.7585, Val Acc: 74.29%, Time: 17.14s
# Epoch: 13, Train Loss:  0.137, Train Acc: 95.47%, Val Loss: 0.8449, Val Acc: 76.13%, Time: 17.06s
# Epoch: 14, Train Loss: 0.1217, Train Acc: 95.77%, Val Loss: 0.7731, Val Acc: 76.81%, Time: 17.05s
# Epoch: 15, Train Loss:  0.109, Train Acc: 96.13%, Val Loss: 0.8009, Val Acc: 77.65%, Time: 17.02s *
# Epoch: 16, Train Loss: 0.1012, Train Acc: 96.46%, Val Loss: 0.9173, Val Acc: 74.62%, Time: 17.08s
# Epoch: 17, Train Loss: 0.1018, Train Acc: 96.31%, Val Loss: 0.8196, Val Acc: 75.63%, Time: 17.04s
# Epoch: 18, Train Loss: 0.09899, Train Acc: 96.59%, Val Loss: 0.8244, Val Acc: 76.64%, Time: 17.17s
# Epoch: 19, Train Loss: 0.09077, Train Acc: 96.78%, Val Loss: 0.9772, Val Acc: 76.30%, Time: 17.03s
# No optimization for a long time, auto-stopping...
# Precision, Recall and F1-Score...
#               precision    recall  f1-score   support
#
#         ABBR       0.79      0.79      0.79        14
#         DESC       0.74      0.57      0.64       114
#         ENTY       0.67      0.82      0.73       149
#          HUM       0.81      0.74      0.77       121
#          LOC       0.79      0.79      0.79        96
#          NUM       0.88      0.90      0.89       101
#
#    micro avg       0.76      0.76      0.76       595
#    macro avg       0.78      0.77      0.77       595
# weighted avg       0.77      0.76      0.76       595
#
# Confusion Matrix...
# [[ 11   2   1   0   0   0]
#  [  1  65  26  11   8   3]
#  [  1   9 122   9   5   3]
#  [  0   3  25  89   3   1]
#  [  1   7   6   0  76   6]
#  [  0   2   3   1   4  91]]
# [0.7953020134228188, 0.7734899328859061, 0.7798319327731092, 0.7831932773109244, 0.7815126050420168, 0.7394957983193278, 0.7764705882352941, 0.7495798319327731, 0.7781512605042017, 0.7630252100840336]
# 0.7720052450510405, 0.015874129327681688, 0.0167328015158505, 0.0002519879819119639
# [0.7953020134228188,
#  0.7734899328859061,
#  0.7798319327731092,
#  0.7831932773109244,
#  0.7815126050420168,
#  0.7394957983193278,
#  0.7764705882352941,
#  0.7495798319327731,
#  0.7781512605042017,
#  0.7630252100840336]

# %% [raw]
# classifier.train(
#     X_train=X_train,
#     y_train=y_train,
#     X_eval=X_eval,
#     y_eval=y_eval,
#     epochs=30
# )
